# %% [markdown]
# <a href="https://colab.research.google.com/github/gapalyt/project2/blob/main/VMS_%EB%B3%80%EA%B2%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 파일

# %%
# 드라이브 마운트
from google.colab import drive 

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 엑셀 파일을 csv로 변환
import pandas as pd

xlsx = pd.read_excel("/content/drive/MyDrive/멀티캠퍼스/I/파이널 프로젝트/자료/VMS_현황자료_20230117.xls")
xlsx.to_csv("/content/drive/MyDrive/멀티캠퍼스/I/파이널 프로젝트/자료/VMS_현황자료_20230117.csv")

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/I/파이널 프로젝트/자료/VMS_현황자료_20230117.csv')
df
# Out:
#       Unnamed: 0    순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  \
# 0              0   112   0010VME00100  129.105278  35.279167   101    경부선
# 1              1   114   0010VME00200  129.061944  35.317778   101    경부선
# 2              2   118   0010VME00400  129.088611  35.466111   101    경부선
# 3              3   120   0010VME00500  129.106944  35.519167   101    경부선
# 4              4   248   0010VME00600  129.113944  35.830778   101    경부선
# ...          ...   ...            ...         ...        ...   ...    ...
# 1485        1485  1074  52026VMN21001  126.973701  35.886580   103    NaN
# 1486        1486  1076  52026VMS21201  127.328327  35.856220   103    NaN
# 1487        1487   138   5510VMS00100  129.014722  35.316944   101  중앙선지선
# 1488        1488   137   5510VMX00100  129.017500  35.275000   101  중앙선지선
# 1489        1489   139   5510VMX00200  129.029722  35.318889   101  중앙선지선
#
#       노선번호 방향
# 0        1  E
# 1        1  E
# 2        1  E
# 3        1  E
# ...

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
df
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0      112   0010VME00100  129.105278  35.279167   101    경부선     1  E
# 1      114   0010VME00200  129.061944  35.317778   101    경부선     1  E
# 2      118   0010VME00400  129.088611  35.466111   101    경부선     1  E
# 3      120   0010VME00500  129.106944  35.519167   101    경부선     1  E
# 4      248   0010VME00600  129.113944  35.830778   101    경부선     1  E
# ...    ...            ...         ...        ...   ...    ...   ... ..
# 1485  1074  52026VMN21001  126.973701  35.886580   103    NaN    26  N
# 1486  1076  52026VMS21201  127.328327  35.856220   103    NaN    26  S
# 1487   138   5510VMS00100  129.014722  35.316944   101  중앙선지선   551  S
# 1488   137   5510VMX00100  129.017500  35.275000   101  중앙선지선   551  X
# 1489   139   5510VMX00200  129.029722  35.318889   101  중앙선지선   551  X
#
# [1490 rows x 8 columns]

# %% [markdown]
# ## 도로명 변경

# %%
df_name = df['도로명'].value_counts().index.tolist()
df_name
# Out:
# ['경부선',
#  '영동선',
#  '중부선',
#  '중부내륙선',
#  '남해선',
#  '서해안선',
#  '호남선',
#  '서울외곽순환선',
#  '당진대전선',
#  '중앙선',
#  '청원상주선',
#  '평택제천선',
#  '익산포항선',
#  '무안광주선',
#  '동해선',
#  '영암순천선',
#  '부산울산선',
#  '순천완주선',
#  '서천공주선',
#  '호남선의지선',
#  '서울양양선',
#  '88올림픽선',
#  '고창담양선',
#  '평택화성선',
#  '중부내륙지선',
#  '제2경인선',
#  '경인선',
#  '남해제1지선',
#  '남해제2지선',
#  '봉담동탄선',
#  '대전남부순환선',
#  '울산선',
#  '중앙선지선',
#  '오산화성선']

# %%
df_name1 = df[df['도로명'] == '경부선']
df_name1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    112  0010VME00100  129.105278  35.279167   101  경부선     1  E
# 1    114  0010VME00200  129.061944  35.317778   101  경부선     1  E
# 2    118  0010VME00400  129.088611  35.466111   101  경부선     1  E
# 3    120  0010VME00500  129.106944  35.519167   101  경부선     1  E
# 4    248  0010VME00600  129.113944  35.830778   101  경부선     1  E
# ..   ...           ...         ...        ...   ...  ...   ... ..
# 150  381  0010VMX04800  127.119167  37.391667   101  경부선     1  X
# 151  383  0010VMX05100  127.040278  37.468056   101  경부선     1  X
# 152  386  0010VMX05300  127.030556  37.484167   101  경부선     1  X
# 153  385  0010VMX05400  127.022222  37.482778   101  경부선     1  X
# 154  387  0010VMX05600  127.017778  37.503056   101  경부선     1  X
#
# [155 rows x 8 columns]

# %%
df_name1_num = df_name1.reset_index(drop = True)
df_name1_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    112  0010VME00100  129.105278  35.279167   101  경부선     1  E
# 1    114  0010VME00200  129.061944  35.317778   101  경부선     1  E
# 2    118  0010VME00400  129.088611  35.466111   101  경부선     1  E
# 3    120  0010VME00500  129.106944  35.519167   101  경부선     1  E
# 4    248  0010VME00600  129.113944  35.830778   101  경부선     1  E
# ..   ...           ...         ...        ...   ...  ...   ... ..
# 150  381  0010VMX04800  127.119167  37.391667   101  경부선     1  X
# 151  383  0010VMX05100  127.040278  37.468056   101  경부선     1  X
# 152  386  0010VMX05300  127.030556  37.484167   101  경부선     1  X
# 153  385  0010VMX05400  127.022222  37.482778   101  경부선     1  X
# 154  387  0010VMX05600  127.017778  37.503056   101  경부선     1  X
#
# [155 rows x 8 columns]

# %%
df_name1_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name1_num
# Out:
#      도로명
# 0    경부선
# 1    경부선
# 2    경부선
# 3    경부선
# 4    경부선
# ..   ...
# 150  경부선
# 151  경부선
# 152  경부선
# 153  경부선
# 154  경부선
#
# [155 rows x 1 columns]

# %%
df_name1_num.iloc[:] = '경부고속도로'
df_name1_num
# Out:
#         도로명
# 0    경부고속도로
# 1    경부고속도로
# 2    경부고속도로
# 3    경부고속도로
# 4    경부고속도로
# ..      ...
# 150  경부고속도로
# 151  경부고속도로
# 152  경부고속도로
# 153  경부고속도로
# 154  경부고속도로
#
# [155 rows x 1 columns]

# %%
df_name1_num1 = df_name1.reset_index(drop = True)
df_name1_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    112  0010VME00100  129.105278  35.279167   101  경부선     1  E
# 1    114  0010VME00200  129.061944  35.317778   101  경부선     1  E
# 2    118  0010VME00400  129.088611  35.466111   101  경부선     1  E
# 3    120  0010VME00500  129.106944  35.519167   101  경부선     1  E
# 4    248  0010VME00600  129.113944  35.830778   101  경부선     1  E
# ..   ...           ...         ...        ...   ...  ...   ... ..
# 150  381  0010VMX04800  127.119167  37.391667   101  경부선     1  X
# 151  383  0010VMX05100  127.040278  37.468056   101  경부선     1  X
# 152  386  0010VMX05300  127.030556  37.484167   101  경부선     1  X
# 153  385  0010VMX05400  127.022222  37.482778   101  경부선     1  X
# 154  387  0010VMX05600  127.017778  37.503056   101  경부선     1  X
#
# [155 rows x 8 columns]

# %%
df_name1_num1['도로명'] = df_name1_num['도로명']
df_name1_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0    112  0010VME00100  129.105278  35.279167   101  경부고속도로     1  E
# 1    114  0010VME00200  129.061944  35.317778   101  경부고속도로     1  E
# 2    118  0010VME00400  129.088611  35.466111   101  경부고속도로     1  E
# 3    120  0010VME00500  129.106944  35.519167   101  경부고속도로     1  E
# 4    248  0010VME00600  129.113944  35.830778   101  경부고속도로     1  E
# ..   ...           ...         ...        ...   ...     ...   ... ..
# 150  381  0010VMX04800  127.119167  37.391667   101  경부고속도로     1  X
# 151  383  0010VMX05100  127.040278  37.468056   101  경부고속도로     1  X
# 152  386  0010VMX05300  127.030556  37.484167   101  경부고속도로     1  X
# 153  385  0010VMX05400  127.022222  37.482778   101  경부고속도로     1  X
# 154  387  0010VMX05600  127.017778  37.503056   101  경부고속도로     1  X
#
# [155 rows x 8 columns]

# %%
df_name2 = df[df['도로명'] == '영동선']
df_name2
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 626  320  0500VME00100  126.739722  37.419444   101  영동선    50  E
# 627  321  0500VME00200  126.782500  37.355556   101  영동선    50  E
# 628  323  0500VME00400  126.831389  37.344722   101  영동선    50  E
# 629  325  0500VME00600  126.940000  37.325833   101  영동선    50  E
# 630  329  0500VME00700  127.018889  37.308333   101  영동선    50  E
# ..   ...           ...         ...        ...   ...  ...   ... ..
# 683  425  0500VMX00950  127.214444  37.247500   101  영동선    50  X
# 684  427  0500VMX01000  127.300833  37.228333   101  영동선    50  X
# 685  431  0500VMX01050  127.364167  37.241944   101  영동선    50  X
# 686  437  0500VMX01100  127.493056  37.246667   101  영동선    50  X
# 687  438  0500VMX01200  127.482222  37.256111   101  영동선    50  X
#
# [62 rows x 8 columns]

# %%
df_name2_num = df_name2.reset_index(drop = True)
df_name2_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   320  0500VME00100  126.739722  37.419444   101  영동선    50  E
# 1   321  0500VME00200  126.782500  37.355556   101  영동선    50  E
# 2   323  0500VME00400  126.831389  37.344722   101  영동선    50  E
# 3   325  0500VME00600  126.940000  37.325833   101  영동선    50  E
# 4   329  0500VME00700  127.018889  37.308333   101  영동선    50  E
# ..  ...           ...         ...        ...   ...  ...   ... ..
# 57  425  0500VMX00950  127.214444  37.247500   101  영동선    50  X
# 58  427  0500VMX01000  127.300833  37.228333   101  영동선    50  X
# 59  431  0500VMX01050  127.364167  37.241944   101  영동선    50  X
# 60  437  0500VMX01100  127.493056  37.246667   101  영동선    50  X
# 61  438  0500VMX01200  127.482222  37.256111   101  영동선    50  X
#
# [62 rows x 8 columns]

# %%
df_name2_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name2_num
# Out:
#     도로명
# 0   영동선
# 1   영동선
# 2   영동선
# 3   영동선
# 4   영동선
# ..  ...
# 57  영동선
# 58  영동선
# 59  영동선
# 60  영동선
# 61  영동선
#
# [62 rows x 1 columns]

# %%
df_name2_num.iloc[:] = '영동고속도로'
df_name2_num
# Out:
#        도로명
# 0   영동고속도로
# 1   영동고속도로
# 2   영동고속도로
# 3   영동고속도로
# 4   영동고속도로
# ..     ...
# 57  영동고속도로
# 58  영동고속도로
# 59  영동고속도로
# 60  영동고속도로
# 61  영동고속도로
#
# [62 rows x 1 columns]

# %%
df_name2_num1 = df_name2.reset_index(drop = True)
df_name2_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   320  0500VME00100  126.739722  37.419444   101  영동선    50  E
# 1   321  0500VME00200  126.782500  37.355556   101  영동선    50  E
# 2   323  0500VME00400  126.831389  37.344722   101  영동선    50  E
# 3   325  0500VME00600  126.940000  37.325833   101  영동선    50  E
# 4   329  0500VME00700  127.018889  37.308333   101  영동선    50  E
# ..  ...           ...         ...        ...   ...  ...   ... ..
# 57  425  0500VMX00950  127.214444  37.247500   101  영동선    50  X
# 58  427  0500VMX01000  127.300833  37.228333   101  영동선    50  X
# 59  431  0500VMX01050  127.364167  37.241944   101  영동선    50  X
# 60  437  0500VMX01100  127.493056  37.246667   101  영동선    50  X
# 61  438  0500VMX01200  127.482222  37.256111   101  영동선    50  X
#
# [62 rows x 8 columns]

# %%
df_name2_num1['도로명'] = df_name2_num['도로명']
df_name2_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   320  0500VME00100  126.739722  37.419444   101  영동고속도로    50  E
# 1   321  0500VME00200  126.782500  37.355556   101  영동고속도로    50  E
# 2   323  0500VME00400  126.831389  37.344722   101  영동고속도로    50  E
# 3   325  0500VME00600  126.940000  37.325833   101  영동고속도로    50  E
# 4   329  0500VME00700  127.018889  37.308333   101  영동고속도로    50  E
# ..  ...           ...         ...        ...   ...     ...   ... ..
# 57  425  0500VMX00950  127.214444  37.247500   101  영동고속도로    50  X
# 58  427  0500VMX01000  127.300833  37.228333   101  영동고속도로    50  X
# 59  431  0500VMX01050  127.364167  37.241944   101  영동고속도로    50  X
# 60  437  0500VMX01100  127.493056  37.246667   101  영동고속도로    50  X
# 61  438  0500VMX01200  127.482222  37.256111   101  영동고속도로    50  X
#
# [62 rows x 8 columns]

# %%
df_name3 = df[df['도로명'] == '중부선']
df_name3
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 492   300  0351VME00100  128.422778  34.868611   101  중부선    35  E
# 493   301  0351VME00200  128.371389  34.981111   101  중부선    35  E
# 494   102  0351VME00300  128.210833  35.071944   101  중부선    35  E
# 495   104  0351VME00350  128.134722  35.121667   101  중부선    35  E
# 496   105  0351VME00400  128.069722  35.155833   101  중부선    35  E
# 497   108  0351VME00450  127.850000  35.457500   101  중부선    35  E
# 498   110  0351VME00600  127.713889  35.631389   101  중부선    35  E
# 499  1351  0351VME00700  127.614900  35.716689   101  중부선    35  E
# 500  1353  0351VME00800  127.594897  35.756600   101  중부선    35  E
# 501  1357  0351VME00900  127.540294  36.078108   101  중부선    35  E
# 502  1355  0351VME01000  127.661958  35.942611   101  중부선    35  E
# 503  1358  0351VME01100  127.487900  36.163347   101  중부선    35  E
# 504  1360  0351VME01200  127.487850  36.218717   101  중부선    35  E
# ...

# %%
df_name3_num = df_name3.reset_index(drop = True)
df_name3_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    300  0351VME00100  128.422778  34.868611   101  중부선    35  E
# 1    301  0351VME00200  128.371389  34.981111   101  중부선    35  E
# 2    102  0351VME00300  128.210833  35.071944   101  중부선    35  E
# 3    104  0351VME00350  128.134722  35.121667   101  중부선    35  E
# 4    105  0351VME00400  128.069722  35.155833   101  중부선    35  E
# 5    108  0351VME00450  127.850000  35.457500   101  중부선    35  E
# 6    110  0351VME00600  127.713889  35.631389   101  중부선    35  E
# 7   1351  0351VME00700  127.614900  35.716689   101  중부선    35  E
# 8   1353  0351VME00800  127.594897  35.756600   101  중부선    35  E
# 9   1357  0351VME00900  127.540294  36.078108   101  중부선    35  E
# 10  1355  0351VME01000  127.661958  35.942611   101  중부선    35  E
# 11  1358  0351VME01100  127.487900  36.163347   101  중부선    35  E
# 12  1360  0351VME01200  127.487850  36.218717   101  중부선    35  E
# ...

# %%
df_name3_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name3_num
# Out:
#     도로명
# 0   중부선
# 1   중부선
# 2   중부선
# 3   중부선
# 4   중부선
# 5   중부선
# 6   중부선
# 7   중부선
# 8   중부선
# 9   중부선
# 10  중부선
# 11  중부선
# 12  중부선
# 13  중부선
# 14  중부선
# 15  중부선
# 16  중부선
# 17  중부선
# 18  중부선
# 19  중부선
# 20  중부선
# 21  중부선
# 22  중부선
# 23  중부선
# 24  중부선
# 25  중부선
# 26  중부선
# 27  중부선
# 28  중부선
# 29  중부선
# 30  중부선
# 31  중부선
# 32  중부선
# 33  중부선
# 34  중부선
# 35  중부선
# 36  중부선
# 37  중부선
# 38  중부선
# 39  중부선
# 40  중부선
# 41  중부선
# 42  중부선
# 43  중부선
# 44  중부선
# 45  중부선
# 46  중부선
# 47  중부선
# 48  중부선
# 49  중부선
# 50  중부선
# 51  중부선
# 52  중부선
# 53  중부선
# 54  중부선
# 55  중부선
# 56  중부선
# 57  중부선
# 58  중부선
# 59  중부선

# %%
df_name3_num.iloc[:] = '중부고속도로'
df_name3_num
# Out:
#        도로명
# 0   중부고속도로
# 1   중부고속도로
# 2   중부고속도로
# 3   중부고속도로
# 4   중부고속도로
# 5   중부고속도로
# 6   중부고속도로
# 7   중부고속도로
# 8   중부고속도로
# 9   중부고속도로
# 10  중부고속도로
# 11  중부고속도로
# 12  중부고속도로
# 13  중부고속도로
# 14  중부고속도로
# 15  중부고속도로
# 16  중부고속도로
# 17  중부고속도로
# 18  중부고속도로
# 19  중부고속도로
# 20  중부고속도로
# 21  중부고속도로
# 22  중부고속도로
# 23  중부고속도로
# 24  중부고속도로
# 25  중부고속도로
# 26  중부고속도로
# 27  중부고속도로
# 28  중부고속도로
# 29  중부고속도로
# 30  중부고속도로
# 31  중부고속도로
# 32  중부고속도로
# 33  중부고속도로
# 34  중부고속도로
# 35  중부고속도로
# 36  중부고속도로
# 37  중부고속도로
# 38  중부고속도로
# 39  중부고속도로
# 40  중부고속도로
# 41  중부고속도로
# 42  중부고속도로
# 43  중부고속도로
# 44  중부고속도로
# 45  중부고속도로
# 46  중부고속도로
# 47  중부고속도로
# 48  중부고속도로
# 49  중부고속도로
# 50  중부고속도로
# 51  중부고속도로
# 52  중부고속도로
# 53  중부고속도로
# 54  중부고속도로
# 55  중부고속도로
# 56  중부고속도로
# 57  중부고속도로
# 58  중부고속도로
# 59  중부고속도로

# %%
df_name3_num1 = df_name3.reset_index(drop = True)
df_name3_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    300  0351VME00100  128.422778  34.868611   101  중부선    35  E
# 1    301  0351VME00200  128.371389  34.981111   101  중부선    35  E
# 2    102  0351VME00300  128.210833  35.071944   101  중부선    35  E
# 3    104  0351VME00350  128.134722  35.121667   101  중부선    35  E
# 4    105  0351VME00400  128.069722  35.155833   101  중부선    35  E
# 5    108  0351VME00450  127.850000  35.457500   101  중부선    35  E
# 6    110  0351VME00600  127.713889  35.631389   101  중부선    35  E
# 7   1351  0351VME00700  127.614900  35.716689   101  중부선    35  E
# 8   1353  0351VME00800  127.594897  35.756600   101  중부선    35  E
# 9   1357  0351VME00900  127.540294  36.078108   101  중부선    35  E
# 10  1355  0351VME01000  127.661958  35.942611   101  중부선    35  E
# 11  1358  0351VME01100  127.487900  36.163347   101  중부선    35  E
# 12  1360  0351VME01200  127.487850  36.218717   101  중부선    35  E
# ...

# %%
df_name3_num1['도로명'] = df_name3_num['도로명']
df_name3_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0    300  0351VME00100  128.422778  34.868611   101  중부고속도로    35  E
# 1    301  0351VME00200  128.371389  34.981111   101  중부고속도로    35  E
# 2    102  0351VME00300  128.210833  35.071944   101  중부고속도로    35  E
# 3    104  0351VME00350  128.134722  35.121667   101  중부고속도로    35  E
# 4    105  0351VME00400  128.069722  35.155833   101  중부고속도로    35  E
# 5    108  0351VME00450  127.850000  35.457500   101  중부고속도로    35  E
# 6    110  0351VME00600  127.713889  35.631389   101  중부고속도로    35  E
# 7   1351  0351VME00700  127.614900  35.716689   101  중부고속도로    35  E
# 8   1353  0351VME00800  127.594897  35.756600   101  중부고속도로    35  E
# 9   1357  0351VME00900  127.540294  36.078108   101  중부고속도로    35  E
# 10  1355  0351VME01000  127.661958  35.942611   101  중부고속도로    35  E
# 11  1358  0351VME01100  127.487900  36.163347   101  중부고속도로    35  E
# 12  1360  0351VME01200  127.487850  36.218717   101  중부고속도로    35  E
# ...

# %%
df_name4 = df[df['도로명'] == '중부내륙선']
df_name4
# Out:
#        순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 575   589   0450VME00050  128.502778  35.306944   101  중부내륙선    45  E
# 576   194   0450VME00100  128.513056  35.486944   101  중부내륙선    45  E
# 577   590   0450VME00230  128.510278  35.495833   101  중부내륙선    45  E
# 578   196   0450VME00270  128.443611  35.642222   101  중부내륙선    45  E
# 579   276   0450VME00400  128.405000  35.716944   101  중부내륙선    45  E
# 580   278   0450VME00500  128.343333  35.810278   101  중부내륙선    45  E
# 581   282   0450VME00600  128.286667  35.896667   101  중부내륙선    45  E
# 582   286   0450VME00700  128.270278  36.023611   101  중부내륙선    45  E
# 583   264   0450VME00800  128.260556  36.206111   101  중부내륙선    45  E
# 584   267   0450VME00900  128.231389  36.345000   101  중부내륙선    45  E
# 585   270   0450VME01000  128.148889  36.572222   101  중부내륙선    45  E
# 586  1163   0450VME01100  127.942778  36.855556   101  중부내륙선    45  E
# ...

# %%
df_name4_num = df_name4.reset_index(drop = True)
df_name4_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    589   0450VME00050  128.502778  35.306944   101  중부내륙선    45  E
# 1    194   0450VME00100  128.513056  35.486944   101  중부내륙선    45  E
# 2    590   0450VME00230  128.510278  35.495833   101  중부내륙선    45  E
# 3    196   0450VME00270  128.443611  35.642222   101  중부내륙선    45  E
# 4    276   0450VME00400  128.405000  35.716944   101  중부내륙선    45  E
# 5    278   0450VME00500  128.343333  35.810278   101  중부내륙선    45  E
# 6    282   0450VME00600  128.286667  35.896667   101  중부내륙선    45  E
# 7    286   0450VME00700  128.270278  36.023611   101  중부내륙선    45  E
# 8    264   0450VME00800  128.260556  36.206111   101  중부내륙선    45  E
# 9    267   0450VME00900  128.231389  36.345000   101  중부내륙선    45  E
# 10   270   0450VME01000  128.148889  36.572222   101  중부내륙선    45  E
# 11  1163   0450VME01100  127.942778  36.855556   101  중부내륙선    45  E
# 12  1167   0450VME01300  127.701667  37.112500   101  중부내륙선    45  E
# ...

# %%
df_name4_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name4_num
# Out:
#       도로명
# 0   중부내륙선
# 1   중부내륙선
# 2   중부내륙선
# 3   중부내륙선
# 4   중부내륙선
# 5   중부내륙선
# 6   중부내륙선
# 7   중부내륙선
# 8   중부내륙선
# 9   중부내륙선
# 10  중부내륙선
# 11  중부내륙선
# 12  중부내륙선
# 13  중부내륙선
# 14  중부내륙선
# 15  중부내륙선
# 16  중부내륙선
# 17  중부내륙선
# 18  중부내륙선
# 19  중부내륙선
# 20  중부내륙선
# 21  중부내륙선
# 22  중부내륙선
# 23  중부내륙선
# 24  중부내륙선
# 25  중부내륙선
# 26  중부내륙선
# 27  중부내륙선
# 28  중부내륙선
# 29  중부내륙선
# 30  중부내륙선
# 31  중부내륙선
# 32  중부내륙선
# 33  중부내륙선
# 34  중부내륙선
# 35  중부내륙선
# 36  중부내륙선
# 37  중부내륙선
# 38  중부내륙선
# 39  중부내륙선
# 40  중부내륙선
# 41  중부내륙선
# 42  중부내륙선
# 43  중부내륙선
# 44  중부내륙선
# 45  중부내륙선
# 46  중부내륙선
# 47  중부내륙선
# 48  중부내륙선
# 49  중부내륙선
# 50  중부내륙선

# %%
df_name4_num.iloc[:] = '중부내륙고속도로'
df_name4_num
# Out:
#          도로명
# 0   중부내륙고속도로
# 1   중부내륙고속도로
# 2   중부내륙고속도로
# 3   중부내륙고속도로
# 4   중부내륙고속도로
# 5   중부내륙고속도로
# 6   중부내륙고속도로
# 7   중부내륙고속도로
# 8   중부내륙고속도로
# 9   중부내륙고속도로
# 10  중부내륙고속도로
# 11  중부내륙고속도로
# 12  중부내륙고속도로
# 13  중부내륙고속도로
# 14  중부내륙고속도로
# 15  중부내륙고속도로
# 16  중부내륙고속도로
# 17  중부내륙고속도로
# 18  중부내륙고속도로
# 19  중부내륙고속도로
# 20  중부내륙고속도로
# 21  중부내륙고속도로
# 22  중부내륙고속도로
# 23  중부내륙고속도로
# 24  중부내륙고속도로
# 25  중부내륙고속도로
# 26  중부내륙고속도로
# 27  중부내륙고속도로
# 28  중부내륙고속도로
# 29  중부내륙고속도로
# 30  중부내륙고속도로
# 31  중부내륙고속도로
# 32  중부내륙고속도로
# 33  중부내륙고속도로
# 34  중부내륙고속도로
# 35  중부내륙고속도로
# 36  중부내륙고속도로
# 37  중부내륙고속도로
# 38  중부내륙고속도로
# 39  중부내륙고속도로
# 40  중부내륙고속도로
# 41  중부내륙고속도로
# 42  중부내륙고속도로
# 43  중부내륙고속도로
# 44  중부내륙고속도로
# 45  중부내륙고속도로
# 46  중부내륙고속도로
# 47  중부내륙고속도로
# 48  중부내륙고속도로
# 49  중부내륙고속도로
# 50  중부내륙고속도로

# %%
df_name4_num1 = df_name4.reset_index(drop = True)
df_name4_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    589   0450VME00050  128.502778  35.306944   101  중부내륙선    45  E
# 1    194   0450VME00100  128.513056  35.486944   101  중부내륙선    45  E
# 2    590   0450VME00230  128.510278  35.495833   101  중부내륙선    45  E
# 3    196   0450VME00270  128.443611  35.642222   101  중부내륙선    45  E
# 4    276   0450VME00400  128.405000  35.716944   101  중부내륙선    45  E
# 5    278   0450VME00500  128.343333  35.810278   101  중부내륙선    45  E
# 6    282   0450VME00600  128.286667  35.896667   101  중부내륙선    45  E
# 7    286   0450VME00700  128.270278  36.023611   101  중부내륙선    45  E
# 8    264   0450VME00800  128.260556  36.206111   101  중부내륙선    45  E
# 9    267   0450VME00900  128.231389  36.345000   101  중부내륙선    45  E
# 10   270   0450VME01000  128.148889  36.572222   101  중부내륙선    45  E
# 11  1163   0450VME01100  127.942778  36.855556   101  중부내륙선    45  E
# 12  1167   0450VME01300  127.701667  37.112500   101  중부내륙선    45  E
# ...

# %%
df_name4_num1['도로명'] = df_name4_num['도로명']
df_name4_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0    589   0450VME00050  128.502778  35.306944   101  중부내륙고속도로    45  E
# 1    194   0450VME00100  128.513056  35.486944   101  중부내륙고속도로    45  E
# 2    590   0450VME00230  128.510278  35.495833   101  중부내륙고속도로    45  E
# 3    196   0450VME00270  128.443611  35.642222   101  중부내륙고속도로    45  E
# 4    276   0450VME00400  128.405000  35.716944   101  중부내륙고속도로    45  E
# 5    278   0450VME00500  128.343333  35.810278   101  중부내륙고속도로    45  E
# 6    282   0450VME00600  128.286667  35.896667   101  중부내륙고속도로    45  E
# 7    286   0450VME00700  128.270278  36.023611   101  중부내륙고속도로    45  E
# 8    264   0450VME00800  128.260556  36.206111   101  중부내륙고속도로    45  E
# 9    267   0450VME00900  128.231389  36.345000   101  중부내륙고속도로    45  E
# 10   270   0450VME01000  128.148889  36.572222   101  중부내륙고속도로    45  E
# 11  1163   0450VME01100  127.942778  36.855556   101  중부내륙고속도로    45  E
# ...

# %%
df_name5 = df[df['도로명'] == '남해선']
df_name5
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 155    64  0100VME00050  127.492733  34.997528   101  남해선    10  E
# 156    67  0100VME00070  127.576678  34.986672   101  남해선    10  E
# 157   199  0100VME00100  128.538889  35.282778   101  남해선    10  E
# 158    68  0100VME00150  127.619028  34.968444   101  남해선    10  E
# 159   163  0100VME00400  127.870556  35.030278   101  남해선    10  E
# 160   164  0100VME00500  128.073889  35.101111   101  남해선    10  E
# 161   167  0100VME00550  128.104444  35.127778   101  남해선    10  E
# 162   168  0100VME00620  128.107222  35.158611   101  남해선    10  E
# 163   172  0100VME00640  128.150000  35.168056   101  남해선    10  E
# 164   176  0100VME00775  128.269167  35.218611   101  남해선    10  E
# 165   181  0100VME00820  128.289444  35.275278   101  남해선    10  E
# 166   184  0100VME00835  128.327222  35.292778   101  남해선    10  E
# 167   188  0100VME00860  128.363889  35.292500   101  남해선    10  E
# ...

# %%
df_name5_num = df_name5.reset_index(drop = True)
df_name5_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0     64  0100VME00050  127.492733  34.997528   101  남해선    10  E
# 1     67  0100VME00070  127.576678  34.986672   101  남해선    10  E
# 2    199  0100VME00100  128.538889  35.282778   101  남해선    10  E
# 3     68  0100VME00150  127.619028  34.968444   101  남해선    10  E
# 4    163  0100VME00400  127.870556  35.030278   101  남해선    10  E
# 5    164  0100VME00500  128.073889  35.101111   101  남해선    10  E
# 6    167  0100VME00550  128.104444  35.127778   101  남해선    10  E
# 7    168  0100VME00620  128.107222  35.158611   101  남해선    10  E
# 8    172  0100VME00640  128.150000  35.168056   101  남해선    10  E
# 9    176  0100VME00775  128.269167  35.218611   101  남해선    10  E
# 10   181  0100VME00820  128.289444  35.275278   101  남해선    10  E
# 11   184  0100VME00835  128.327222  35.292778   101  남해선    10  E
# 12   188  0100VME00860  128.363889  35.292500   101  남해선    10  E
# ...

# %%
df_name5_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name5_num
# Out:
#     도로명
# 0   남해선
# 1   남해선
# 2   남해선
# 3   남해선
# 4   남해선
# 5   남해선
# 6   남해선
# 7   남해선
# 8   남해선
# 9   남해선
# 10  남해선
# 11  남해선
# 12  남해선
# 13  남해선
# 14  남해선
# 15  남해선
# 16  남해선
# 17  남해선
# 18  남해선
# 19  남해선
# 20  남해선
# 21  남해선
# 22  남해선
# 23  남해선
# 24  남해선
# 25  남해선
# 26  남해선
# 27  남해선
# 28  남해선
# 29  남해선
# 30  남해선
# 31  남해선
# 32  남해선
# 33  남해선
# 34  남해선
# 35  남해선
# 36  남해선
# 37  남해선
# 38  남해선
# 39  남해선
# 40  남해선
# 41  남해선
# 42  남해선
# 43  남해선
# 44  남해선
# 45  남해선
# 46  남해선
# 47  남해선
# 48  남해선
# 49  남해선
# 50  남해선

# %%
df_name5_num.iloc[:] = '남해고속도로'
df_name5_num
# Out:
#        도로명
# 0   남해고속도로
# 1   남해고속도로
# 2   남해고속도로
# 3   남해고속도로
# 4   남해고속도로
# 5   남해고속도로
# 6   남해고속도로
# 7   남해고속도로
# 8   남해고속도로
# 9   남해고속도로
# 10  남해고속도로
# 11  남해고속도로
# 12  남해고속도로
# 13  남해고속도로
# 14  남해고속도로
# 15  남해고속도로
# 16  남해고속도로
# 17  남해고속도로
# 18  남해고속도로
# 19  남해고속도로
# 20  남해고속도로
# 21  남해고속도로
# 22  남해고속도로
# 23  남해고속도로
# 24  남해고속도로
# 25  남해고속도로
# 26  남해고속도로
# 27  남해고속도로
# 28  남해고속도로
# 29  남해고속도로
# 30  남해고속도로
# 31  남해고속도로
# 32  남해고속도로
# 33  남해고속도로
# 34  남해고속도로
# 35  남해고속도로
# 36  남해고속도로
# 37  남해고속도로
# 38  남해고속도로
# 39  남해고속도로
# 40  남해고속도로
# 41  남해고속도로
# 42  남해고속도로
# 43  남해고속도로
# 44  남해고속도로
# 45  남해고속도로
# 46  남해고속도로
# 47  남해고속도로
# 48  남해고속도로
# 49  남해고속도로
# 50  남해고속도로

# %%
df_name5_num1 = df_name5.reset_index(drop = True)
df_name5_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0     64  0100VME00050  127.492733  34.997528   101  남해선    10  E
# 1     67  0100VME00070  127.576678  34.986672   101  남해선    10  E
# 2    199  0100VME00100  128.538889  35.282778   101  남해선    10  E
# 3     68  0100VME00150  127.619028  34.968444   101  남해선    10  E
# 4    163  0100VME00400  127.870556  35.030278   101  남해선    10  E
# 5    164  0100VME00500  128.073889  35.101111   101  남해선    10  E
# 6    167  0100VME00550  128.104444  35.127778   101  남해선    10  E
# 7    168  0100VME00620  128.107222  35.158611   101  남해선    10  E
# 8    172  0100VME00640  128.150000  35.168056   101  남해선    10  E
# 9    176  0100VME00775  128.269167  35.218611   101  남해선    10  E
# 10   181  0100VME00820  128.289444  35.275278   101  남해선    10  E
# 11   184  0100VME00835  128.327222  35.292778   101  남해선    10  E
# 12   188  0100VME00860  128.363889  35.292500   101  남해선    10  E
# ...

# %%
df_name5_num1['도로명'] = df_name5_num['도로명']
df_name5_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0     64  0100VME00050  127.492733  34.997528   101  남해고속도로    10  E
# 1     67  0100VME00070  127.576678  34.986672   101  남해고속도로    10  E
# 2    199  0100VME00100  128.538889  35.282778   101  남해고속도로    10  E
# 3     68  0100VME00150  127.619028  34.968444   101  남해고속도로    10  E
# 4    163  0100VME00400  127.870556  35.030278   101  남해고속도로    10  E
# 5    164  0100VME00500  128.073889  35.101111   101  남해고속도로    10  E
# 6    167  0100VME00550  128.104444  35.127778   101  남해고속도로    10  E
# 7    168  0100VME00620  128.107222  35.158611   101  남해고속도로    10  E
# 8    172  0100VME00640  128.150000  35.168056   101  남해고속도로    10  E
# 9    176  0100VME00775  128.269167  35.218611   101  남해고속도로    10  E
# 10   181  0100VME00820  128.289444  35.275278   101  남해고속도로    10  E
# 11   184  0100VME00835  128.327222  35.292778   101  남해고속도로    10  E
# 12   188  0100VME00860  128.363889  35.292500   101  남해고속도로    10  E
# ...

# %%
df_name6 = df[df['도로명'] == '서해안선']
df_name6
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급   도로명  노선번호 방향
# 284    94  0150VME00050  126.475000  34.851944   101  서해안선    15  E
# 285    96  0150VME00100  126.504167  34.952778   101  서해안선    15  E
# 286    98  0150VME00200  126.481667  35.070278   101  서해안선    15  E
# 287  1370  0150VME00300  126.625553  35.393767   101  서해안선    15  E
# 288  1372  0150VME00400  126.679314  35.482108   101  서해안선    15  E
# 289   582  0150VME00500  126.692822  35.559475   101  서해안선    15  E
# 290  1374  0150VME00600  126.835319  35.810272   101  서해안선    15  E
# 291  1377  0150VME00700  126.837500  35.956944   101  서해안선    15  E
# 292  1379  0150VME00800  126.800000  36.027778   101  서해안선    15  E
# 293  1363  0150VME00900  126.637619  36.118903   101  서해안선    15  E
# 294  1365  0150VME01000  126.589400  36.308950   101  서해안선    15  E
# 295  1368  0150VME01100  126.575019  36.567125   101  서해안선    15  E
# 296  1202  0150VME01300  126.554722  36.688333   101  서해안선   150  E
# ...

# %%
df_name6_num = df_name6.reset_index(drop = True)
df_name6_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급   도로명  노선번호 방향
# 0     94  0150VME00050  126.475000  34.851944   101  서해안선    15  E
# 1     96  0150VME00100  126.504167  34.952778   101  서해안선    15  E
# 2     98  0150VME00200  126.481667  35.070278   101  서해안선    15  E
# 3   1370  0150VME00300  126.625553  35.393767   101  서해안선    15  E
# 4   1372  0150VME00400  126.679314  35.482108   101  서해안선    15  E
# 5    582  0150VME00500  126.692822  35.559475   101  서해안선    15  E
# 6   1374  0150VME00600  126.835319  35.810272   101  서해안선    15  E
# 7   1377  0150VME00700  126.837500  35.956944   101  서해안선    15  E
# 8   1379  0150VME00800  126.800000  36.027778   101  서해안선    15  E
# 9   1363  0150VME00900  126.637619  36.118903   101  서해안선    15  E
# 10  1365  0150VME01000  126.589400  36.308950   101  서해안선    15  E
# 11  1368  0150VME01100  126.575019  36.567125   101  서해안선    15  E
# 12  1202  0150VME01300  126.554722  36.688333   101  서해안선   150  E
# ...

# %%
df_name6_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name6_num
# Out:
#      도로명
# 0   서해안선
# 1   서해안선
# 2   서해안선
# 3   서해안선
# 4   서해안선
# 5   서해안선
# 6   서해안선
# 7   서해안선
# 8   서해안선
# 9   서해안선
# 10  서해안선
# 11  서해안선
# 12  서해안선
# 13  서해안선
# 14  서해안선
# 15  서해안선
# 16  서해안선
# 17  서해안선
# 18  서해안선
# 19  서해안선
# 20  서해안선
# 21  서해안선
# 22  서해안선
# 23  서해안선
# 24  서해안선
# 25  서해안선
# 26  서해안선
# 27  서해안선
# 28  서해안선
# 29  서해안선
# 30  서해안선
# 31  서해안선
# 32  서해안선
# 33  서해안선
# 34  서해안선
# 35  서해안선
# 36  서해안선
# 37  서해안선
# 38  서해안선
# 39  서해안선
# 40  서해안선
# 41  서해안선
# 42  서해안선
# 43  서해안선
# 44  서해안선
# 45  서해안선
# 46  서해안선
# 47  서해안선
# 48  서해안선
# 49  서해안선

# %%
df_name6_num.iloc[:] = '서해안고속도로'
df_name6_num
# Out:
#         도로명
# 0   서해안고속도로
# 1   서해안고속도로
# 2   서해안고속도로
# 3   서해안고속도로
# 4   서해안고속도로
# 5   서해안고속도로
# 6   서해안고속도로
# 7   서해안고속도로
# 8   서해안고속도로
# 9   서해안고속도로
# 10  서해안고속도로
# 11  서해안고속도로
# 12  서해안고속도로
# 13  서해안고속도로
# 14  서해안고속도로
# 15  서해안고속도로
# 16  서해안고속도로
# 17  서해안고속도로
# 18  서해안고속도로
# 19  서해안고속도로
# 20  서해안고속도로
# 21  서해안고속도로
# 22  서해안고속도로
# 23  서해안고속도로
# 24  서해안고속도로
# 25  서해안고속도로
# 26  서해안고속도로
# 27  서해안고속도로
# 28  서해안고속도로
# 29  서해안고속도로
# 30  서해안고속도로
# 31  서해안고속도로
# 32  서해안고속도로
# 33  서해안고속도로
# 34  서해안고속도로
# 35  서해안고속도로
# 36  서해안고속도로
# 37  서해안고속도로
# 38  서해안고속도로
# 39  서해안고속도로
# 40  서해안고속도로
# 41  서해안고속도로
# 42  서해안고속도로
# 43  서해안고속도로
# 44  서해안고속도로
# 45  서해안고속도로
# 46  서해안고속도로
# 47  서해안고속도로
# 48  서해안고속도로
# 49  서해안고속도로

# %%
df_name6_num1 = df_name6.reset_index(drop = True)
df_name6_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급   도로명  노선번호 방향
# 0     94  0150VME00050  126.475000  34.851944   101  서해안선    15  E
# 1     96  0150VME00100  126.504167  34.952778   101  서해안선    15  E
# 2     98  0150VME00200  126.481667  35.070278   101  서해안선    15  E
# 3   1370  0150VME00300  126.625553  35.393767   101  서해안선    15  E
# 4   1372  0150VME00400  126.679314  35.482108   101  서해안선    15  E
# 5    582  0150VME00500  126.692822  35.559475   101  서해안선    15  E
# 6   1374  0150VME00600  126.835319  35.810272   101  서해안선    15  E
# 7   1377  0150VME00700  126.837500  35.956944   101  서해안선    15  E
# 8   1379  0150VME00800  126.800000  36.027778   101  서해안선    15  E
# 9   1363  0150VME00900  126.637619  36.118903   101  서해안선    15  E
# 10  1365  0150VME01000  126.589400  36.308950   101  서해안선    15  E
# 11  1368  0150VME01100  126.575019  36.567125   101  서해안선    15  E
# 12  1202  0150VME01300  126.554722  36.688333   101  서해안선   150  E
# ...

# %%
df_name6_num1['도로명'] = df_name6_num['도로명']
df_name6_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 0     94  0150VME00050  126.475000  34.851944   101  서해안고속도로    15  E
# 1     96  0150VME00100  126.504167  34.952778   101  서해안고속도로    15  E
# 2     98  0150VME00200  126.481667  35.070278   101  서해안고속도로    15  E
# 3   1370  0150VME00300  126.625553  35.393767   101  서해안고속도로    15  E
# 4   1372  0150VME00400  126.679314  35.482108   101  서해안고속도로    15  E
# 5    582  0150VME00500  126.692822  35.559475   101  서해안고속도로    15  E
# 6   1374  0150VME00600  126.835319  35.810272   101  서해안고속도로    15  E
# 7   1377  0150VME00700  126.837500  35.956944   101  서해안고속도로    15  E
# 8   1379  0150VME00800  126.800000  36.027778   101  서해안고속도로    15  E
# 9   1363  0150VME00900  126.637619  36.118903   101  서해안고속도로    15  E
# 10  1365  0150VME01000  126.589400  36.308950   101  서해안고속도로    15  E
# 11  1368  0150VME01100  126.575019  36.567125   101  서해안고속도로    15  E
# ...

# %%
df_name7 = df[df['도로명'] == '호남선']
df_name7
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 369    71  0251VME00100  127.258056  35.094167   101  호남선    25  E
# 370    43  0251VME00200  127.008056  35.251944   101  호남선   251  E
# 371   553  0251VME00600  126.951389  35.215000   101  호남선    25  E
# 372   558  0251VME00700  126.901667  35.181111   101  호남선    25  E
# 373   566  0251VME00800  126.815278  35.243056   101  호남선    25  E
# 374   568  0251VME00900  126.808889  35.394722   101  호남선    25  E
# 375   520  0251VME01000  126.823056  35.552222   101  호남선    25  E
# 376   527  0251VME01200  127.057778  35.900000   101  호남선    25  E
# 377   523  0251VME01300  126.961389  35.702500   101  호남선    25  E
# 378   525  0251VME01400  127.052500  35.853611   101  호남선    25  E
# 379   531  0251VME01500  127.081667  35.934444   101  호남선    25  E
# 380  1336  0251VME01600  127.100339  35.954950   101  호남선    25  E
# 381  1340  0251VME01700  127.103044  36.034742   101  호남선    25  E
# ...

# %%
df_name7_num = df_name7.reset_index(drop = True)
df_name7_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0     71  0251VME00100  127.258056  35.094167   101  호남선    25  E
# 1     43  0251VME00200  127.008056  35.251944   101  호남선   251  E
# 2    553  0251VME00600  126.951389  35.215000   101  호남선    25  E
# 3    558  0251VME00700  126.901667  35.181111   101  호남선    25  E
# 4    566  0251VME00800  126.815278  35.243056   101  호남선    25  E
# 5    568  0251VME00900  126.808889  35.394722   101  호남선    25  E
# 6    520  0251VME01000  126.823056  35.552222   101  호남선    25  E
# 7    527  0251VME01200  127.057778  35.900000   101  호남선    25  E
# 8    523  0251VME01300  126.961389  35.702500   101  호남선    25  E
# 9    525  0251VME01400  127.052500  35.853611   101  호남선    25  E
# 10   531  0251VME01500  127.081667  35.934444   101  호남선    25  E
# 11  1336  0251VME01600  127.100339  35.954950   101  호남선    25  E
# 12  1340  0251VME01700  127.103044  36.034742   101  호남선    25  E
# ...

# %%
df_name7_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name7_num
# Out:
#     도로명
# 0   호남선
# 1   호남선
# 2   호남선
# 3   호남선
# 4   호남선
# 5   호남선
# 6   호남선
# 7   호남선
# 8   호남선
# 9   호남선
# 10  호남선
# 11  호남선
# 12  호남선
# 13  호남선
# 14  호남선
# 15  호남선
# 16  호남선
# 17  호남선
# 18  호남선
# 19  호남선
# 20  호남선
# 21  호남선
# 22  호남선
# 23  호남선
# 24  호남선
# 25  호남선
# 26  호남선
# 27  호남선
# 28  호남선
# 29  호남선
# 30  호남선
# 31  호남선
# 32  호남선
# 33  호남선
# 34  호남선
# 35  호남선
# 36  호남선
# 37  호남선
# 38  호남선
# 39  호남선
# 40  호남선
# 41  호남선
# 42  호남선
# 43  호남선

# %%
df_name7_num.iloc[:] = '호남고속도로'
df_name7_num
# Out:
#        도로명
# 0   호남고속도로
# 1   호남고속도로
# 2   호남고속도로
# 3   호남고속도로
# 4   호남고속도로
# 5   호남고속도로
# 6   호남고속도로
# 7   호남고속도로
# 8   호남고속도로
# 9   호남고속도로
# 10  호남고속도로
# 11  호남고속도로
# 12  호남고속도로
# 13  호남고속도로
# 14  호남고속도로
# 15  호남고속도로
# 16  호남고속도로
# 17  호남고속도로
# 18  호남고속도로
# 19  호남고속도로
# 20  호남고속도로
# 21  호남고속도로
# 22  호남고속도로
# 23  호남고속도로
# 24  호남고속도로
# 25  호남고속도로
# 26  호남고속도로
# 27  호남고속도로
# 28  호남고속도로
# 29  호남고속도로
# 30  호남고속도로
# 31  호남고속도로
# 32  호남고속도로
# 33  호남고속도로
# 34  호남고속도로
# 35  호남고속도로
# 36  호남고속도로
# 37  호남고속도로
# 38  호남고속도로
# 39  호남고속도로
# 40  호남고속도로
# 41  호남고속도로
# 42  호남고속도로
# 43  호남고속도로

# %%
df_name7_num1 = df_name7.reset_index(drop = True)
df_name7_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0     71  0251VME00100  127.258056  35.094167   101  호남선    25  E
# 1     43  0251VME00200  127.008056  35.251944   101  호남선   251  E
# 2    553  0251VME00600  126.951389  35.215000   101  호남선    25  E
# 3    558  0251VME00700  126.901667  35.181111   101  호남선    25  E
# 4    566  0251VME00800  126.815278  35.243056   101  호남선    25  E
# 5    568  0251VME00900  126.808889  35.394722   101  호남선    25  E
# 6    520  0251VME01000  126.823056  35.552222   101  호남선    25  E
# 7    527  0251VME01200  127.057778  35.900000   101  호남선    25  E
# 8    523  0251VME01300  126.961389  35.702500   101  호남선    25  E
# 9    525  0251VME01400  127.052500  35.853611   101  호남선    25  E
# 10   531  0251VME01500  127.081667  35.934444   101  호남선    25  E
# 11  1336  0251VME01600  127.100339  35.954950   101  호남선    25  E
# 12  1340  0251VME01700  127.103044  36.034742   101  호남선    25  E
# ...

# %%
df_name7_num1['도로명'] = df_name7_num['도로명']
df_name7_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0     71  0251VME00100  127.258056  35.094167   101  호남고속도로    25  E
# 1     43  0251VME00200  127.008056  35.251944   101  호남고속도로   251  E
# 2    553  0251VME00600  126.951389  35.215000   101  호남고속도로    25  E
# 3    558  0251VME00700  126.901667  35.181111   101  호남고속도로    25  E
# 4    566  0251VME00800  126.815278  35.243056   101  호남고속도로    25  E
# 5    568  0251VME00900  126.808889  35.394722   101  호남고속도로    25  E
# 6    520  0251VME01000  126.823056  35.552222   101  호남고속도로    25  E
# 7    527  0251VME01200  127.057778  35.900000   101  호남고속도로    25  E
# 8    523  0251VME01300  126.961389  35.702500   101  호남고속도로    25  E
# 9    525  0251VME01400  127.052500  35.853611   101  호남고속도로    25  E
# 10   531  0251VME01500  127.081667  35.934444   101  호남고속도로    25  E
# 11  1336  0251VME01600  127.100339  35.954950   101  호남고속도로    25  E
# 12  1340  0251VME01700  127.103044  36.034742   101  호남고속도로    25  E
# ...

# %%
df_name8 = df[df['도로명'] == '서울외곽순환선']
df_name8
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 773  341  1000VME00100  127.123889  37.436667   101  서울외곽순환선   100  E
# 774  345  1000VME00200  127.138889  37.485278   101  서울외곽순환선   100  E
# 775  349  1000VME00250  127.177778  37.553056   101  서울외곽순환선   100  E
# 776  351  1000VME00300  127.157222  37.590833   101  서울외곽순환선   100  E
# 777  443  1000VME00400  126.767778  37.592500   101  서울외곽순환선   100  E
# 778  445  1000VME00500  126.752222  37.562500   101  서울외곽순환선   100  E
# 779  454  1000VME00800  126.763333  37.461111   101  서울외곽순환선   100  E
# 780  404  1000VME00880  126.834167  37.408333   101  서울외곽순환선   100  E
# 781  406  1000VME00900  126.851389  37.392778   101  서울외곽순환선   100  E
# 782  357  1000VME01000  127.025556  37.392778   101  서울외곽순환선   100  E
# 783  359  1000VME01050  127.053611  37.396111   101  서울외곽순환선   100  E
# 784  342  1000VMS00100  127.123889  37.436667   101  서울외곽순환선   100  S
# ...

# %%
df_name8_num = df_name8.reset_index(drop = True)
df_name8_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 0   341  1000VME00100  127.123889  37.436667   101  서울외곽순환선   100  E
# 1   345  1000VME00200  127.138889  37.485278   101  서울외곽순환선   100  E
# 2   349  1000VME00250  127.177778  37.553056   101  서울외곽순환선   100  E
# 3   351  1000VME00300  127.157222  37.590833   101  서울외곽순환선   100  E
# 4   443  1000VME00400  126.767778  37.592500   101  서울외곽순환선   100  E
# 5   445  1000VME00500  126.752222  37.562500   101  서울외곽순환선   100  E
# 6   454  1000VME00800  126.763333  37.461111   101  서울외곽순환선   100  E
# 7   404  1000VME00880  126.834167  37.408333   101  서울외곽순환선   100  E
# 8   406  1000VME00900  126.851389  37.392778   101  서울외곽순환선   100  E
# 9   357  1000VME01000  127.025556  37.392778   101  서울외곽순환선   100  E
# 10  359  1000VME01050  127.053611  37.396111   101  서울외곽순환선   100  E
# 11  342  1000VMS00100  127.123889  37.436667   101  서울외곽순환선   100  S
# 12  339  1000VMS00150  127.123056  37.420278   101  서울외곽순환선   100  S
# ...

# %%
df_name8_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name8_num
# Out:
#         도로명
# 0   서울외곽순환선
# 1   서울외곽순환선
# 2   서울외곽순환선
# 3   서울외곽순환선
# 4   서울외곽순환선
# 5   서울외곽순환선
# 6   서울외곽순환선
# 7   서울외곽순환선
# 8   서울외곽순환선
# 9   서울외곽순환선
# 10  서울외곽순환선
# 11  서울외곽순환선
# 12  서울외곽순환선
# 13  서울외곽순환선
# 14  서울외곽순환선
# 15  서울외곽순환선
# 16  서울외곽순환선
# 17  서울외곽순환선
# 18  서울외곽순환선
# 19  서울외곽순환선
# 20  서울외곽순환선
# 21  서울외곽순환선
# 22  서울외곽순환선
# 23  서울외곽순환선
# 24  서울외곽순환선
# 25  서울외곽순환선
# 26  서울외곽순환선
# 27  서울외곽순환선
# 28  서울외곽순환선
# 29  서울외곽순환선
# 30  서울외곽순환선
# 31  서울외곽순환선
# 32  서울외곽순환선
# 33  서울외곽순환선
# 34  서울외곽순환선
# 35  서울외곽순환선
# 36  서울외곽순환선
# 37  서울외곽순환선
# 38  서울외곽순환선

# %%
df_name8_num.iloc[:] = '수도권제1순환선'
df_name8_num
# Out:
#          도로명
# 0   수도권제1순환선
# 1   수도권제1순환선
# 2   수도권제1순환선
# 3   수도권제1순환선
# 4   수도권제1순환선
# 5   수도권제1순환선
# 6   수도권제1순환선
# 7   수도권제1순환선
# 8   수도권제1순환선
# 9   수도권제1순환선
# 10  수도권제1순환선
# 11  수도권제1순환선
# 12  수도권제1순환선
# 13  수도권제1순환선
# 14  수도권제1순환선
# 15  수도권제1순환선
# 16  수도권제1순환선
# 17  수도권제1순환선
# 18  수도권제1순환선
# 19  수도권제1순환선
# 20  수도권제1순환선
# 21  수도권제1순환선
# 22  수도권제1순환선
# 23  수도권제1순환선
# 24  수도권제1순환선
# 25  수도권제1순환선
# 26  수도권제1순환선
# 27  수도권제1순환선
# 28  수도권제1순환선
# 29  수도권제1순환선
# 30  수도권제1순환선
# 31  수도권제1순환선
# 32  수도권제1순환선
# 33  수도권제1순환선
# 34  수도권제1순환선
# 35  수도권제1순환선
# 36  수도권제1순환선
# 37  수도권제1순환선
# 38  수도권제1순환선

# %%
df_name8_num1 = df_name8.reset_index(drop = True)
df_name8_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 0   341  1000VME00100  127.123889  37.436667   101  서울외곽순환선   100  E
# 1   345  1000VME00200  127.138889  37.485278   101  서울외곽순환선   100  E
# 2   349  1000VME00250  127.177778  37.553056   101  서울외곽순환선   100  E
# 3   351  1000VME00300  127.157222  37.590833   101  서울외곽순환선   100  E
# 4   443  1000VME00400  126.767778  37.592500   101  서울외곽순환선   100  E
# 5   445  1000VME00500  126.752222  37.562500   101  서울외곽순환선   100  E
# 6   454  1000VME00800  126.763333  37.461111   101  서울외곽순환선   100  E
# 7   404  1000VME00880  126.834167  37.408333   101  서울외곽순환선   100  E
# 8   406  1000VME00900  126.851389  37.392778   101  서울외곽순환선   100  E
# 9   357  1000VME01000  127.025556  37.392778   101  서울외곽순환선   100  E
# 10  359  1000VME01050  127.053611  37.396111   101  서울외곽순환선   100  E
# 11  342  1000VMS00100  127.123889  37.436667   101  서울외곽순환선   100  S
# 12  339  1000VMS00150  127.123056  37.420278   101  서울외곽순환선   100  S
# ...

# %%
df_name8_num1['도로명'] = df_name8_num['도로명']
df_name8_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   341  1000VME00100  127.123889  37.436667   101  수도권제1순환선   100  E
# 1   345  1000VME00200  127.138889  37.485278   101  수도권제1순환선   100  E
# 2   349  1000VME00250  127.177778  37.553056   101  수도권제1순환선   100  E
# 3   351  1000VME00300  127.157222  37.590833   101  수도권제1순환선   100  E
# 4   443  1000VME00400  126.767778  37.592500   101  수도권제1순환선   100  E
# 5   445  1000VME00500  126.752222  37.562500   101  수도권제1순환선   100  E
# 6   454  1000VME00800  126.763333  37.461111   101  수도권제1순환선   100  E
# 7   404  1000VME00880  126.834167  37.408333   101  수도권제1순환선   100  E
# 8   406  1000VME00900  126.851389  37.392778   101  수도권제1순환선   100  E
# 9   357  1000VME01000  127.025556  37.392778   101  수도권제1순환선   100  E
# 10  359  1000VME01050  127.053611  37.396111   101  수도권제1순환선   100  E
# 11  342  1000VMS00100  127.123889  37.436667   101  수도권제1순환선   100  S
# ...

# %%
df_name9 = df[df['도로명'] == '당진대전선']
df_name9
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 459  1211  0301VME00100  126.623056  36.845278   101  당진대전선    30  E
# 460  1176  0301VME00300  126.768611  36.676111   101  당진대전선    30  E
# 461  1180  0301VME00400  126.849167  36.614444   101  당진대전선    30  E
# 462  1184  0301VME00500  126.943333  36.574722   101  당진대전선    30  E
# 463  1188  0301VME00600  127.042778  36.483056   101  당진대전선    30  E
# 464  1190  0301VME00700  127.105833  36.481944   101  당진대전선    30  E
# 465  1195  0301VME00800  127.161944  36.493333   101  당진대전선    30  E
# 466  1199  0301VME00900  127.264444  36.441111   101  당진대전선    30  E
# 467  1200  0301VME01000  127.308056  36.398333   101  당진대전선    30  E
# 468  1212  0301VMS00100  126.641389  36.828333   101  당진대전선    30  S
# 469  1215  0301VMS00200  126.666667  36.801111   101  당진대전선    30  S
# 470  1175  0301VMS00300  126.728889  36.733889   101  당진대전선    30  S
# 471  1179  0301VMS00400  126.805556  36.657222   101  당진대전선    30  S
# ...

# %%
df_name9_num = df_name9.reset_index(drop = True)
df_name9_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1211  0301VME00100  126.623056  36.845278   101  당진대전선    30  E
# 1   1176  0301VME00300  126.768611  36.676111   101  당진대전선    30  E
# 2   1180  0301VME00400  126.849167  36.614444   101  당진대전선    30  E
# 3   1184  0301VME00500  126.943333  36.574722   101  당진대전선    30  E
# 4   1188  0301VME00600  127.042778  36.483056   101  당진대전선    30  E
# 5   1190  0301VME00700  127.105833  36.481944   101  당진대전선    30  E
# 6   1195  0301VME00800  127.161944  36.493333   101  당진대전선    30  E
# 7   1199  0301VME00900  127.264444  36.441111   101  당진대전선    30  E
# 8   1200  0301VME01000  127.308056  36.398333   101  당진대전선    30  E
# 9   1212  0301VMS00100  126.641389  36.828333   101  당진대전선    30  S
# 10  1215  0301VMS00200  126.666667  36.801111   101  당진대전선    30  S
# 11  1175  0301VMS00300  126.728889  36.733889   101  당진대전선    30  S
# 12  1179  0301VMS00400  126.805556  36.657222   101  당진대전선    30  S
# ...

# %%
df_name9_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name9_num
# Out:
#       도로명
# 0   당진대전선
# 1   당진대전선
# 2   당진대전선
# 3   당진대전선
# 4   당진대전선
# 5   당진대전선
# 6   당진대전선
# 7   당진대전선
# 8   당진대전선
# 9   당진대전선
# 10  당진대전선
# 11  당진대전선
# 12  당진대전선
# 13  당진대전선
# 14  당진대전선
# 15  당진대전선
# 16  당진대전선
# 17  당진대전선
# 18  당진대전선
# 19  당진대전선
# 20  당진대전선
# 21  당진대전선
# 22  당진대전선
# 23  당진대전선
# 24  당진대전선
# 25  당진대전선
# 26  당진대전선
# 27  당진대전선
# 28  당진대전선
# 29  당진대전선
# 30  당진대전선
# 31  당진대전선
# 32  당진대전선

# %%
df_name9_num.iloc[:] = '서산영덕고속도로'
df_name9_num
# Out:
#          도로명
# 0   서산영덕고속도로
# 1   서산영덕고속도로
# 2   서산영덕고속도로
# 3   서산영덕고속도로
# 4   서산영덕고속도로
# 5   서산영덕고속도로
# 6   서산영덕고속도로
# 7   서산영덕고속도로
# 8   서산영덕고속도로
# 9   서산영덕고속도로
# 10  서산영덕고속도로
# 11  서산영덕고속도로
# 12  서산영덕고속도로
# 13  서산영덕고속도로
# 14  서산영덕고속도로
# 15  서산영덕고속도로
# 16  서산영덕고속도로
# 17  서산영덕고속도로
# 18  서산영덕고속도로
# 19  서산영덕고속도로
# 20  서산영덕고속도로
# 21  서산영덕고속도로
# 22  서산영덕고속도로
# 23  서산영덕고속도로
# 24  서산영덕고속도로
# 25  서산영덕고속도로
# 26  서산영덕고속도로
# 27  서산영덕고속도로
# 28  서산영덕고속도로
# 29  서산영덕고속도로
# 30  서산영덕고속도로
# 31  서산영덕고속도로
# 32  서산영덕고속도로

# %%
df_name9_num1 = df_name9.reset_index(drop = True)
df_name9_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1211  0301VME00100  126.623056  36.845278   101  당진대전선    30  E
# 1   1176  0301VME00300  126.768611  36.676111   101  당진대전선    30  E
# 2   1180  0301VME00400  126.849167  36.614444   101  당진대전선    30  E
# 3   1184  0301VME00500  126.943333  36.574722   101  당진대전선    30  E
# 4   1188  0301VME00600  127.042778  36.483056   101  당진대전선    30  E
# 5   1190  0301VME00700  127.105833  36.481944   101  당진대전선    30  E
# 6   1195  0301VME00800  127.161944  36.493333   101  당진대전선    30  E
# 7   1199  0301VME00900  127.264444  36.441111   101  당진대전선    30  E
# 8   1200  0301VME01000  127.308056  36.398333   101  당진대전선    30  E
# 9   1212  0301VMS00100  126.641389  36.828333   101  당진대전선    30  S
# 10  1215  0301VMS00200  126.666667  36.801111   101  당진대전선    30  S
# 11  1175  0301VMS00300  126.728889  36.733889   101  당진대전선    30  S
# 12  1179  0301VMS00400  126.805556  36.657222   101  당진대전선    30  S
# ...

# %%
df_name9_num1['도로명'] = df_name9_num['도로명']
df_name9_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1211  0301VME00100  126.623056  36.845278   101  서산영덕고속도로    30  E
# 1   1176  0301VME00300  126.768611  36.676111   101  서산영덕고속도로    30  E
# 2   1180  0301VME00400  126.849167  36.614444   101  서산영덕고속도로    30  E
# 3   1184  0301VME00500  126.943333  36.574722   101  서산영덕고속도로    30  E
# 4   1188  0301VME00600  127.042778  36.483056   101  서산영덕고속도로    30  E
# 5   1190  0301VME00700  127.105833  36.481944   101  서산영덕고속도로    30  E
# 6   1195  0301VME00800  127.161944  36.493333   101  서산영덕고속도로    30  E
# 7   1199  0301VME00900  127.264444  36.441111   101  서산영덕고속도로    30  E
# 8   1200  0301VME01000  127.308056  36.398333   101  서산영덕고속도로    30  E
# 9   1212  0301VMS00100  126.641389  36.828333   101  서산영덕고속도로    30  S
# 10  1215  0301VMS00200  126.666667  36.801111   101  서산영덕고속도로    30  S
# 11  1175  0301VMS00300  126.728889  36.733889   101  서산영덕고속도로    30  S
# ...

# %%
df_name10 = df[df['도로명'] == '중앙선']
df_name10
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 688   134  0550VME00100  128.980000  35.233889   101  중앙선    55  E
# 689   135  0550VME00300  128.983611  35.256111   101  중앙선    55  E
# 690   231  0550VME00400  128.527279  35.915278   101  중앙선    55  E
# 691   235  0550VME00500  128.535833  36.066111   101  중앙선    55  E
# 692   291  0550VME00600  128.545833  36.831667   101  중앙선    55  E
# 693    10  0550VME00800  128.292778  36.989722   101  중앙선    55  E
# 694    12  0550VME00900  128.150278  37.114444   101  중앙선    55  E
# 695    14  0550VME01000  128.096944  37.214722   101  중앙선    55  E
# 696    15  0550VME01100  128.044167  37.254167   101  중앙선    55  E
# 697    16  0550VME01300  127.971389  37.306389   101  중앙선    55  E
# 698  1170  0550VME01400  127.691667  36.999444   101  중앙선    55  E
# 699  1173  0550VMS00200  127.768611  37.785278   101  중앙선    55  S
# 700   136  0550VMS00300  128.983611  35.256111   101  중앙선    55  S
# ...

# %%
df_name10_num = df_name10.reset_index(drop = True)
df_name10_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    134  0550VME00100  128.980000  35.233889   101  중앙선    55  E
# 1    135  0550VME00300  128.983611  35.256111   101  중앙선    55  E
# 2    231  0550VME00400  128.527279  35.915278   101  중앙선    55  E
# 3    235  0550VME00500  128.535833  36.066111   101  중앙선    55  E
# 4    291  0550VME00600  128.545833  36.831667   101  중앙선    55  E
# 5     10  0550VME00800  128.292778  36.989722   101  중앙선    55  E
# 6     12  0550VME00900  128.150278  37.114444   101  중앙선    55  E
# 7     14  0550VME01000  128.096944  37.214722   101  중앙선    55  E
# 8     15  0550VME01100  128.044167  37.254167   101  중앙선    55  E
# 9     16  0550VME01300  127.971389  37.306389   101  중앙선    55  E
# 10  1170  0550VME01400  127.691667  36.999444   101  중앙선    55  E
# 11  1173  0550VMS00200  127.768611  37.785278   101  중앙선    55  S
# 12   136  0550VMS00300  128.983611  35.256111   101  중앙선    55  S
# ...

# %%
df_name10_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name10_num
# Out:
#     도로명
# 0   중앙선
# 1   중앙선
# 2   중앙선
# 3   중앙선
# 4   중앙선
# 5   중앙선
# 6   중앙선
# 7   중앙선
# 8   중앙선
# 9   중앙선
# 10  중앙선
# 11  중앙선
# 12  중앙선
# 13  중앙선
# 14  중앙선
# 15  중앙선
# 16  중앙선
# 17  중앙선
# 18  중앙선
# 19  중앙선
# 20  중앙선
# 21  중앙선
# 22  중앙선
# 23  중앙선
# 24  중앙선
# 25  중앙선
# 26  중앙선
# 27  중앙선
# 28  중앙선

# %%
df_name10_num.iloc[:] = '중앙고속도로'
df_name10_num
# Out:
#        도로명
# 0   중앙고속도로
# 1   중앙고속도로
# 2   중앙고속도로
# 3   중앙고속도로
# 4   중앙고속도로
# 5   중앙고속도로
# 6   중앙고속도로
# 7   중앙고속도로
# 8   중앙고속도로
# 9   중앙고속도로
# 10  중앙고속도로
# 11  중앙고속도로
# 12  중앙고속도로
# 13  중앙고속도로
# 14  중앙고속도로
# 15  중앙고속도로
# 16  중앙고속도로
# 17  중앙고속도로
# 18  중앙고속도로
# 19  중앙고속도로
# 20  중앙고속도로
# 21  중앙고속도로
# 22  중앙고속도로
# 23  중앙고속도로
# 24  중앙고속도로
# 25  중앙고속도로
# 26  중앙고속도로
# 27  중앙고속도로
# 28  중앙고속도로

# %%
df_name10_num1 = df_name10.reset_index(drop = True)
df_name10_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    134  0550VME00100  128.980000  35.233889   101  중앙선    55  E
# 1    135  0550VME00300  128.983611  35.256111   101  중앙선    55  E
# 2    231  0550VME00400  128.527279  35.915278   101  중앙선    55  E
# 3    235  0550VME00500  128.535833  36.066111   101  중앙선    55  E
# 4    291  0550VME00600  128.545833  36.831667   101  중앙선    55  E
# 5     10  0550VME00800  128.292778  36.989722   101  중앙선    55  E
# 6     12  0550VME00900  128.150278  37.114444   101  중앙선    55  E
# 7     14  0550VME01000  128.096944  37.214722   101  중앙선    55  E
# 8     15  0550VME01100  128.044167  37.254167   101  중앙선    55  E
# 9     16  0550VME01300  127.971389  37.306389   101  중앙선    55  E
# 10  1170  0550VME01400  127.691667  36.999444   101  중앙선    55  E
# 11  1173  0550VMS00200  127.768611  37.785278   101  중앙선    55  S
# 12   136  0550VMS00300  128.983611  35.256111   101  중앙선    55  S
# ...

# %%
df_name10_num1['도로명'] = df_name10_num['도로명']
df_name10_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0    134  0550VME00100  128.980000  35.233889   101  중앙고속도로    55  E
# 1    135  0550VME00300  128.983611  35.256111   101  중앙고속도로    55  E
# 2    231  0550VME00400  128.527279  35.915278   101  중앙고속도로    55  E
# 3    235  0550VME00500  128.535833  36.066111   101  중앙고속도로    55  E
# 4    291  0550VME00600  128.545833  36.831667   101  중앙고속도로    55  E
# 5     10  0550VME00800  128.292778  36.989722   101  중앙고속도로    55  E
# 6     12  0550VME00900  128.150278  37.114444   101  중앙고속도로    55  E
# 7     14  0550VME01000  128.096944  37.214722   101  중앙고속도로    55  E
# 8     15  0550VME01100  128.044167  37.254167   101  중앙고속도로    55  E
# 9     16  0550VME01300  127.971389  37.306389   101  중앙고속도로    55  E
# 10  1170  0550VME01400  127.691667  36.999444   101  중앙고속도로    55  E
# 11  1173  0550VMS00200  127.768611  37.785278   101  중앙고속도로    55  S
# 12   136  0550VMS00300  128.983611  35.256111   101  중앙고속도로    55  S
# ...

# %%
df_name11 = df[df['도로명'] == '청원상주선']
df_name11
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 432  1244  0300VME00100  127.476389  36.546111   101  청원상주선    30  E
# 433  1248  0300VME00200  127.593056  36.500278   101  청원상주선    30  E
# 434  1252  0300VME00300  127.679167  36.470278   101  청원상주선    30  E
# 435  1256  0300VME00400  127.756389  36.451944   101  청원상주선    30  E
# 436  1260  0300VME00500  127.936111  36.439444   101  청원상주선    30  E
# 437  1264  0300VME00600  128.120556  36.373333   101  청원상주선    30  E
# 438  1268  0300VME00700  128.203889  36.362778   101  청원상주선    30  E
# 439  1269  0300VME00800  128.216667  36.368056   101  청원상주선    30  E
# 440  1243  0300VMS00100  127.470833  36.551667   101  청원상주선    30  S
# 441  1247  0300VMS00200  127.537500  36.517222   101  청원상주선    30  S
# 442  1251  0300VMS00300  127.650556  36.473889   101  청원상주선    30  S
# 443  1255  0300VMS00400  127.751944  36.452778   101  청원상주선    30  S
# 444  1259  0300VMS00500  127.824722  36.452500   101  청원상주선    30  S
# ...

# %%
df_name11_num = df_name11.reset_index(drop = True)
df_name11_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1244  0300VME00100  127.476389  36.546111   101  청원상주선    30  E
# 1   1248  0300VME00200  127.593056  36.500278   101  청원상주선    30  E
# 2   1252  0300VME00300  127.679167  36.470278   101  청원상주선    30  E
# 3   1256  0300VME00400  127.756389  36.451944   101  청원상주선    30  E
# 4   1260  0300VME00500  127.936111  36.439444   101  청원상주선    30  E
# 5   1264  0300VME00600  128.120556  36.373333   101  청원상주선    30  E
# 6   1268  0300VME00700  128.203889  36.362778   101  청원상주선    30  E
# 7   1269  0300VME00800  128.216667  36.368056   101  청원상주선    30  E
# 8   1243  0300VMS00100  127.470833  36.551667   101  청원상주선    30  S
# 9   1247  0300VMS00200  127.537500  36.517222   101  청원상주선    30  S
# 10  1251  0300VMS00300  127.650556  36.473889   101  청원상주선    30  S
# 11  1255  0300VMS00400  127.751944  36.452778   101  청원상주선    30  S
# 12  1259  0300VMS00500  127.824722  36.452500   101  청원상주선    30  S
# ...

# %%
df_name11_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name11_num
# Out:
#       도로명
# 0   청원상주선
# 1   청원상주선
# 2   청원상주선
# 3   청원상주선
# 4   청원상주선
# 5   청원상주선
# 6   청원상주선
# 7   청원상주선
# 8   청원상주선
# 9   청원상주선
# 10  청원상주선
# 11  청원상주선
# 12  청원상주선
# 13  청원상주선
# 14  청원상주선
# 15  청원상주선
# 16  청원상주선
# 17  청원상주선
# 18  청원상주선
# 19  청원상주선
# 20  청원상주선
# 21  청원상주선
# 22  청원상주선
# 23  청원상주선
# 24  청원상주선
# 25  청원상주선
# 26  청원상주선

# %%
df_name11_num.iloc[:] = '서산영덕고속도로'
df_name11_num
# Out:
#          도로명
# 0   서산영덕고속도로
# 1   서산영덕고속도로
# 2   서산영덕고속도로
# 3   서산영덕고속도로
# 4   서산영덕고속도로
# 5   서산영덕고속도로
# 6   서산영덕고속도로
# 7   서산영덕고속도로
# 8   서산영덕고속도로
# 9   서산영덕고속도로
# 10  서산영덕고속도로
# 11  서산영덕고속도로
# 12  서산영덕고속도로
# 13  서산영덕고속도로
# 14  서산영덕고속도로
# 15  서산영덕고속도로
# 16  서산영덕고속도로
# 17  서산영덕고속도로
# 18  서산영덕고속도로
# 19  서산영덕고속도로
# 20  서산영덕고속도로
# 21  서산영덕고속도로
# 22  서산영덕고속도로
# 23  서산영덕고속도로
# 24  서산영덕고속도로
# 25  서산영덕고속도로
# 26  서산영덕고속도로

# %%
df_name11_num1 = df_name11.reset_index(drop = True)
df_name11_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1244  0300VME00100  127.476389  36.546111   101  청원상주선    30  E
# 1   1248  0300VME00200  127.593056  36.500278   101  청원상주선    30  E
# 2   1252  0300VME00300  127.679167  36.470278   101  청원상주선    30  E
# 3   1256  0300VME00400  127.756389  36.451944   101  청원상주선    30  E
# 4   1260  0300VME00500  127.936111  36.439444   101  청원상주선    30  E
# 5   1264  0300VME00600  128.120556  36.373333   101  청원상주선    30  E
# 6   1268  0300VME00700  128.203889  36.362778   101  청원상주선    30  E
# 7   1269  0300VME00800  128.216667  36.368056   101  청원상주선    30  E
# 8   1243  0300VMS00100  127.470833  36.551667   101  청원상주선    30  S
# 9   1247  0300VMS00200  127.537500  36.517222   101  청원상주선    30  S
# 10  1251  0300VMS00300  127.650556  36.473889   101  청원상주선    30  S
# 11  1255  0300VMS00400  127.751944  36.452778   101  청원상주선    30  S
# 12  1259  0300VMS00500  127.824722  36.452500   101  청원상주선    30  S
# ...

# %%
df_name11_num1['도로명'] = df_name11_num['도로명']
df_name11_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1244  0300VME00100  127.476389  36.546111   101  서산영덕고속도로    30  E
# 1   1248  0300VME00200  127.593056  36.500278   101  서산영덕고속도로    30  E
# 2   1252  0300VME00300  127.679167  36.470278   101  서산영덕고속도로    30  E
# 3   1256  0300VME00400  127.756389  36.451944   101  서산영덕고속도로    30  E
# 4   1260  0300VME00500  127.936111  36.439444   101  서산영덕고속도로    30  E
# 5   1264  0300VME00600  128.120556  36.373333   101  서산영덕고속도로    30  E
# 6   1268  0300VME00700  128.203889  36.362778   101  서산영덕고속도로    30  E
# 7   1269  0300VME00800  128.216667  36.368056   101  서산영덕고속도로    30  E
# 8   1243  0300VMS00100  127.470833  36.551667   101  서산영덕고속도로    30  S
# 9   1247  0300VMS00200  127.537500  36.517222   101  서산영덕고속도로    30  S
# 10  1251  0300VMS00300  127.650556  36.473889   101  서산영덕고속도로    30  S
# 11  1255  0300VMS00400  127.751944  36.452778   101  서산영덕고속도로    30  S
# ...

# %%
df_name12 = df[df['도로명'] == '평택제천선']
df_name12
# Out:
#        순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 231  1116  010411VMS11202  126.931667  37.048333   101  평택제천선    40  S
# 339   395    0170VMS00100  127.001944  37.024167   101  평택제천선    40  S
# 552   472    0400VME00200  127.083611  37.028889   101  평택제천선    40  E
# 553  1146    0400VME00300  127.424167  36.949722   101  평택제천선    40  E
# 554   474    0400VME00400  127.192500  36.952778   101  평택제천선    40  E
# 555  1149    0400VME00500  127.288889  36.968333   101  평택제천선    40  E
# 556  1151    0400VME00600  127.449444  36.925833   101  평택제천선    40  E
# 557  1155    0400VME00700  127.516944  36.944444   101  평택제천선    40  E
# 558  1158    0400VME00800  127.580556  36.963611   101  평택제천선    40  E
# 559  1161    0400VME00900  127.639444  36.998333   101  평택제천선    40  E
# 560   471    0400VMS00100  126.952222  37.041667   101  평택제천선    40  S
# 561   473    0400VMS00200  127.154722  37.035556   101  평택제천선    40  S
# ...

# %%
df_name12_num = df_name12.reset_index(drop = True)
df_name12_num
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1116  010411VMS11202  126.931667  37.048333   101  평택제천선    40  S
# 1    395    0170VMS00100  127.001944  37.024167   101  평택제천선    40  S
# 2    472    0400VME00200  127.083611  37.028889   101  평택제천선    40  E
# 3   1146    0400VME00300  127.424167  36.949722   101  평택제천선    40  E
# 4    474    0400VME00400  127.192500  36.952778   101  평택제천선    40  E
# 5   1149    0400VME00500  127.288889  36.968333   101  평택제천선    40  E
# 6   1151    0400VME00600  127.449444  36.925833   101  평택제천선    40  E
# 7   1155    0400VME00700  127.516944  36.944444   101  평택제천선    40  E
# 8   1158    0400VME00800  127.580556  36.963611   101  평택제천선    40  E
# 9   1161    0400VME00900  127.639444  36.998333   101  평택제천선    40  E
# 10   471    0400VMS00100  126.952222  37.041667   101  평택제천선    40  S
# 11   473    0400VMS00200  127.154722  37.035556   101  평택제천선    40  S
# ...

# %%
df_name12_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name12_num
# Out:
#       도로명
# 0   평택제천선
# 1   평택제천선
# 2   평택제천선
# 3   평택제천선
# 4   평택제천선
# 5   평택제천선
# 6   평택제천선
# 7   평택제천선
# 8   평택제천선
# 9   평택제천선
# 10  평택제천선
# 11  평택제천선
# 12  평택제천선
# 13  평택제천선
# 14  평택제천선
# 15  평택제천선
# 16  평택제천선
# 17  평택제천선
# 18  평택제천선
# 19  평택제천선
# 20  평택제천선
# 21  평택제천선
# 22  평택제천선
# 23  평택제천선
# 24  평택제천선

# %%
df_name12_num.iloc[:] = '평택제천고속도로'
df_name12_num
# Out:
#          도로명
# 0   평택제천고속도로
# 1   평택제천고속도로
# 2   평택제천고속도로
# 3   평택제천고속도로
# 4   평택제천고속도로
# 5   평택제천고속도로
# 6   평택제천고속도로
# 7   평택제천고속도로
# 8   평택제천고속도로
# 9   평택제천고속도로
# 10  평택제천고속도로
# 11  평택제천고속도로
# 12  평택제천고속도로
# 13  평택제천고속도로
# 14  평택제천고속도로
# 15  평택제천고속도로
# 16  평택제천고속도로
# 17  평택제천고속도로
# 18  평택제천고속도로
# 19  평택제천고속도로
# 20  평택제천고속도로
# 21  평택제천고속도로
# 22  평택제천고속도로
# 23  평택제천고속도로
# 24  평택제천고속도로

# %%
df_name12_num1 = df_name12.reset_index(drop = True)
df_name12_num1
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1116  010411VMS11202  126.931667  37.048333   101  평택제천선    40  S
# 1    395    0170VMS00100  127.001944  37.024167   101  평택제천선    40  S
# 2    472    0400VME00200  127.083611  37.028889   101  평택제천선    40  E
# 3   1146    0400VME00300  127.424167  36.949722   101  평택제천선    40  E
# 4    474    0400VME00400  127.192500  36.952778   101  평택제천선    40  E
# 5   1149    0400VME00500  127.288889  36.968333   101  평택제천선    40  E
# 6   1151    0400VME00600  127.449444  36.925833   101  평택제천선    40  E
# 7   1155    0400VME00700  127.516944  36.944444   101  평택제천선    40  E
# 8   1158    0400VME00800  127.580556  36.963611   101  평택제천선    40  E
# 9   1161    0400VME00900  127.639444  36.998333   101  평택제천선    40  E
# 10   471    0400VMS00100  126.952222  37.041667   101  평택제천선    40  S
# 11   473    0400VMS00200  127.154722  37.035556   101  평택제천선    40  S
# ...

# %%
df_name12_num1['도로명'] = df_name12_num['도로명']
df_name12_num1
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1116  010411VMS11202  126.931667  37.048333   101  평택제천고속도로    40  S
# 1    395    0170VMS00100  127.001944  37.024167   101  평택제천고속도로    40  S
# 2    472    0400VME00200  127.083611  37.028889   101  평택제천고속도로    40  E
# 3   1146    0400VME00300  127.424167  36.949722   101  평택제천고속도로    40  E
# 4    474    0400VME00400  127.192500  36.952778   101  평택제천고속도로    40  E
# 5   1149    0400VME00500  127.288889  36.968333   101  평택제천고속도로    40  E
# 6   1151    0400VME00600  127.449444  36.925833   101  평택제천고속도로    40  E
# 7   1155    0400VME00700  127.516944  36.944444   101  평택제천고속도로    40  E
# 8   1158    0400VME00800  127.580556  36.963611   101  평택제천고속도로    40  E
# 9   1161    0400VME00900  127.639444  36.998333   101  평택제천고속도로    40  E
# 10   471    0400VMS00100  126.952222  37.041667   101  평택제천고속도로    40  S
# 11   473    0400VMS00200  127.154722  37.035556   101  평택제천고속도로    40  S
# ...

# %%
df_name13 = df[df['도로명'] == '익산포항선']
df_name13
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 346   293  0200VME00100  128.809722  35.956389   101  익산포항선    20  E
# 347   294  0200VME00200  128.905833  36.030833   101  익산포항선    20  E
# 348   292  0200VMS00100  128.694167  35.941111   101  익산포항선    20  S
# 349   295  0200VMS00200  128.950000  36.054444   101  익산포항선    20  S
# 350   297  0200VMX00100  129.306667  36.036389   101  익산포항선    20  X
# 351   296  0200VMX00200  129.339444  36.056667   101  익산포항선    20  X
# 352  1331  0201VME00100  127.126667  35.910000   101  익산포항선    20  E
# 353  1330  0201VME00150  127.159869  35.893692   101  익산포항선    20  E
# 354   533  0201VME00200  127.204722  35.868889   101  익산포항선    20  E
# 355   538  0201VME00300  127.406667  35.771667   101  익산포항선    20  E
# 356   542  0201VME00400  127.533889  35.738889   101  익산포항선    20  E
# 357  1332  0201VMS00100  127.126389  35.918611   101  익산포항선    20  S
# 358  1335  0201VMS00150  127.164444  35.883392   101  익산포항선    20  S
# ...

# %%
df_name13_num = df_name13.reset_index(drop = True)
df_name13_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    293  0200VME00100  128.809722  35.956389   101  익산포항선    20  E
# 1    294  0200VME00200  128.905833  36.030833   101  익산포항선    20  E
# 2    292  0200VMS00100  128.694167  35.941111   101  익산포항선    20  S
# 3    295  0200VMS00200  128.950000  36.054444   101  익산포항선    20  S
# 4    297  0200VMX00100  129.306667  36.036389   101  익산포항선    20  X
# 5    296  0200VMX00200  129.339444  36.056667   101  익산포항선    20  X
# 6   1331  0201VME00100  127.126667  35.910000   101  익산포항선    20  E
# 7   1330  0201VME00150  127.159869  35.893692   101  익산포항선    20  E
# 8    533  0201VME00200  127.204722  35.868889   101  익산포항선    20  E
# 9    538  0201VME00300  127.406667  35.771667   101  익산포항선    20  E
# 10   542  0201VME00400  127.533889  35.738889   101  익산포항선    20  E
# 11  1332  0201VMS00100  127.126389  35.918611   101  익산포항선    20  S
# 12  1335  0201VMS00150  127.164444  35.883392   101  익산포항선    20  S
# ...

# %%
df_name13_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name13_num
# Out:
#       도로명
# 0   익산포항선
# 1   익산포항선
# 2   익산포항선
# 3   익산포항선
# 4   익산포항선
# 5   익산포항선
# 6   익산포항선
# 7   익산포항선
# 8   익산포항선
# 9   익산포항선
# 10  익산포항선
# 11  익산포항선
# 12  익산포항선
# 13  익산포항선
# 14  익산포항선
# 15  익산포항선
# 16  익산포항선
# 17  익산포항선
# 18  익산포항선
# 19  익산포항선
# 20  익산포항선
# 21  익산포항선
# 22  익산포항선

# %%
df_name13_num.iloc[:] = '새만금포항고속도로'
df_name13_num
# Out:
#           도로명
# 0   새만금포항고속도로
# 1   새만금포항고속도로
# 2   새만금포항고속도로
# 3   새만금포항고속도로
# 4   새만금포항고속도로
# 5   새만금포항고속도로
# 6   새만금포항고속도로
# 7   새만금포항고속도로
# 8   새만금포항고속도로
# 9   새만금포항고속도로
# 10  새만금포항고속도로
# 11  새만금포항고속도로
# 12  새만금포항고속도로
# 13  새만금포항고속도로
# 14  새만금포항고속도로
# 15  새만금포항고속도로
# 16  새만금포항고속도로
# 17  새만금포항고속도로
# 18  새만금포항고속도로
# 19  새만금포항고속도로
# 20  새만금포항고속도로
# 21  새만금포항고속도로
# 22  새만금포항고속도로

# %%
df_name13_num1 = df_name13.reset_index(drop = True)
df_name13_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    293  0200VME00100  128.809722  35.956389   101  익산포항선    20  E
# 1    294  0200VME00200  128.905833  36.030833   101  익산포항선    20  E
# 2    292  0200VMS00100  128.694167  35.941111   101  익산포항선    20  S
# 3    295  0200VMS00200  128.950000  36.054444   101  익산포항선    20  S
# 4    297  0200VMX00100  129.306667  36.036389   101  익산포항선    20  X
# 5    296  0200VMX00200  129.339444  36.056667   101  익산포항선    20  X
# 6   1331  0201VME00100  127.126667  35.910000   101  익산포항선    20  E
# 7   1330  0201VME00150  127.159869  35.893692   101  익산포항선    20  E
# 8    533  0201VME00200  127.204722  35.868889   101  익산포항선    20  E
# 9    538  0201VME00300  127.406667  35.771667   101  익산포항선    20  E
# 10   542  0201VME00400  127.533889  35.738889   101  익산포항선    20  E
# 11  1332  0201VMS00100  127.126389  35.918611   101  익산포항선    20  S
# 12  1335  0201VMS00150  127.164444  35.883392   101  익산포항선    20  S
# ...

# %%
df_name13_num1['도로명'] = df_name13_num['도로명']
df_name13_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급        도로명  노선번호 방향
# 0    293  0200VME00100  128.809722  35.956389   101  새만금포항고속도로    20  E
# 1    294  0200VME00200  128.905833  36.030833   101  새만금포항고속도로    20  E
# 2    292  0200VMS00100  128.694167  35.941111   101  새만금포항고속도로    20  S
# 3    295  0200VMS00200  128.950000  36.054444   101  새만금포항고속도로    20  S
# 4    297  0200VMX00100  129.306667  36.036389   101  새만금포항고속도로    20  X
# 5    296  0200VMX00200  129.339444  36.056667   101  새만금포항고속도로    20  X
# 6   1331  0201VME00100  127.126667  35.910000   101  새만금포항고속도로    20  E
# 7   1330  0201VME00150  127.159869  35.893692   101  새만금포항고속도로    20  E
# 8    533  0201VME00200  127.204722  35.868889   101  새만금포항고속도로    20  E
# 9    538  0201VME00300  127.406667  35.771667   101  새만금포항고속도로    20  E
# 10   542  0201VME00400  127.533889  35.738889   101  새만금포항고속도로    20  E
# 11  1332  0201VMS00100  127.126389  35.918611   101  새만금포항고속도로    20  S
# ...

# %%
df_name14 = df[df['도로명'] == '무안광주선']
df_name14
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 250  76  0121VME00100  126.447500  35.016389   101  무안광주선    12  E
# 251  78  0121VME00200  126.519444  35.040000   101  무안광주선    12  E
# 252  82  0121VME00300  126.558056  35.058889   101  무안광주선    12  E
# 253  86  0121VME00400  126.656111  35.081667   101  무안광주선    12  E
# 254  77  0121VMS00100  126.478056  35.027222   101  무안광주선    12  S
# 255  79  0121VMS00200  126.522500  35.040556   101  무안광주선    12  S
# 256  83  0121VMS00300  126.586667  35.066389   101  무안광주선    12  S
# 257  85  0121VMS00400  126.631389  35.076111   101  무안광주선    12  S
# 258  89  0121VMS00500  126.728056  35.110278   101  무안광주선    12  S
# 259  91  0121VMS00600  126.751389  35.137500   101  무안광주선    12  S
# 260  73  0121VMX00100  126.389444  34.999722   101  무안광주선    12  X
# 261  93  0121VMX00200  126.778333  35.136667   101  무안광주선    12  X
# 262  75  0121VMX00300  126.446944  35.006111   101  무안광주선    12  X
# ...

# %%
df_name14_num = df_name14.reset_index(drop = True)
df_name14_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   76  0121VME00100  126.447500  35.016389   101  무안광주선    12  E
# 1   78  0121VME00200  126.519444  35.040000   101  무안광주선    12  E
# 2   82  0121VME00300  126.558056  35.058889   101  무안광주선    12  E
# 3   86  0121VME00400  126.656111  35.081667   101  무안광주선    12  E
# 4   77  0121VMS00100  126.478056  35.027222   101  무안광주선    12  S
# 5   79  0121VMS00200  126.522500  35.040556   101  무안광주선    12  S
# 6   83  0121VMS00300  126.586667  35.066389   101  무안광주선    12  S
# 7   85  0121VMS00400  126.631389  35.076111   101  무안광주선    12  S
# 8   89  0121VMS00500  126.728056  35.110278   101  무안광주선    12  S
# 9   91  0121VMS00600  126.751389  35.137500   101  무안광주선    12  S
# 10  73  0121VMX00100  126.389444  34.999722   101  무안광주선    12  X
# 11  93  0121VMX00200  126.778333  35.136667   101  무안광주선    12  X
# 12  75  0121VMX00300  126.446944  35.006111   101  무안광주선    12  X
# ...

# %%
df_name14_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name14_num
# Out:
#       도로명
# 0   무안광주선
# 1   무안광주선
# 2   무안광주선
# 3   무안광주선
# 4   무안광주선
# 5   무안광주선
# 6   무안광주선
# 7   무안광주선
# 8   무안광주선
# 9   무안광주선
# 10  무안광주선
# 11  무안광주선
# 12  무안광주선
# 13  무안광주선
# 14  무안광주선
# 15  무안광주선
# 16  무안광주선
# 17  무안광주선
# 18  무안광주선
# 19  무안광주선
# 20  무안광주선

# %%
df_name14_num.iloc[:] = '무안광주고속도로'
df_name14_num
# Out:
#          도로명
# 0   무안광주고속도로
# 1   무안광주고속도로
# 2   무안광주고속도로
# 3   무안광주고속도로
# 4   무안광주고속도로
# 5   무안광주고속도로
# 6   무안광주고속도로
# 7   무안광주고속도로
# 8   무안광주고속도로
# 9   무안광주고속도로
# 10  무안광주고속도로
# 11  무안광주고속도로
# 12  무안광주고속도로
# 13  무안광주고속도로
# 14  무안광주고속도로
# 15  무안광주고속도로
# 16  무안광주고속도로
# 17  무안광주고속도로
# 18  무안광주고속도로
# 19  무안광주고속도로
# 20  무안광주고속도로

# %%
df_name14_num1 = df_name14.reset_index(drop = True)
df_name14_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   76  0121VME00100  126.447500  35.016389   101  무안광주선    12  E
# 1   78  0121VME00200  126.519444  35.040000   101  무안광주선    12  E
# 2   82  0121VME00300  126.558056  35.058889   101  무안광주선    12  E
# 3   86  0121VME00400  126.656111  35.081667   101  무안광주선    12  E
# 4   77  0121VMS00100  126.478056  35.027222   101  무안광주선    12  S
# 5   79  0121VMS00200  126.522500  35.040556   101  무안광주선    12  S
# 6   83  0121VMS00300  126.586667  35.066389   101  무안광주선    12  S
# 7   85  0121VMS00400  126.631389  35.076111   101  무안광주선    12  S
# 8   89  0121VMS00500  126.728056  35.110278   101  무안광주선    12  S
# 9   91  0121VMS00600  126.751389  35.137500   101  무안광주선    12  S
# 10  73  0121VMX00100  126.389444  34.999722   101  무안광주선    12  X
# 11  93  0121VMX00200  126.778333  35.136667   101  무안광주선    12  X
# 12  75  0121VMX00300  126.446944  35.006111   101  무안광주선    12  X
# ...

# %%
df_name14_num1['도로명'] = df_name14_num['도로명']
df_name14_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   76  0121VME00100  126.447500  35.016389   101  무안광주고속도로    12  E
# 1   78  0121VME00200  126.519444  35.040000   101  무안광주고속도로    12  E
# 2   82  0121VME00300  126.558056  35.058889   101  무안광주고속도로    12  E
# 3   86  0121VME00400  126.656111  35.081667   101  무안광주고속도로    12  E
# 4   77  0121VMS00100  126.478056  35.027222   101  무안광주고속도로    12  S
# 5   79  0121VMS00200  126.522500  35.040556   101  무안광주고속도로    12  S
# 6   83  0121VMS00300  126.586667  35.066389   101  무안광주고속도로    12  S
# 7   85  0121VMS00400  126.631389  35.076111   101  무안광주고속도로    12  S
# 8   89  0121VMS00500  126.728056  35.110278   101  무안광주고속도로    12  S
# 9   91  0121VMS00600  126.751389  35.137500   101  무안광주고속도로    12  S
# 10  73  0121VMX00100  126.389444  34.999722   101  무안광주고속도로    12  X
# 11  93  0121VMX00200  126.778333  35.136667   101  무안광주고속도로    12  X
# 12  75  0121VMX00300  126.446944  35.006111   101  무안광주고속도로    12  X
# ...

# %%
df_name15 = df[df['도로명'] == '동해선']
df_name15
# Out:
#        순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 733   478   0650VME00100  129.101111  37.557500   101  동해선    65  E
# 734   479   0650VME00200  129.072500  37.603333   101  동해선    65  E
# 735   484   0650VME00400  128.798333  37.889444   101  동해선    65  E
# 736   488   0650VME00500  128.718056  37.995833   101  동해선    65  E
# 737   491   0650VME00700  128.635278  38.053056   101  동해선    65  E
# 738  1122  0650VME0401K2  128.843333  37.738889   101  동해선    65  E
# 739  1121  0650VMN0081K3  129.106111  37.556111   101  동해선    65  N
# 740   480   0650VMS00100  129.020278  37.632222   101  동해선    65  S
# 741   482   0650VMS00200  128.826389  37.798889   101  동해선    65  S
# 742   487   0650VMS00300  128.758611  37.942222   101  동해선    65  S
# 743  1123   0650VMS00500  128.661389  38.038889   101  동해선    65  S
# 744   486   0650VMX00100  128.790000  37.931667   101  동해선    65  X
# 745   485   0650VMX00200  128.814167  37.911389   101  동해선    65  X
# ...

# %%
df_name15_num = df_name15.reset_index(drop = True)
df_name15_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    478   0650VME00100  129.101111  37.557500   101  동해선    65  E
# 1    479   0650VME00200  129.072500  37.603333   101  동해선    65  E
# 2    484   0650VME00400  128.798333  37.889444   101  동해선    65  E
# 3    488   0650VME00500  128.718056  37.995833   101  동해선    65  E
# 4    491   0650VME00700  128.635278  38.053056   101  동해선    65  E
# 5   1122  0650VME0401K2  128.843333  37.738889   101  동해선    65  E
# 6   1121  0650VMN0081K3  129.106111  37.556111   101  동해선    65  N
# 7    480   0650VMS00100  129.020278  37.632222   101  동해선    65  S
# 8    482   0650VMS00200  128.826389  37.798889   101  동해선    65  S
# 9    487   0650VMS00300  128.758611  37.942222   101  동해선    65  S
# 10  1123   0650VMS00500  128.661389  38.038889   101  동해선    65  S
# 11   486   0650VMX00100  128.790000  37.931667   101  동해선    65  X
# 12   485   0650VMX00200  128.814167  37.911389   101  동해선    65  X
# ...

# %%
df_name15_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name15_num
# Out:
#     도로명
# 0   동해선
# 1   동해선
# 2   동해선
# 3   동해선
# 4   동해선
# 5   동해선
# 6   동해선
# 7   동해선
# 8   동해선
# 9   동해선
# 10  동해선
# 11  동해선
# 12  동해선
# 13  동해선
# 14  동해선
# 15  동해선
# 16  동해선
# 17  동해선
# 18  동해선
# 19  동해선
# 20  동해선

# %%
df_name15_num.iloc[:] = '동해고속도로'
df_name15_num
# Out:
#        도로명
# 0   동해고속도로
# 1   동해고속도로
# 2   동해고속도로
# 3   동해고속도로
# 4   동해고속도로
# 5   동해고속도로
# 6   동해고속도로
# 7   동해고속도로
# 8   동해고속도로
# 9   동해고속도로
# 10  동해고속도로
# 11  동해고속도로
# 12  동해고속도로
# 13  동해고속도로
# 14  동해고속도로
# 15  동해고속도로
# 16  동해고속도로
# 17  동해고속도로
# 18  동해고속도로
# 19  동해고속도로
# 20  동해고속도로

# %%
df_name15_num1 = df_name15.reset_index(drop = True)
df_name15_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    478   0650VME00100  129.101111  37.557500   101  동해선    65  E
# 1    479   0650VME00200  129.072500  37.603333   101  동해선    65  E
# 2    484   0650VME00400  128.798333  37.889444   101  동해선    65  E
# 3    488   0650VME00500  128.718056  37.995833   101  동해선    65  E
# 4    491   0650VME00700  128.635278  38.053056   101  동해선    65  E
# 5   1122  0650VME0401K2  128.843333  37.738889   101  동해선    65  E
# 6   1121  0650VMN0081K3  129.106111  37.556111   101  동해선    65  N
# 7    480   0650VMS00100  129.020278  37.632222   101  동해선    65  S
# 8    482   0650VMS00200  128.826389  37.798889   101  동해선    65  S
# 9    487   0650VMS00300  128.758611  37.942222   101  동해선    65  S
# 10  1123   0650VMS00500  128.661389  38.038889   101  동해선    65  S
# 11   486   0650VMX00100  128.790000  37.931667   101  동해선    65  X
# 12   485   0650VMX00200  128.814167  37.911389   101  동해선    65  X
# ...

# %%
df_name15_num1['도로명'] = df_name15_num['도로명']
df_name15_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0    478   0650VME00100  129.101111  37.557500   101  동해고속도로    65  E
# 1    479   0650VME00200  129.072500  37.603333   101  동해고속도로    65  E
# 2    484   0650VME00400  128.798333  37.889444   101  동해고속도로    65  E
# 3    488   0650VME00500  128.718056  37.995833   101  동해고속도로    65  E
# 4    491   0650VME00700  128.635278  38.053056   101  동해고속도로    65  E
# 5   1122  0650VME0401K2  128.843333  37.738889   101  동해고속도로    65  E
# 6   1121  0650VMN0081K3  129.106111  37.556111   101  동해고속도로    65  N
# 7    480   0650VMS00100  129.020278  37.632222   101  동해고속도로    65  S
# 8    482   0650VMS00200  128.826389  37.798889   101  동해고속도로    65  S
# 9    487   0650VMS00300  128.758611  37.942222   101  동해고속도로    65  S
# 10  1123   0650VMS00500  128.661389  38.038889   101  동해고속도로    65  S
# 11   486   0650VMX00100  128.790000  37.931667   101  동해고속도로    65  X
# ...

# %%
df_name16 = df[df['도로명'] == '영암순천선']
df_name16
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 206  49  0101VME00200  126.680833  34.698333   101  영암순천선    10  E
# 207  53  0101VME00500  126.870000  34.692778   101  영암순천선    10  E
# 208  59  0101VME01100  127.492222  35.045556   101  영암순천선    10  E
# 209  62  0101VME01400  127.498333  35.031944   101  영암순천선    10  E
# 210  47  0101VMS00100  126.565278  34.737500   101  영암순천선    10  S
# 211  52  0101VMS00200  126.754167  34.694722   101  영암순천선    10  S
# 212  56  0101VMS00500  126.934444  34.723056   101  영암순천선    10  S
# 213  61  0101VMS01100  127.337500  35.030556   101  영암순천선    10  S
# 214  44  0101VMX00100  126.488056  34.741944   101  영암순천선    10  X
# 215  45  0101VMX00200  126.515833  34.734167   101  영암순천선    10  X
# 216  46  0101VMX00300  126.523611  34.768889   101  영암순천선    10  X
# 217  48  0101VMX00400  126.595833  34.732778   101  영암순천선    10  X
# 218  50  0101VMX00500  126.727778  34.669167   101  영암순천선    10  X
# ...

# %%
df_name16_num = df_name16.reset_index(drop = True)
df_name16_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   49  0101VME00200  126.680833  34.698333   101  영암순천선    10  E
# 1   53  0101VME00500  126.870000  34.692778   101  영암순천선    10  E
# 2   59  0101VME01100  127.492222  35.045556   101  영암순천선    10  E
# 3   62  0101VME01400  127.498333  35.031944   101  영암순천선    10  E
# 4   47  0101VMS00100  126.565278  34.737500   101  영암순천선    10  S
# 5   52  0101VMS00200  126.754167  34.694722   101  영암순천선    10  S
# 6   56  0101VMS00500  126.934444  34.723056   101  영암순천선    10  S
# 7   61  0101VMS01100  127.337500  35.030556   101  영암순천선    10  S
# 8   44  0101VMX00100  126.488056  34.741944   101  영암순천선    10  X
# 9   45  0101VMX00200  126.515833  34.734167   101  영암순천선    10  X
# 10  46  0101VMX00300  126.523611  34.768889   101  영암순천선    10  X
# 11  48  0101VMX00400  126.595833  34.732778   101  영암순천선    10  X
# 12  50  0101VMX00500  126.727778  34.669167   101  영암순천선    10  X
# ...

# %%
df_name16_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name16_num
# Out:
#       도로명
# 0   영암순천선
# 1   영암순천선
# 2   영암순천선
# 3   영암순천선
# 4   영암순천선
# 5   영암순천선
# 6   영암순천선
# 7   영암순천선
# 8   영암순천선
# 9   영암순천선
# 10  영암순천선
# 11  영암순천선
# 12  영암순천선
# 13  영암순천선
# 14  영암순천선
# 15  영암순천선
# 16  영암순천선
# 17  영암순천선
# 18  영암순천선
# 19  영암순천선

# %%
df_name16_num.iloc[:] = '남해고속도로'
df_name16_num
# Out:
#        도로명
# 0   남해고속도로
# 1   남해고속도로
# 2   남해고속도로
# 3   남해고속도로
# 4   남해고속도로
# 5   남해고속도로
# 6   남해고속도로
# 7   남해고속도로
# 8   남해고속도로
# 9   남해고속도로
# 10  남해고속도로
# 11  남해고속도로
# 12  남해고속도로
# 13  남해고속도로
# 14  남해고속도로
# 15  남해고속도로
# 16  남해고속도로
# 17  남해고속도로
# 18  남해고속도로
# 19  남해고속도로

# %%
df_name16_num1 = df_name16.reset_index(drop = True)
df_name16_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   49  0101VME00200  126.680833  34.698333   101  영암순천선    10  E
# 1   53  0101VME00500  126.870000  34.692778   101  영암순천선    10  E
# 2   59  0101VME01100  127.492222  35.045556   101  영암순천선    10  E
# 3   62  0101VME01400  127.498333  35.031944   101  영암순천선    10  E
# 4   47  0101VMS00100  126.565278  34.737500   101  영암순천선    10  S
# 5   52  0101VMS00200  126.754167  34.694722   101  영암순천선    10  S
# 6   56  0101VMS00500  126.934444  34.723056   101  영암순천선    10  S
# 7   61  0101VMS01100  127.337500  35.030556   101  영암순천선    10  S
# 8   44  0101VMX00100  126.488056  34.741944   101  영암순천선    10  X
# 9   45  0101VMX00200  126.515833  34.734167   101  영암순천선    10  X
# 10  46  0101VMX00300  126.523611  34.768889   101  영암순천선    10  X
# 11  48  0101VMX00400  126.595833  34.732778   101  영암순천선    10  X
# 12  50  0101VMX00500  126.727778  34.669167   101  영암순천선    10  X
# ...

# %%
df_name16_num1['도로명'] = df_name16_num['도로명']
df_name16_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   49  0101VME00200  126.680833  34.698333   101  남해고속도로    10  E
# 1   53  0101VME00500  126.870000  34.692778   101  남해고속도로    10  E
# 2   59  0101VME01100  127.492222  35.045556   101  남해고속도로    10  E
# 3   62  0101VME01400  127.498333  35.031944   101  남해고속도로    10  E
# 4   47  0101VMS00100  126.565278  34.737500   101  남해고속도로    10  S
# 5   52  0101VMS00200  126.754167  34.694722   101  남해고속도로    10  S
# 6   56  0101VMS00500  126.934444  34.723056   101  남해고속도로    10  S
# 7   61  0101VMS01100  127.337500  35.030556   101  남해고속도로    10  S
# 8   44  0101VMX00100  126.488056  34.741944   101  남해고속도로    10  X
# 9   45  0101VMX00200  126.515833  34.734167   101  남해고속도로    10  X
# 10  46  0101VMX00300  126.523611  34.768889   101  남해고속도로    10  X
# 11  48  0101VMX00400  126.595833  34.732778   101  남해고속도로    10  X
# 12  50  0101VMX00500  126.727778  34.669167   101  남해고속도로    10  X
# ...

# %%
df_name17 = df[df['도로명'] == '순천완주선']
df_name17
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 413  574  0270VME00100  127.553611  34.947500   101  순천완주선    27  E
# 414  575  0270VME00200  127.472139  35.122722   101  순천완주선    27  E
# 415  577  0270VME00300  127.353897  35.341336   101  순천완주선    27  E
# 416  578  0270VME00400  127.325497  35.377697   101  순천완주선    27  E
# 417   21  0270VME00500  127.305806  35.417292   101  순천완주선    27  E
# 418   23  0270VME00600  127.306439  35.521700   101  순천완주선    27  E
# 419   25  0270VME00700  127.334528  35.604572   101  순천완주선    27  E
# 420  547  0270VME01000  127.187706  35.856028   101  순천완주선    27  E
# 421  579  0270VMS00100  127.319586  35.383742   101  순천완주선    27  S
# 422   22  0270VMS00200  127.310950  35.431858   101  순천완주선    27  S
# 423   24  0270VMS00400  127.321608  35.579136   101  순천완주선    27  S
# 424  544  0270VMS00500  127.304247  35.650089   101  순천완주선    27  S
# 425  545  0270VMS00600  127.198525  35.799128   101  순천완주선    27  S
# ...

# %%
df_name17_num = df_name17.reset_index(drop = True)
df_name17_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   574  0270VME00100  127.553611  34.947500   101  순천완주선    27  E
# 1   575  0270VME00200  127.472139  35.122722   101  순천완주선    27  E
# 2   577  0270VME00300  127.353897  35.341336   101  순천완주선    27  E
# 3   578  0270VME00400  127.325497  35.377697   101  순천완주선    27  E
# 4    21  0270VME00500  127.305806  35.417292   101  순천완주선    27  E
# 5    23  0270VME00600  127.306439  35.521700   101  순천완주선    27  E
# 6    25  0270VME00700  127.334528  35.604572   101  순천완주선    27  E
# 7   547  0270VME01000  127.187706  35.856028   101  순천완주선    27  E
# 8   579  0270VMS00100  127.319586  35.383742   101  순천완주선    27  S
# 9    22  0270VMS00200  127.310950  35.431858   101  순천완주선    27  S
# 10   24  0270VMS00400  127.321608  35.579136   101  순천완주선    27  S
# 11  544  0270VMS00500  127.304247  35.650089   101  순천완주선    27  S
# 12  545  0270VMS00600  127.198525  35.799128   101  순천완주선    27  S
# ...

# %%
df_name17_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name17_num
# Out:
#       도로명
# 0   순천완주선
# 1   순천완주선
# 2   순천완주선
# 3   순천완주선
# 4   순천완주선
# 5   순천완주선
# 6   순천완주선
# 7   순천완주선
# 8   순천완주선
# 9   순천완주선
# 10  순천완주선
# 11  순천완주선
# 12  순천완주선
# 13  순천완주선
# 14  순천완주선
# 15  순천완주선
# 16  순천완주선
# 17  순천완주선
# 18  순천완주선

# %%
df_name17_num.iloc[:] = '순천완주고속도로'
df_name17_num
# Out:
#          도로명
# 0   순천완주고속도로
# 1   순천완주고속도로
# 2   순천완주고속도로
# 3   순천완주고속도로
# 4   순천완주고속도로
# 5   순천완주고속도로
# 6   순천완주고속도로
# 7   순천완주고속도로
# 8   순천완주고속도로
# 9   순천완주고속도로
# 10  순천완주고속도로
# 11  순천완주고속도로
# 12  순천완주고속도로
# 13  순천완주고속도로
# 14  순천완주고속도로
# 15  순천완주고속도로
# 16  순천완주고속도로
# 17  순천완주고속도로
# 18  순천완주고속도로

# %%
df_name17_num1 = df_name17.reset_index(drop = True)
df_name17_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   574  0270VME00100  127.553611  34.947500   101  순천완주선    27  E
# 1   575  0270VME00200  127.472139  35.122722   101  순천완주선    27  E
# 2   577  0270VME00300  127.353897  35.341336   101  순천완주선    27  E
# 3   578  0270VME00400  127.325497  35.377697   101  순천완주선    27  E
# 4    21  0270VME00500  127.305806  35.417292   101  순천완주선    27  E
# 5    23  0270VME00600  127.306439  35.521700   101  순천완주선    27  E
# 6    25  0270VME00700  127.334528  35.604572   101  순천완주선    27  E
# 7   547  0270VME01000  127.187706  35.856028   101  순천완주선    27  E
# 8   579  0270VMS00100  127.319586  35.383742   101  순천완주선    27  S
# 9    22  0270VMS00200  127.310950  35.431858   101  순천완주선    27  S
# 10   24  0270VMS00400  127.321608  35.579136   101  순천완주선    27  S
# 11  544  0270VMS00500  127.304247  35.650089   101  순천완주선    27  S
# 12  545  0270VMS00600  127.198525  35.799128   101  순천완주선    27  S
# ...

# %%
df_name17_num1['도로명'] = df_name17_num['도로명']
df_name17_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   574  0270VME00100  127.553611  34.947500   101  순천완주고속도로    27  E
# 1   575  0270VME00200  127.472139  35.122722   101  순천완주고속도로    27  E
# 2   577  0270VME00300  127.353897  35.341336   101  순천완주고속도로    27  E
# 3   578  0270VME00400  127.325497  35.377697   101  순천완주고속도로    27  E
# 4    21  0270VME00500  127.305806  35.417292   101  순천완주고속도로    27  E
# 5    23  0270VME00600  127.306439  35.521700   101  순천완주고속도로    27  E
# 6    25  0270VME00700  127.334528  35.604572   101  순천완주고속도로    27  E
# 7   547  0270VME01000  127.187706  35.856028   101  순천완주고속도로    27  E
# 8   579  0270VMS00100  127.319586  35.383742   101  순천완주고속도로    27  S
# 9    22  0270VMS00200  127.310950  35.431858   101  순천완주고속도로    27  S
# 10   24  0270VMS00400  127.321608  35.579136   101  순천완주고속도로    27  S
# 11  544  0270VMS00500  127.304247  35.650089   101  순천완주고속도로    27  S
# ...

# %%
df_name18 = df[df['도로명'] == '서천공주선']
df_name18
# Out:
#         순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 1056   504  1510VME00100  126.776667  36.213056   101  서천공주선   151  E
# 1057   507  1510VME00200  126.823611  36.278333   101  서천공주선   151  E
# 1058   511  1510VME00300  126.923889  36.360833   101  서천공주선   151  E
# 1059   515  1510VME00400  127.035278  36.445833   101  서천공주선   151  E
# 1060   517  1510VME00500  127.062222  36.459444   101  서천공주선   151  E
# 1061  1382  1510VMS00600  126.775000  36.093889   101  서천공주선   151  S
# 1062   506  1510VMS00700  126.806667  36.267222   101  서천공주선   151  S
# 1063   510  1510VMS00800  126.877500  36.322222   101  서천공주선   151  S
# 1064   514  1510VMS00900  126.984444  36.392500   101  서천공주선   151  S
# 1065   518  1510VMS01000  127.063889  36.478889   101  서천공주선   151  S
# 1066  1380  1510VMX01100  126.787222  36.045833   101  서천공주선   151  X
# 1067  1381  1510VMX01200  126.783056  36.039167   101  서천공주선   151  X
# ...

# %%
df_name18_num = df_name18.reset_index(drop = True)
df_name18_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    504  1510VME00100  126.776667  36.213056   101  서천공주선   151  E
# 1    507  1510VME00200  126.823611  36.278333   101  서천공주선   151  E
# 2    511  1510VME00300  126.923889  36.360833   101  서천공주선   151  E
# 3    515  1510VME00400  127.035278  36.445833   101  서천공주선   151  E
# 4    517  1510VME00500  127.062222  36.459444   101  서천공주선   151  E
# 5   1382  1510VMS00600  126.775000  36.093889   101  서천공주선   151  S
# 6    506  1510VMS00700  126.806667  36.267222   101  서천공주선   151  S
# 7    510  1510VMS00800  126.877500  36.322222   101  서천공주선   151  S
# 8    514  1510VMS00900  126.984444  36.392500   101  서천공주선   151  S
# 9    518  1510VMS01000  127.063889  36.478889   101  서천공주선   151  S
# 10  1380  1510VMX01100  126.787222  36.045833   101  서천공주선   151  X
# 11  1381  1510VMX01200  126.783056  36.039167   101  서천공주선   151  X
# 12   505  1510VMX01300  126.813056  36.243889   101  서천공주선   151  X
# ...

# %%
df_name18_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name18_num
# Out:
#       도로명
# 0   서천공주선
# 1   서천공주선
# 2   서천공주선
# 3   서천공주선
# 4   서천공주선
# 5   서천공주선
# 6   서천공주선
# 7   서천공주선
# 8   서천공주선
# 9   서천공주선
# 10  서천공주선
# 11  서천공주선
# 12  서천공주선
# 13  서천공주선
# 14  서천공주선
# 15  서천공주선
# 16  서천공주선
# 17  서천공주선

# %%
df_name18_num.iloc[:] = '서천공주고속도로'
df_name18_num
# Out:
#          도로명
# 0   서천공주고속도로
# 1   서천공주고속도로
# 2   서천공주고속도로
# 3   서천공주고속도로
# 4   서천공주고속도로
# 5   서천공주고속도로
# 6   서천공주고속도로
# 7   서천공주고속도로
# 8   서천공주고속도로
# 9   서천공주고속도로
# 10  서천공주고속도로
# 11  서천공주고속도로
# 12  서천공주고속도로
# 13  서천공주고속도로
# 14  서천공주고속도로
# 15  서천공주고속도로
# 16  서천공주고속도로
# 17  서천공주고속도로

# %%
df_name18_num1 = df_name18.reset_index(drop = True)
df_name18_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    504  1510VME00100  126.776667  36.213056   101  서천공주선   151  E
# 1    507  1510VME00200  126.823611  36.278333   101  서천공주선   151  E
# 2    511  1510VME00300  126.923889  36.360833   101  서천공주선   151  E
# 3    515  1510VME00400  127.035278  36.445833   101  서천공주선   151  E
# 4    517  1510VME00500  127.062222  36.459444   101  서천공주선   151  E
# 5   1382  1510VMS00600  126.775000  36.093889   101  서천공주선   151  S
# 6    506  1510VMS00700  126.806667  36.267222   101  서천공주선   151  S
# 7    510  1510VMS00800  126.877500  36.322222   101  서천공주선   151  S
# 8    514  1510VMS00900  126.984444  36.392500   101  서천공주선   151  S
# 9    518  1510VMS01000  127.063889  36.478889   101  서천공주선   151  S
# 10  1380  1510VMX01100  126.787222  36.045833   101  서천공주선   151  X
# 11  1381  1510VMX01200  126.783056  36.039167   101  서천공주선   151  X
# 12   505  1510VMX01300  126.813056  36.243889   101  서천공주선   151  X
# ...

# %%
df_name18_num1['도로명'] = df_name18_num['도로명']
df_name18_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0    504  1510VME00100  126.776667  36.213056   101  서천공주고속도로   151  E
# 1    507  1510VME00200  126.823611  36.278333   101  서천공주고속도로   151  E
# 2    511  1510VME00300  126.923889  36.360833   101  서천공주고속도로   151  E
# 3    515  1510VME00400  127.035278  36.445833   101  서천공주고속도로   151  E
# 4    517  1510VME00500  127.062222  36.459444   101  서천공주고속도로   151  E
# 5   1382  1510VMS00600  126.775000  36.093889   101  서천공주고속도로   151  S
# 6    506  1510VMS00700  126.806667  36.267222   101  서천공주고속도로   151  S
# 7    510  1510VMS00800  126.877500  36.322222   101  서천공주고속도로   151  S
# 8    514  1510VMS00900  126.984444  36.392500   101  서천공주고속도로   151  S
# 9    518  1510VMS01000  127.063889  36.478889   101  서천공주고속도로   151  S
# 10  1380  1510VMX01100  126.787222  36.045833   101  서천공주고속도로   151  X
# 11  1381  1510VMX01200  126.783056  36.039167   101  서천공주고속도로   151  X
# ...

# %%
df_name19 = df[df['도로명'] == '호남선의지선']
df_name19
# Out:
#         순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 1127  1341  2510VME00100  127.117675  36.106967   101  호남선의지선   251  E
# 1128  1346  2510VME00200  127.270336  36.211764   101  호남선의지선   251  E
# 1129  1349  2510VME00300  127.294600  36.272153   101  호남선의지선   251  E
# 1130  1237  2510VME00400  127.325000  36.372500   101  호남선의지선   251  E
# 1131  1240  2510VME00500  127.354444  36.394444   101  호남선의지선   251  E
# 1132  1343  2510VMS00100  127.154825  36.146786   101  호남선의지선   251  S
# 1133  1344  2510VMS00150  127.218353  36.161658   101  호남선의지선   251  S
# 1134  1345  2510VMS00170  127.243275  36.174728   101  호남선의지선   251  S
# 1135  1350  2510VMS00200  127.300239  36.275333   101  호남선의지선   251  S
# 1136  1236  2510VMS00400  127.307500  36.309722   101  호남선의지선   251  S
# 1137  1241  2510VMS00500  127.358889  36.400278   101  호남선의지선   251  S
# 1138  1342  2510VMX00100  127.125411  36.127531   101  호남선의지선   251  X
# ...

# %%
df_name19_num = df_name19.reset_index(drop = True)
df_name19_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   1341  2510VME00100  127.117675  36.106967   101  호남선의지선   251  E
# 1   1346  2510VME00200  127.270336  36.211764   101  호남선의지선   251  E
# 2   1349  2510VME00300  127.294600  36.272153   101  호남선의지선   251  E
# 3   1237  2510VME00400  127.325000  36.372500   101  호남선의지선   251  E
# 4   1240  2510VME00500  127.354444  36.394444   101  호남선의지선   251  E
# 5   1343  2510VMS00100  127.154825  36.146786   101  호남선의지선   251  S
# 6   1344  2510VMS00150  127.218353  36.161658   101  호남선의지선   251  S
# 7   1345  2510VMS00170  127.243275  36.174728   101  호남선의지선   251  S
# 8   1350  2510VMS00200  127.300239  36.275333   101  호남선의지선   251  S
# 9   1236  2510VMS00400  127.307500  36.309722   101  호남선의지선   251  S
# 10  1241  2510VMS00500  127.358889  36.400278   101  호남선의지선   251  S
# 11  1342  2510VMX00100  127.125411  36.127531   101  호남선의지선   251  X
# 12  1347  2510VMX00200  127.276247  36.253167   101  호남선의지선   251  X
# ...

# %%
df_name19_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name19_num
# Out:
#        도로명
# 0   호남선의지선
# 1   호남선의지선
# 2   호남선의지선
# 3   호남선의지선
# 4   호남선의지선
# 5   호남선의지선
# 6   호남선의지선
# 7   호남선의지선
# 8   호남선의지선
# 9   호남선의지선
# 10  호남선의지선
# 11  호남선의지선
# 12  호남선의지선
# 13  호남선의지선
# 14  호남선의지선
# 15  호남선의지선
# 16  호남선의지선

# %%
df_name19_num.iloc[:] = '호남고속도로지선'
df_name19_num
# Out:
#          도로명
# 0   호남고속도로지선
# 1   호남고속도로지선
# 2   호남고속도로지선
# 3   호남고속도로지선
# 4   호남고속도로지선
# 5   호남고속도로지선
# 6   호남고속도로지선
# 7   호남고속도로지선
# 8   호남고속도로지선
# 9   호남고속도로지선
# 10  호남고속도로지선
# 11  호남고속도로지선
# 12  호남고속도로지선
# 13  호남고속도로지선
# 14  호남고속도로지선
# 15  호남고속도로지선
# 16  호남고속도로지선

# %%
df_name19_num1 = df_name19.reset_index(drop = True)
df_name19_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   1341  2510VME00100  127.117675  36.106967   101  호남선의지선   251  E
# 1   1346  2510VME00200  127.270336  36.211764   101  호남선의지선   251  E
# 2   1349  2510VME00300  127.294600  36.272153   101  호남선의지선   251  E
# 3   1237  2510VME00400  127.325000  36.372500   101  호남선의지선   251  E
# 4   1240  2510VME00500  127.354444  36.394444   101  호남선의지선   251  E
# 5   1343  2510VMS00100  127.154825  36.146786   101  호남선의지선   251  S
# 6   1344  2510VMS00150  127.218353  36.161658   101  호남선의지선   251  S
# 7   1345  2510VMS00170  127.243275  36.174728   101  호남선의지선   251  S
# 8   1350  2510VMS00200  127.300239  36.275333   101  호남선의지선   251  S
# 9   1236  2510VMS00400  127.307500  36.309722   101  호남선의지선   251  S
# 10  1241  2510VMS00500  127.358889  36.400278   101  호남선의지선   251  S
# 11  1342  2510VMX00100  127.125411  36.127531   101  호남선의지선   251  X
# 12  1347  2510VMX00200  127.276247  36.253167   101  호남선의지선   251  X
# ...

# %%
df_name19_num1['도로명'] = df_name19_num['도로명']
df_name19_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1341  2510VME00100  127.117675  36.106967   101  호남고속도로지선   251  E
# 1   1346  2510VME00200  127.270336  36.211764   101  호남고속도로지선   251  E
# 2   1349  2510VME00300  127.294600  36.272153   101  호남고속도로지선   251  E
# 3   1237  2510VME00400  127.325000  36.372500   101  호남고속도로지선   251  E
# 4   1240  2510VME00500  127.354444  36.394444   101  호남고속도로지선   251  E
# 5   1343  2510VMS00100  127.154825  36.146786   101  호남고속도로지선   251  S
# 6   1344  2510VMS00150  127.218353  36.161658   101  호남고속도로지선   251  S
# 7   1345  2510VMS00170  127.243275  36.174728   101  호남고속도로지선   251  S
# 8   1350  2510VMS00200  127.300239  36.275333   101  호남고속도로지선   251  S
# 9   1236  2510VMS00400  127.307500  36.309722   101  호남고속도로지선   251  S
# 10  1241  2510VMS00500  127.358889  36.400278   101  호남고속도로지선   251  S
# 11  1342  2510VMX00100  127.125411  36.127531   101  호남고속도로지선   251  X
# ...

# %%
df_name20 = df[df['도로명'] == '서울양양선']
df_name20
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 717    19  0600VME00001  127.171944  37.576389   101  서울양양선    60  E
# 718  1133  0600VME00002  127.241944  37.597222   101  서울양양선    60  E
# 719  1136  0600VME00004  127.323889  37.631944   101  서울양양선    60  E
# 720  1139  0600VME00008  127.592778  37.726111   101  서울양양선    60  E
# 721  1141  0600VME00009  127.694444  37.745000   101  서울양양선    60  E
# 722  1134  0600VMS00001  127.241944  37.597222   101  서울양양선    60  S
# 723  1137  0600VMS00003  127.328333  37.633889   101  서울양양선    60  S
# 724  1138  0600VMS00004  127.403611  37.637778   101  서울양양선    60  S
# 725  1140  0600VMS00008  127.656944  37.740556   101  서울양양선    60  S
# 726  1142  0600VMS00100  127.810556  37.756944   101  서울양양선    60  S
# 727  1143  0600VMS00200  127.917222  37.748333   101  서울양양선    60  S
# 728    20  0600VMX00001  127.194167  37.576667   101  서울양양선    60  X
# 729  1132  0600VMX00002  127.207500  37.595000   101  서울양양선    60  X
# ...

# %%
df_name20_num = df_name20.reset_index(drop = True)
df_name20_num
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0     19  0600VME00001  127.171944  37.576389   101  서울양양선    60  E
# 1   1133  0600VME00002  127.241944  37.597222   101  서울양양선    60  E
# 2   1136  0600VME00004  127.323889  37.631944   101  서울양양선    60  E
# 3   1139  0600VME00008  127.592778  37.726111   101  서울양양선    60  E
# 4   1141  0600VME00009  127.694444  37.745000   101  서울양양선    60  E
# 5   1134  0600VMS00001  127.241944  37.597222   101  서울양양선    60  S
# 6   1137  0600VMS00003  127.328333  37.633889   101  서울양양선    60  S
# 7   1138  0600VMS00004  127.403611  37.637778   101  서울양양선    60  S
# 8   1140  0600VMS00008  127.656944  37.740556   101  서울양양선    60  S
# 9   1142  0600VMS00100  127.810556  37.756944   101  서울양양선    60  S
# 10  1143  0600VMS00200  127.917222  37.748333   101  서울양양선    60  S
# 11    20  0600VMX00001  127.194167  37.576667   101  서울양양선    60  X
# 12  1132  0600VMX00002  127.207500  37.595000   101  서울양양선    60  X
# ...

# %%
df_name20_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name20_num
# Out:
#       도로명
# 0   서울양양선
# 1   서울양양선
# 2   서울양양선
# 3   서울양양선
# 4   서울양양선
# 5   서울양양선
# 6   서울양양선
# 7   서울양양선
# 8   서울양양선
# 9   서울양양선
# 10  서울양양선
# 11  서울양양선
# 12  서울양양선
# 13  서울양양선
# 14  서울양양선
# 15  서울양양선

# %%
df_name20_num.iloc[:] = '서울양양고속도로'
df_name20_num
# Out:
#          도로명
# 0   서울양양고속도로
# 1   서울양양고속도로
# 2   서울양양고속도로
# 3   서울양양고속도로
# 4   서울양양고속도로
# 5   서울양양고속도로
# 6   서울양양고속도로
# 7   서울양양고속도로
# 8   서울양양고속도로
# 9   서울양양고속도로
# 10  서울양양고속도로
# 11  서울양양고속도로
# 12  서울양양고속도로
# 13  서울양양고속도로
# 14  서울양양고속도로
# 15  서울양양고속도로

# %%
df_name20_num1 = df_name20.reset_index(drop = True)
df_name20_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0     19  0600VME00001  127.171944  37.576389   101  서울양양선    60  E
# 1   1133  0600VME00002  127.241944  37.597222   101  서울양양선    60  E
# 2   1136  0600VME00004  127.323889  37.631944   101  서울양양선    60  E
# 3   1139  0600VME00008  127.592778  37.726111   101  서울양양선    60  E
# 4   1141  0600VME00009  127.694444  37.745000   101  서울양양선    60  E
# 5   1134  0600VMS00001  127.241944  37.597222   101  서울양양선    60  S
# 6   1137  0600VMS00003  127.328333  37.633889   101  서울양양선    60  S
# 7   1138  0600VMS00004  127.403611  37.637778   101  서울양양선    60  S
# 8   1140  0600VMS00008  127.656944  37.740556   101  서울양양선    60  S
# 9   1142  0600VMS00100  127.810556  37.756944   101  서울양양선    60  S
# 10  1143  0600VMS00200  127.917222  37.748333   101  서울양양선    60  S
# 11    20  0600VMX00001  127.194167  37.576667   101  서울양양선    60  X
# 12  1132  0600VMX00002  127.207500  37.595000   101  서울양양선    60  X
# ...

# %%
df_name20_num1['도로명'] = df_name20_num['도로명']
df_name20_num1
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0     19  0600VME00001  127.171944  37.576389   101  서울양양고속도로    60  E
# 1   1133  0600VME00002  127.241944  37.597222   101  서울양양고속도로    60  E
# 2   1136  0600VME00004  127.323889  37.631944   101  서울양양고속도로    60  E
# 3   1139  0600VME00008  127.592778  37.726111   101  서울양양고속도로    60  E
# 4   1141  0600VME00009  127.694444  37.745000   101  서울양양고속도로    60  E
# 5   1134  0600VMS00001  127.241944  37.597222   101  서울양양고속도로    60  S
# 6   1137  0600VMS00003  127.328333  37.633889   101  서울양양고속도로    60  S
# 7   1138  0600VMS00004  127.403611  37.637778   101  서울양양고속도로    60  S
# 8   1140  0600VMS00008  127.656944  37.740556   101  서울양양고속도로    60  S
# 9   1142  0600VMS00100  127.810556  37.756944   101  서울양양고속도로    60  S
# 10  1143  0600VMS00200  127.917222  37.748333   101  서울양양고속도로    60  S
# 11    20  0600VMX00001  127.194167  37.576667   101  서울양양고속도로    60  X
# ...

# %%
df_name21 = df[df['도로명'] == '88올림픽선']
df_name21
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 235  552  0120VME00100  127.076667  35.348056   101  88올림픽선    12  E
# 236   26  0120VME00250  127.276172  35.391481   101  88올림픽선    12  E
# 237   28  0120VME00400  127.480278  35.481667   101  88올림픽선    12  E
# 238  204  0120VME00500  127.929167  35.659722   101  88올림픽선    12  E
# 239  206  0120VME00700  128.342778  35.745278   101  88올림픽선    12  E
# 240  209  0120VME00800  128.440833  35.772222   101  88올림픽선    12  E
# 241  551  0120VMS00100  126.997222  35.305000   101  88올림픽선    12  S
# 242   27  0120VMS00300  127.416111  35.438056   101  88올림픽선    12  S
# 243   29  0120VMS00400  127.656111  35.533333   101  88올림픽선    12  S
# 244  203  0120VMS00500  127.784444  35.538333   101  88올림픽선    12  S
# 245  205  0120VMS00600  128.180278  35.704722   101  88올림픽선    12  S
# 246  208  0120VMS00700  128.408611  35.764444   101  88올림픽선    12  S
# 247  549  0120VMX00100  126.976111  35.293333   101  88올림픽선    12  X
# ...

# %%
df_name21_num = df_name21.reset_index(drop = True)
df_name21_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   552  0120VME00100  127.076667  35.348056   101  88올림픽선    12  E
# 1    26  0120VME00250  127.276172  35.391481   101  88올림픽선    12  E
# 2    28  0120VME00400  127.480278  35.481667   101  88올림픽선    12  E
# 3   204  0120VME00500  127.929167  35.659722   101  88올림픽선    12  E
# 4   206  0120VME00700  128.342778  35.745278   101  88올림픽선    12  E
# 5   209  0120VME00800  128.440833  35.772222   101  88올림픽선    12  E
# 6   551  0120VMS00100  126.997222  35.305000   101  88올림픽선    12  S
# 7    27  0120VMS00300  127.416111  35.438056   101  88올림픽선    12  S
# 8    29  0120VMS00400  127.656111  35.533333   101  88올림픽선    12  S
# 9   203  0120VMS00500  127.784444  35.538333   101  88올림픽선    12  S
# 10  205  0120VMS00600  128.180278  35.704722   101  88올림픽선    12  S
# 11  208  0120VMS00700  128.408611  35.764444   101  88올림픽선    12  S
# 12  549  0120VMX00100  126.976111  35.293333   101  88올림픽선    12  X
# ...

# %%
df_name21_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name21_num
# Out:
#        도로명
# 0   88올림픽선
# 1   88올림픽선
# 2   88올림픽선
# 3   88올림픽선
# 4   88올림픽선
# 5   88올림픽선
# 6   88올림픽선
# 7   88올림픽선
# 8   88올림픽선
# 9   88올림픽선
# 10  88올림픽선
# 11  88올림픽선
# 12  88올림픽선
# 13  88올림픽선
# 14  88올림픽선

# %%
df_name21_num.iloc[:] = '광주대구고속도로'
df_name21_num
# Out:
#          도로명
# 0   광주대구고속도로
# 1   광주대구고속도로
# 2   광주대구고속도로
# 3   광주대구고속도로
# 4   광주대구고속도로
# 5   광주대구고속도로
# 6   광주대구고속도로
# 7   광주대구고속도로
# 8   광주대구고속도로
# 9   광주대구고속도로
# 10  광주대구고속도로
# 11  광주대구고속도로
# 12  광주대구고속도로
# 13  광주대구고속도로
# 14  광주대구고속도로

# %%
df_name21_num1 = df_name21.reset_index(drop = True)
df_name21_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   552  0120VME00100  127.076667  35.348056   101  88올림픽선    12  E
# 1    26  0120VME00250  127.276172  35.391481   101  88올림픽선    12  E
# 2    28  0120VME00400  127.480278  35.481667   101  88올림픽선    12  E
# 3   204  0120VME00500  127.929167  35.659722   101  88올림픽선    12  E
# 4   206  0120VME00700  128.342778  35.745278   101  88올림픽선    12  E
# 5   209  0120VME00800  128.440833  35.772222   101  88올림픽선    12  E
# 6   551  0120VMS00100  126.997222  35.305000   101  88올림픽선    12  S
# 7    27  0120VMS00300  127.416111  35.438056   101  88올림픽선    12  S
# 8    29  0120VMS00400  127.656111  35.533333   101  88올림픽선    12  S
# 9   203  0120VMS00500  127.784444  35.538333   101  88올림픽선    12  S
# 10  205  0120VMS00600  128.180278  35.704722   101  88올림픽선    12  S
# 11  208  0120VMS00700  128.408611  35.764444   101  88올림픽선    12  S
# 12  549  0120VMX00100  126.976111  35.293333   101  88올림픽선    12  X
# ...

# %%
df_name21_num1['도로명'] = df_name21_num['도로명']
df_name21_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   552  0120VME00100  127.076667  35.348056   101  광주대구고속도로    12  E
# 1    26  0120VME00250  127.276172  35.391481   101  광주대구고속도로    12  E
# 2    28  0120VME00400  127.480278  35.481667   101  광주대구고속도로    12  E
# 3   204  0120VME00500  127.929167  35.659722   101  광주대구고속도로    12  E
# 4   206  0120VME00700  128.342778  35.745278   101  광주대구고속도로    12  E
# 5   209  0120VME00800  128.440833  35.772222   101  광주대구고속도로    12  E
# 6   551  0120VMS00100  126.997222  35.305000   101  광주대구고속도로    12  S
# 7    27  0120VMS00300  127.416111  35.438056   101  광주대구고속도로    12  S
# 8    29  0120VMS00400  127.656111  35.533333   101  광주대구고속도로    12  S
# 9   203  0120VMS00500  127.784444  35.538333   101  광주대구고속도로    12  S
# 10  205  0120VMS00600  128.180278  35.704722   101  광주대구고속도로    12  S
# 11  208  0120VMS00700  128.408611  35.764444   101  광주대구고속도로    12  S
# ...

# %%
df_name22 = df[df['도로명'] == '고창담양선']
df_name22
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 271   30   0140VME00100  126.661389  35.408333   101  고창담양선   253  E
# 272   36   0140VME00300  126.775000  35.348333   101  고창담양선   253  E
# 273   38   0140VME00400  126.861111  35.268333   101  고창담양선   253  E
# 274   40   0140VME00500  126.929167  35.248333   101  고창담양선   253  E
# 275  584  0140VME0052K2  126.695000  35.386111   101  고창담양선   253  E
# 276   33   0140VMS00100  126.697500  35.383611   101  고창담양선   253  S
# 277   37   0140VMS00200  126.796944  35.336667   101  고창담양선   253  S
# 278   39   0140VMS00300  126.923056  35.249722   101  고창담양선   253  S
# 279   41   0140VMS00400  127.008056  35.251944   101  고창담양선   253  S
# 280   31   0140VMX00100  126.676111  35.407222   101  고창담양선   253  X
# 281   32   0140VMX00200  126.680556  35.407222   101  고창담양선   253  X
# 282   34   0140VMX00300  126.753889  35.321667   101  고창담양선   253  X
# 283   35   0140VMX00400  126.763333  35.320000   101  고창담양선   253  X

# %%
df_name22_num = df_name22.reset_index(drop = True)
df_name22_num
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    30   0140VME00100  126.661389  35.408333   101  고창담양선   253  E
# 1    36   0140VME00300  126.775000  35.348333   101  고창담양선   253  E
# 2    38   0140VME00400  126.861111  35.268333   101  고창담양선   253  E
# 3    40   0140VME00500  126.929167  35.248333   101  고창담양선   253  E
# 4   584  0140VME0052K2  126.695000  35.386111   101  고창담양선   253  E
# 5    33   0140VMS00100  126.697500  35.383611   101  고창담양선   253  S
# 6    37   0140VMS00200  126.796944  35.336667   101  고창담양선   253  S
# 7    39   0140VMS00300  126.923056  35.249722   101  고창담양선   253  S
# 8    41   0140VMS00400  127.008056  35.251944   101  고창담양선   253  S
# 9    31   0140VMX00100  126.676111  35.407222   101  고창담양선   253  X
# 10   32   0140VMX00200  126.680556  35.407222   101  고창담양선   253  X
# 11   34   0140VMX00300  126.753889  35.321667   101  고창담양선   253  X
# 12   35   0140VMX00400  126.763333  35.320000   101  고창담양선   253  X

# %%
df_name22_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name22_num
# Out:
#       도로명
# 0   고창담양선
# 1   고창담양선
# 2   고창담양선
# 3   고창담양선
# 4   고창담양선
# 5   고창담양선
# 6   고창담양선
# 7   고창담양선
# 8   고창담양선
# 9   고창담양선
# 10  고창담양선
# 11  고창담양선
# 12  고창담양선

# %%
df_name22_num.iloc[:] = '고창담양고속도로'
df_name22_num
# Out:
#          도로명
# 0   고창담양고속도로
# 1   고창담양고속도로
# 2   고창담양고속도로
# 3   고창담양고속도로
# 4   고창담양고속도로
# 5   고창담양고속도로
# 6   고창담양고속도로
# 7   고창담양고속도로
# 8   고창담양고속도로
# 9   고창담양고속도로
# 10  고창담양고속도로
# 11  고창담양고속도로
# 12  고창담양고속도로

# %%
df_name22_num1 = df_name22.reset_index(drop = True)
df_name22_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0    30   0140VME00100  126.661389  35.408333   101  고창담양선   253  E
# 1    36   0140VME00300  126.775000  35.348333   101  고창담양선   253  E
# 2    38   0140VME00400  126.861111  35.268333   101  고창담양선   253  E
# 3    40   0140VME00500  126.929167  35.248333   101  고창담양선   253  E
# 4   584  0140VME0052K2  126.695000  35.386111   101  고창담양선   253  E
# 5    33   0140VMS00100  126.697500  35.383611   101  고창담양선   253  S
# 6    37   0140VMS00200  126.796944  35.336667   101  고창담양선   253  S
# 7    39   0140VMS00300  126.923056  35.249722   101  고창담양선   253  S
# 8    41   0140VMS00400  127.008056  35.251944   101  고창담양선   253  S
# 9    31   0140VMX00100  126.676111  35.407222   101  고창담양선   253  X
# 10   32   0140VMX00200  126.680556  35.407222   101  고창담양선   253  X
# 11   34   0140VMX00300  126.753889  35.321667   101  고창담양선   253  X
# 12   35   0140VMX00400  126.763333  35.320000   101  고창담양선   253  X

# %%
df_name22_num1['도로명'] = df_name22_num['도로명']
df_name22_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0    30   0140VME00100  126.661389  35.408333   101  고창담양고속도로   253  E
# 1    36   0140VME00300  126.775000  35.348333   101  고창담양고속도로   253  E
# 2    38   0140VME00400  126.861111  35.268333   101  고창담양고속도로   253  E
# 3    40   0140VME00500  126.929167  35.248333   101  고창담양고속도로   253  E
# 4   584  0140VME0052K2  126.695000  35.386111   101  고창담양고속도로   253  E
# 5    33   0140VMS00100  126.697500  35.383611   101  고창담양고속도로   253  S
# 6    37   0140VMS00200  126.796944  35.336667   101  고창담양고속도로   253  S
# 7    39   0140VMS00300  126.923056  35.249722   101  고창담양고속도로   253  S
# 8    41   0140VMS00400  127.008056  35.251944   101  고창담양고속도로   253  S
# 9    31   0140VMX00100  126.676111  35.407222   101  고창담양고속도로   253  X
# 10   32   0140VMX00200  126.680556  35.407222   101  고창담양고속도로   253  X
# 11   34   0140VMX00300  126.753889  35.321667   101  고창담양고속도로   253  X
# ...

# %%
df_name23 = df[df['도로명'] == '평택화성선']
df_name23
# Out:
#        순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 226  1111  010411VME11002  126.985278  37.018056   101  평택화성선    17  E
# 227  1112  010411VME11301  126.991667  37.066111   101  평택화성선    17  E
# 228  1113  010411VME11502  126.995556  37.105556   101  평택화성선    17  E
# 230  1114  010411VME12302  126.975278  37.180833   101  평택화성선    17  E
# 232  1115  010411VMS12201  126.966111  37.208889   101  평택화성선    17  S
# 337   389    0170VME00200  126.979167  37.006389   101  평택화성선    17  E
# 338   392    0170VME00500  126.998056  37.154722   101  평택화성선    17  E
# 340   388    0170VMS00200  127.007500  37.015278   101  평택화성선    17  S
# 341   390    0170VMS00400  126.991667  37.066111   101  평택화성선    17  S
# 342   391    0170VMS00600  126.996389  37.120556   101  평택화성선    17  S
# 343   393    0170VMS00700  126.998056  37.161111   101  평택화성선    17  S
# 344   394    0170VMS00800  126.966111  37.208889   101  평택화성선    17  S

# %%
df_name23_num = df_name23.reset_index(drop = True)
df_name23_num
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1111  010411VME11002  126.985278  37.018056   101  평택화성선    17  E
# 1   1112  010411VME11301  126.991667  37.066111   101  평택화성선    17  E
# 2   1113  010411VME11502  126.995556  37.105556   101  평택화성선    17  E
# 3   1114  010411VME12302  126.975278  37.180833   101  평택화성선    17  E
# 4   1115  010411VMS12201  126.966111  37.208889   101  평택화성선    17  S
# 5    389    0170VME00200  126.979167  37.006389   101  평택화성선    17  E
# 6    392    0170VME00500  126.998056  37.154722   101  평택화성선    17  E
# 7    388    0170VMS00200  127.007500  37.015278   101  평택화성선    17  S
# 8    390    0170VMS00400  126.991667  37.066111   101  평택화성선    17  S
# 9    391    0170VMS00600  126.996389  37.120556   101  평택화성선    17  S
# 10   393    0170VMS00700  126.998056  37.161111   101  평택화성선    17  S
# 11   394    0170VMS00800  126.966111  37.208889   101  평택화성선    17  S

# %%
df_name23_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name23_num
# Out:
#       도로명
# 0   평택화성선
# 1   평택화성선
# 2   평택화성선
# 3   평택화성선
# 4   평택화성선
# 5   평택화성선
# 6   평택화성선
# 7   평택화성선
# 8   평택화성선
# 9   평택화성선
# 10  평택화성선
# 11  평택화성선

# %%
df_name23_num.iloc[:] = '평택화성고속도로'
df_name23_num
# Out:
#          도로명
# 0   평택화성고속도로
# 1   평택화성고속도로
# 2   평택화성고속도로
# 3   평택화성고속도로
# 4   평택화성고속도로
# 5   평택화성고속도로
# 6   평택화성고속도로
# 7   평택화성고속도로
# 8   평택화성고속도로
# 9   평택화성고속도로
# 10  평택화성고속도로
# 11  평택화성고속도로

# %%
df_name23_num1 = df_name23.reset_index(drop = True)
df_name23_num1
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   1111  010411VME11002  126.985278  37.018056   101  평택화성선    17  E
# 1   1112  010411VME11301  126.991667  37.066111   101  평택화성선    17  E
# 2   1113  010411VME11502  126.995556  37.105556   101  평택화성선    17  E
# 3   1114  010411VME12302  126.975278  37.180833   101  평택화성선    17  E
# 4   1115  010411VMS12201  126.966111  37.208889   101  평택화성선    17  S
# 5    389    0170VME00200  126.979167  37.006389   101  평택화성선    17  E
# 6    392    0170VME00500  126.998056  37.154722   101  평택화성선    17  E
# 7    388    0170VMS00200  127.007500  37.015278   101  평택화성선    17  S
# 8    390    0170VMS00400  126.991667  37.066111   101  평택화성선    17  S
# 9    391    0170VMS00600  126.996389  37.120556   101  평택화성선    17  S
# 10   393    0170VMS00700  126.998056  37.161111   101  평택화성선    17  S
# 11   394    0170VMS00800  126.966111  37.208889   101  평택화성선    17  S

# %%
df_name23_num1['도로명'] = df_name23_num['도로명']
df_name23_num1
# Out:
#       순번          VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1111  010411VME11002  126.985278  37.018056   101  평택화성고속도로    17  E
# 1   1112  010411VME11301  126.991667  37.066111   101  평택화성고속도로    17  E
# 2   1113  010411VME11502  126.995556  37.105556   101  평택화성고속도로    17  E
# 3   1114  010411VME12302  126.975278  37.180833   101  평택화성고속도로    17  E
# 4   1115  010411VMS12201  126.966111  37.208889   101  평택화성고속도로    17  S
# 5    389    0170VME00200  126.979167  37.006389   101  평택화성고속도로    17  E
# 6    392    0170VME00500  126.998056  37.154722   101  평택화성고속도로    17  E
# 7    388    0170VMS00200  127.007500  37.015278   101  평택화성고속도로    17  S
# 8    390    0170VMS00400  126.991667  37.066111   101  평택화성고속도로    17  S
# 9    391    0170VMS00600  126.996389  37.120556   101  평택화성고속도로    17  S
# 10   393    0170VMS00700  126.998056  37.161111   101  평택화성고속도로    17  S
# 11   394    0170VMS00800  126.966111  37.208889   101  평택화성고속도로    17  S

# %%
df_name24 = df[df['도로명'] == '중부내륙지선']
df_name24
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 1434  240  4510VME00200  128.508056  35.817222   101  중부내륙지선   451  E
# 1435  246  4510VME00300  128.531944  35.870556   101  중부내륙지선   451  E
# 1436  241  4510VMS00300  128.507778  35.816944   101  중부내륙지선   451  S
# 1437  197  4510VMX00100  128.474444  35.726667   101  중부내륙지선   451  X
# 1438  239  4510VMX00150  128.484167  35.795278   101  중부내륙지선   451  X
# 1439  242  4510VMX00200  128.524444  35.833611   101  중부내륙지선   451  X
# 1440  243  4510VMX00300  128.527880  35.839187   101  중부내륙지선   451  X
# 1441  245  4510VMX00400  128.521700  35.851667   101  중부내륙지선   451  X
# 1442  244  4510VMX00500  128.524490  35.860278   101  중부내륙지선   451  X
# 1443  247  4510VMX00600  128.525863  35.886389   101  중부내륙지선   451  X

# %%
df_name24_num = df_name24.reset_index(drop = True)
df_name24_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  240  4510VME00200  128.508056  35.817222   101  중부내륙지선   451  E
# 1  246  4510VME00300  128.531944  35.870556   101  중부내륙지선   451  E
# 2  241  4510VMS00300  128.507778  35.816944   101  중부내륙지선   451  S
# 3  197  4510VMX00100  128.474444  35.726667   101  중부내륙지선   451  X
# 4  239  4510VMX00150  128.484167  35.795278   101  중부내륙지선   451  X
# 5  242  4510VMX00200  128.524444  35.833611   101  중부내륙지선   451  X
# 6  243  4510VMX00300  128.527880  35.839187   101  중부내륙지선   451  X
# 7  245  4510VMX00400  128.521700  35.851667   101  중부내륙지선   451  X
# 8  244  4510VMX00500  128.524490  35.860278   101  중부내륙지선   451  X
# 9  247  4510VMX00600  128.525863  35.886389   101  중부내륙지선   451  X

# %%
df_name24_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name24_num
# Out:
#       도로명
# 0  중부내륙지선
# 1  중부내륙지선
# 2  중부내륙지선
# 3  중부내륙지선
# 4  중부내륙지선
# 5  중부내륙지선
# 6  중부내륙지선
# 7  중부내륙지선
# 8  중부내륙지선
# 9  중부내륙지선

# %%
df_name24_num.iloc[:] = '중부내륙고속도로지선'
df_name24_num
# Out:
#           도로명
# 0  중부내륙고속도로지선
# 1  중부내륙고속도로지선
# 2  중부내륙고속도로지선
# 3  중부내륙고속도로지선
# 4  중부내륙고속도로지선
# 5  중부내륙고속도로지선
# 6  중부내륙고속도로지선
# 7  중부내륙고속도로지선
# 8  중부내륙고속도로지선
# 9  중부내륙고속도로지선

# %%
df_name24_num1 = df_name24.reset_index(drop = True)
df_name24_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  240  4510VME00200  128.508056  35.817222   101  중부내륙지선   451  E
# 1  246  4510VME00300  128.531944  35.870556   101  중부내륙지선   451  E
# 2  241  4510VMS00300  128.507778  35.816944   101  중부내륙지선   451  S
# 3  197  4510VMX00100  128.474444  35.726667   101  중부내륙지선   451  X
# 4  239  4510VMX00150  128.484167  35.795278   101  중부내륙지선   451  X
# 5  242  4510VMX00200  128.524444  35.833611   101  중부내륙지선   451  X
# 6  243  4510VMX00300  128.527880  35.839187   101  중부내륙지선   451  X
# 7  245  4510VMX00400  128.521700  35.851667   101  중부내륙지선   451  X
# 8  244  4510VMX00500  128.524490  35.860278   101  중부내륙지선   451  X
# 9  247  4510VMX00600  128.525863  35.886389   101  중부내륙지선   451  X

# %%
df_name24_num1['도로명'] = df_name24_num['도로명']
df_name24_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급         도로명  노선번호 방향
# 0  240  4510VME00200  128.508056  35.817222   101  중부내륙고속도로지선   451  E
# 1  246  4510VME00300  128.531944  35.870556   101  중부내륙고속도로지선   451  E
# 2  241  4510VMS00300  128.507778  35.816944   101  중부내륙고속도로지선   451  S
# 3  197  4510VMX00100  128.474444  35.726667   101  중부내륙고속도로지선   451  X
# 4  239  4510VMX00150  128.484167  35.795278   101  중부내륙고속도로지선   451  X
# 5  242  4510VMX00200  128.524444  35.833611   101  중부내륙고속도로지선   451  X
# 6  243  4510VMX00300  128.527880  35.839187   101  중부내륙고속도로지선   451  X
# 7  245  4510VMX00400  128.521700  35.851667   101  중부내륙고속도로지선   451  X
# 8  244  4510VMX00500  128.524490  35.860278   101  중부내륙고속도로지선   451  X
# 9  247  4510VMX00600  128.525863  35.886389   101  중부내륙고속도로지선   451  X

# %%
df_name25 = df[df['도로명'] == '제2경인선']
df_name25
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 822  410  1100VME00100  126.694444  37.430278   101  제2경인선   110  E
# 823  412  1100VME00200  126.773889  37.428333   101  제2경인선   110  E
# 824  411  1100VMS00100  126.760000  37.429444   101  제2경인선   110  S
# 825  414  1100VMS00300  126.869722  37.392222   101  제2경인선   110  S
# 826  409  1100VMX00100  126.745556  37.440833   101  제2경인선   110  X
# 827  413  1100VMX00150  126.776111  37.436111   101  제2경인선   110  X
# 828   17  1100VMX00250  126.768611  37.419722   101  제2경인선   110  X

# %%
df_name25_num = df_name25.reset_index(drop = True)
df_name25_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  410  1100VME00100  126.694444  37.430278   101  제2경인선   110  E
# 1  412  1100VME00200  126.773889  37.428333   101  제2경인선   110  E
# 2  411  1100VMS00100  126.760000  37.429444   101  제2경인선   110  S
# 3  414  1100VMS00300  126.869722  37.392222   101  제2경인선   110  S
# 4  409  1100VMX00100  126.745556  37.440833   101  제2경인선   110  X
# 5  413  1100VMX00150  126.776111  37.436111   101  제2경인선   110  X
# 6   17  1100VMX00250  126.768611  37.419722   101  제2경인선   110  X

# %%
df_name25_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name25_num
# Out:
#      도로명
# 0  제2경인선
# 1  제2경인선
# 2  제2경인선
# 3  제2경인선
# 4  제2경인선
# 5  제2경인선
# 6  제2경인선

# %%
df_name25_num.iloc[:] = '제2경인고속도로'
df_name25_num
# Out:
#         도로명
# 0  제2경인고속도로
# 1  제2경인고속도로
# 2  제2경인고속도로
# 3  제2경인고속도로
# 4  제2경인고속도로
# 5  제2경인고속도로
# 6  제2경인고속도로

# %%
df_name25_num1 = df_name25.reset_index(drop = True)
df_name25_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  410  1100VME00100  126.694444  37.430278   101  제2경인선   110  E
# 1  412  1100VME00200  126.773889  37.428333   101  제2경인선   110  E
# 2  411  1100VMS00100  126.760000  37.429444   101  제2경인선   110  S
# 3  414  1100VMS00300  126.869722  37.392222   101  제2경인선   110  S
# 4  409  1100VMX00100  126.745556  37.440833   101  제2경인선   110  X
# 5  413  1100VMX00150  126.776111  37.436111   101  제2경인선   110  X
# 6   17  1100VMX00250  126.768611  37.419722   101  제2경인선   110  X

# %%
df_name25_num1['도로명'] = df_name25_num['도로명']
df_name25_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0  410  1100VME00100  126.694444  37.430278   101  제2경인고속도로   110  E
# 1  412  1100VME00200  126.773889  37.428333   101  제2경인고속도로   110  E
# 2  411  1100VMS00100  126.760000  37.429444   101  제2경인고속도로   110  S
# 3  414  1100VMS00300  126.869722  37.392222   101  제2경인고속도로   110  S
# 4  409  1100VMX00100  126.745556  37.440833   101  제2경인고속도로   110  X
# 5  413  1100VMX00150  126.776111  37.436111   101  제2경인고속도로   110  X
# 6   17  1100VMX00250  126.768611  37.419722   101  제2경인고속도로   110  X

# %%
df_name26 = df[df['도로명'] == '경인선']
df_name26
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 879  455  1200VME00100  126.641389  37.454167   101  경인선   120  E
# 880  456  1200VME00300  126.738611  37.523333   101  경인선   120  E
# 881  457  1200VMS00100  126.738611  37.523333   101  경인선   120  S
# 882  460  1200VMS00200  126.821389  37.520278   101  경인선   120  S
# 883  458  1200VMX00100  126.775278  37.520833   101  경인선   120  X
# 884  459  1200VMX00200  126.777500  37.525278   101  경인선   120  X

# %%
df_name26_num = df_name26.reset_index(drop = True)
df_name26_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  455  1200VME00100  126.641389  37.454167   101  경인선   120  E
# 1  456  1200VME00300  126.738611  37.523333   101  경인선   120  E
# 2  457  1200VMS00100  126.738611  37.523333   101  경인선   120  S
# 3  460  1200VMS00200  126.821389  37.520278   101  경인선   120  S
# 4  458  1200VMX00100  126.775278  37.520833   101  경인선   120  X
# 5  459  1200VMX00200  126.777500  37.525278   101  경인선   120  X

# %%
df_name26_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name26_num
# Out:
#    도로명
# 0  경인선
# 1  경인선
# 2  경인선
# 3  경인선
# 4  경인선
# 5  경인선

# %%
df_name26_num.iloc[:] = '경인고속도로'
df_name26_num
# Out:
#       도로명
# 0  경인고속도로
# 1  경인고속도로
# 2  경인고속도로
# 3  경인고속도로
# 4  경인고속도로
# 5  경인고속도로

# %%
df_name26_num1 = df_name26.reset_index(drop = True)
df_name26_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  455  1200VME00100  126.641389  37.454167   101  경인선   120  E
# 1  456  1200VME00300  126.738611  37.523333   101  경인선   120  E
# 2  457  1200VMS00100  126.738611  37.523333   101  경인선   120  S
# 3  460  1200VMS00200  126.821389  37.520278   101  경인선   120  S
# 4  458  1200VMX00100  126.775278  37.520833   101  경인선   120  X
# 5  459  1200VMX00200  126.777500  37.525278   101  경인선   120  X

# %%
df_name26_num1['도로명'] = df_name26_num['도로명']
df_name26_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  455  1200VME00100  126.641389  37.454167   101  경인고속도로   120  E
# 1  456  1200VME00300  126.738611  37.523333   101  경인고속도로   120  E
# 2  457  1200VMS00100  126.738611  37.523333   101  경인고속도로   120  S
# 3  460  1200VMS00200  126.821389  37.520278   101  경인고속도로   120  S
# 4  458  1200VMX00100  126.775278  37.520833   101  경인고속도로   120  X
# 5  459  1200VMX00200  126.777500  37.525278   101  경인고속도로   120  X

# %%
df_name27 = df[df['도로명'] == '남해제1지선']
df_name27
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 812  1084  1020VME00100  128.536667  35.241111   101  남해제1지선   102  E
# 813  1085  1020VMS00100  128.546111  35.238333   101  남해제1지선   102  S
# 814  1086  1020VMX00020  128.575833  35.226111   101  남해제1지선   102  X
# 815  1088  1020VMX00050  128.587222  35.238333   101  남해제1지선   102  X
# 816  1087  1020VMX00070  128.602222  35.248611   101  남해제1지선   102  X

# %%
df_name27_num = df_name27.reset_index(drop = True)
df_name27_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  1084  1020VME00100  128.536667  35.241111   101  남해제1지선   102  E
# 1  1085  1020VMS00100  128.546111  35.238333   101  남해제1지선   102  S
# 2  1086  1020VMX00020  128.575833  35.226111   101  남해제1지선   102  X
# 3  1088  1020VMX00050  128.587222  35.238333   101  남해제1지선   102  X
# 4  1087  1020VMX00070  128.602222  35.248611   101  남해제1지선   102  X

# %%
df_name27_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name27_num
# Out:
#       도로명
# 0  남해제1지선
# 1  남해제1지선
# 2  남해제1지선
# 3  남해제1지선
# 4  남해제1지선

# %%
df_name27_num.iloc[:] = '남해고속도로제1지선'
df_name27_num
# Out:
#           도로명
# 0  남해고속도로제1지선
# 1  남해고속도로제1지선
# 2  남해고속도로제1지선
# 3  남해고속도로제1지선
# 4  남해고속도로제1지선

# %%
df_name27_num1 = df_name27.reset_index(drop = True)
df_name27_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  1084  1020VME00100  128.536667  35.241111   101  남해제1지선   102  E
# 1  1085  1020VMS00100  128.546111  35.238333   101  남해제1지선   102  S
# 2  1086  1020VMX00020  128.575833  35.226111   101  남해제1지선   102  X
# 3  1088  1020VMX00050  128.587222  35.238333   101  남해제1지선   102  X
# 4  1087  1020VMX00070  128.602222  35.248611   101  남해제1지선   102  X

# %%
df_name27_num1['도로명'] = df_name27_num['도로명']
df_name27_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급         도로명  노선번호 방향
# 0  1084  1020VME00100  128.536667  35.241111   101  남해고속도로제1지선   102  E
# 1  1085  1020VMS00100  128.546111  35.238333   101  남해고속도로제1지선   102  S
# 2  1086  1020VMX00020  128.575833  35.226111   101  남해고속도로제1지선   102  X
# 3  1088  1020VMX00050  128.587222  35.238333   101  남해고속도로제1지선   102  X
# 4  1087  1020VMX00070  128.602222  35.248611   101  남해고속도로제1지선   102  X

# %%
df_name28 = df[df['도로명'] == '남해제2지선']
df_name28
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 817  1090  1040VME00100  128.879722  35.166667   101  남해제2지선   104  E
# 818  1089  1040VMX00100  128.793889  35.185833   101  남해제2지선   104  X
# 819  1091  1040VMX00200  128.887778  35.154722   101  남해제2지선   104  X
# 820  1092  1040VMX00300  128.955278  35.146944   101  남해제2지선   104  X
# 821  1093  1040VMX00400  128.991389  35.145000   101  남해제2지선   104  X

# %%
df_name28_num = df_name28.reset_index(drop = True)
df_name28_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  1090  1040VME00100  128.879722  35.166667   101  남해제2지선   104  E
# 1  1089  1040VMX00100  128.793889  35.185833   101  남해제2지선   104  X
# 2  1091  1040VMX00200  128.887778  35.154722   101  남해제2지선   104  X
# 3  1092  1040VMX00300  128.955278  35.146944   101  남해제2지선   104  X
# 4  1093  1040VMX00400  128.991389  35.145000   101  남해제2지선   104  X

# %%
df_name28_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name28_num
# Out:
#       도로명
# 0  남해제2지선
# 1  남해제2지선
# 2  남해제2지선
# 3  남해제2지선
# 4  남해제2지선

# %%
df_name28_num.iloc[:] = '남해고속도로제2지선'
df_name28_num
# Out:
#           도로명
# 0  남해고속도로제2지선
# 1  남해고속도로제2지선
# 2  남해고속도로제2지선
# 3  남해고속도로제2지선
# 4  남해고속도로제2지선

# %%
df_name28_num1 = df_name28.reset_index(drop = True)
df_name28_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  1090  1040VME00100  128.879722  35.166667   101  남해제2지선   104  E
# 1  1089  1040VMX00100  128.793889  35.185833   101  남해제2지선   104  X
# 2  1091  1040VMX00200  128.887778  35.154722   101  남해제2지선   104  X
# 3  1092  1040VMX00300  128.955278  35.146944   101  남해제2지선   104  X
# 4  1093  1040VMX00400  128.991389  35.145000   101  남해제2지선   104  X

# %%
df_name28_num1['도로명'] = df_name28_num['도로명']
df_name28_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급         도로명  노선번호 방향
# 0  1090  1040VME00100  128.879722  35.166667   101  남해고속도로제2지선   104  E
# 1  1089  1040VMX00100  128.793889  35.185833   101  남해고속도로제2지선   104  X
# 2  1091  1040VMX00200  128.887778  35.154722   101  남해고속도로제2지선   104  X
# 3  1092  1040VMX00300  128.955278  35.146944   101  남해고속도로제2지선   104  X
# 4  1093  1040VMX00400  128.991389  35.145000   101  남해고속도로제2지선   104  X

# %%
df_name29 = df[df['도로명'] == '봉담동탄선']
df_name29
# Out:
#         순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 233   1120  010411VMS12403  127.024444  37.172778   101  봉담동탄선   400  S
# 234   1118  010411VMS12703  127.088611  37.178333   101  봉담동탄선   400  S
# 345   1119  020001VMS21004  127.053889  37.180000   101  봉담동탄선   400  S
# 1317   397    4000VME00100  127.063056  37.183611   101  봉담동탄선   400  E
# 1318   398    4000VME00200  127.029722  37.174444   101  봉담동탄선   400  E

# %%
df_name29_num = df_name29.reset_index(drop = True)
df_name29_num
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  1120  010411VMS12403  127.024444  37.172778   101  봉담동탄선   400  S
# 1  1118  010411VMS12703  127.088611  37.178333   101  봉담동탄선   400  S
# 2  1119  020001VMS21004  127.053889  37.180000   101  봉담동탄선   400  S
# 3   397    4000VME00100  127.063056  37.183611   101  봉담동탄선   400  E
# 4   398    4000VME00200  127.029722  37.174444   101  봉담동탄선   400  E

# %%
df_name29_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name29_num
# Out:
#      도로명
# 0  봉담동탄선
# 1  봉담동탄선
# 2  봉담동탄선
# 3  봉담동탄선
# 4  봉담동탄선

# %%
df_name29_num.iloc[:] = '수도권제2순환고속도로'
df_name29_num
# Out:
#            도로명
# 0  수도권제2순환고속도로
# 1  수도권제2순환고속도로
# 2  수도권제2순환고속도로
# 3  수도권제2순환고속도로
# 4  수도권제2순환고속도로

# %%
df_name29_num1 = df_name29.reset_index(drop = True)
df_name29_num1
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  1120  010411VMS12403  127.024444  37.172778   101  봉담동탄선   400  S
# 1  1118  010411VMS12703  127.088611  37.178333   101  봉담동탄선   400  S
# 2  1119  020001VMS21004  127.053889  37.180000   101  봉담동탄선   400  S
# 3   397    4000VME00100  127.063056  37.183611   101  봉담동탄선   400  E
# 4   398    4000VME00200  127.029722  37.174444   101  봉담동탄선   400  E

# %%
df_name29_num1['도로명'] = df_name29_num['도로명']
df_name29_num1
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급          도로명  노선번호 방향
# 0  1120  010411VMS12403  127.024444  37.172778   101  수도권제2순환고속도로   400  S
# 1  1118  010411VMS12703  127.088611  37.178333   101  수도권제2순환고속도로   400  S
# 2  1119  020001VMS21004  127.053889  37.180000   101  수도권제2순환고속도로   400  S
# 3   397    4000VME00100  127.063056  37.183611   101  수도권제2순환고속도로   400  E
# 4   398    4000VME00200  127.029722  37.174444   101  수도권제2순환고속도로   400  E

# %%
df_name30 = df[df['도로명'] == '울산선']
df_name30
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 334  141  0160VMS00200  129.143889  35.598056   101  울산선    16  S
# 335  143  0160VMX00100  129.265556  35.547222   101  울산선    16  X
# 336  142  0160VMX00200  129.296944  35.517500   101  울산선    16  X

# %%
df_name30_num = df_name30.reset_index(drop = True)
df_name30_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  141  0160VMS00200  129.143889  35.598056   101  울산선    16  S
# 1  143  0160VMX00100  129.265556  35.547222   101  울산선    16  X
# 2  142  0160VMX00200  129.296944  35.517500   101  울산선    16  X

# %%
df_name30_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name30_num
# Out:
#    도로명
# 0  울산선
# 1  울산선
# 2  울산선

# %%
df_name30_num.iloc[:] = '울산고속도로'
df_name30_num
# Out:
#       도로명
# 0  울산고속도로
# 1  울산고속도로
# 2  울산고속도로

# %%
df_name30_num1 = df_name30.reset_index(drop = True)
df_name30_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  141  0160VMS00200  129.143889  35.598056   101  울산선    16  S
# 1  143  0160VMX00100  129.265556  35.547222   101  울산선    16  X
# 2  142  0160VMX00200  129.296944  35.517500   101  울산선    16  X

# %%
df_name30_num1['도로명'] = df_name30_num['도로명']
df_name30_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  141  0160VMS00200  129.143889  35.598056   101  울산고속도로    16  S
# 1  143  0160VMX00100  129.265556  35.547222   101  울산고속도로    16  X
# 2  142  0160VMX00200  129.296944  35.517500   101  울산고속도로    16  X

# %%
df_name31 = df[df['도로명'] == '중앙선지선']
df_name31
# Out:
#        순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 1487  138  5510VMS00100  129.014722  35.316944   101  중앙선지선   551  S
# 1488  137  5510VMX00100  129.017500  35.275000   101  중앙선지선   551  X
# 1489  139  5510VMX00200  129.029722  35.318889   101  중앙선지선   551  X

# %%
df_name31_num = df_name31.reset_index(drop = True)
df_name31_num
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  138  5510VMS00100  129.014722  35.316944   101  중앙선지선   551  S
# 1  137  5510VMX00100  129.017500  35.275000   101  중앙선지선   551  X
# 2  139  5510VMX00200  129.029722  35.318889   101  중앙선지선   551  X

# %%
df_name31_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name31_num
# Out:
#      도로명
# 0  중앙선지선
# 1  중앙선지선
# 2  중앙선지선

# %%
df_name31_num.iloc[:] = '중앙고속도로지선'
df_name31_num
# Out:
#         도로명
# 0  중앙고속도로지선
# 1  중앙고속도로지선
# 2  중앙고속도로지선

# %%
df_name31_num1 = df_name31.reset_index(drop = True)
df_name31_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  138  5510VMS00100  129.014722  35.316944   101  중앙선지선   551  S
# 1  137  5510VMX00100  129.017500  35.275000   101  중앙선지선   551  X
# 2  139  5510VMX00200  129.029722  35.318889   101  중앙선지선   551  X

# %%
df_name31_num1['도로명'] = df_name31_num['도로명']
df_name31_num1
# Out:
#     순번        VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0  138  5510VMS00100  129.014722  35.316944   101  중앙고속도로지선   551  S
# 1  137  5510VMX00100  129.017500  35.275000   101  중앙고속도로지선   551  X
# 2  139  5510VMX00200  129.029722  35.318889   101  중앙고속도로지선   551  X

# %%
df_name32 = df[df['도로명'] == '오산화성선']
df_name32
# Out:
#         순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 229   1117  010411VME11901  127.010278  37.188611   101  오산화성선   171  E
# 1319   396    4000VMS00200  127.010278  37.188611   101  오산화성선   171  S

# %%
df_name32_num = df_name32.reset_index(drop = True)
df_name32_num
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  1117  010411VME11901  127.010278  37.188611   101  오산화성선   171  E
# 1   396    4000VMS00200  127.010278  37.188611   101  오산화성선   171  S

# %%
df_name32_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name32_num
# Out:
#      도로명
# 0  오산화성선
# 1  오산화성선

# %%
df_name32_num.iloc[:] = '오산화성고속도로'
df_name32_num
# Out:
#         도로명
# 0  오산화성고속도로
# 1  오산화성고속도로

# %%
df_name32_num1 = df_name32.reset_index(drop = True)
df_name32_num1
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0  1117  010411VME11901  127.010278  37.188611   101  오산화성선   171  E
# 1   396    4000VMS00200  127.010278  37.188611   101  오산화성선   171  S

# %%
df_name32_num1['도로명'] = df_name32_num['도로명']
df_name32_num1
# Out:
#      순번          VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0  1117  010411VME11901  127.010278  37.188611   101  오산화성고속도로   171  E
# 1   396    4000VMS00200  127.010278  37.188611   101  오산화성고속도로   171  S

# %%
df_name33 = df[df['도로명'] == '부산울산선']
df_name33
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 754  144  0651VME00100  129.205278  35.212222   101  부산울산선   651  E
# 755  148  0651VME00200  129.208056  35.257500   101  부산울산선   651  E
# 756  150  0651VME00300  129.227778  35.299444   101  부산울산선   651  E
# 757  154  0651VME00400  129.251944  35.365000   101  부산울산선   651  E
# 758  157  0651VME00500  129.282222  35.451667   101  부산울산선   651  E
# 759  159  0651VME00600  129.269167  35.495000   101  부산울산선   651  E
# 760  147  0651VMS00100  129.205278  35.235833   101  부산울산선   651  S
# 761  151  0651VMS00200  129.229167  35.311389   101  부산울산선   651  S
# 762  153  0651VMS00300  129.251944  35.364167   101  부산울산선   651  S
# 763  156  0651VMS00400  129.274444  35.428333   101  부산울산선   651  S
# 764  160  0651VMS00500  129.263056  35.498611   101  부산울산선   651  S
# 765  145  0651VMX00100  129.165000  35.175556   101  부산울산선   651  X
# 766  146  0651VMX00200  129.205556  35.195833   101  부산울산선   651  X
# ...

# %%
df_name33_num = df_name33.reset_index(drop = True)
df_name33_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   144  0651VME00100  129.205278  35.212222   101  부산울산선   651  E
# 1   148  0651VME00200  129.208056  35.257500   101  부산울산선   651  E
# 2   150  0651VME00300  129.227778  35.299444   101  부산울산선   651  E
# 3   154  0651VME00400  129.251944  35.365000   101  부산울산선   651  E
# 4   157  0651VME00500  129.282222  35.451667   101  부산울산선   651  E
# 5   159  0651VME00600  129.269167  35.495000   101  부산울산선   651  E
# 6   147  0651VMS00100  129.205278  35.235833   101  부산울산선   651  S
# 7   151  0651VMS00200  129.229167  35.311389   101  부산울산선   651  S
# 8   153  0651VMS00300  129.251944  35.364167   101  부산울산선   651  S
# 9   156  0651VMS00400  129.274444  35.428333   101  부산울산선   651  S
# 10  160  0651VMS00500  129.263056  35.498611   101  부산울산선   651  S
# 11  145  0651VMX00100  129.165000  35.175556   101  부산울산선   651  X
# 12  146  0651VMX00200  129.205556  35.195833   101  부산울산선   651  X
# ...

# %%
df_name33_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name33_num
# Out:
#       도로명
# 0   부산울산선
# 1   부산울산선
# 2   부산울산선
# 3   부산울산선
# 4   부산울산선
# 5   부산울산선
# 6   부산울산선
# 7   부산울산선
# 8   부산울산선
# 9   부산울산선
# 10  부산울산선
# 11  부산울산선
# 12  부산울산선
# 13  부산울산선
# 14  부산울산선
# 15  부산울산선
# 16  부산울산선
# 17  부산울산선
# 18  부산울산선

# %%
df_name33_num.iloc[:] = '동해고속도로'
df_name33_num
# Out:
#        도로명
# 0   동해고속도로
# 1   동해고속도로
# 2   동해고속도로
# 3   동해고속도로
# 4   동해고속도로
# 5   동해고속도로
# 6   동해고속도로
# 7   동해고속도로
# 8   동해고속도로
# 9   동해고속도로
# 10  동해고속도로
# 11  동해고속도로
# 12  동해고속도로
# 13  동해고속도로
# 14  동해고속도로
# 15  동해고속도로
# 16  동해고속도로
# 17  동해고속도로
# 18  동해고속도로

# %%
df_name33_num2 = df_name33.reset_index(drop = True)
df_name33_num2
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   144  0651VME00100  129.205278  35.212222   101  부산울산선   651  E
# 1   148  0651VME00200  129.208056  35.257500   101  부산울산선   651  E
# 2   150  0651VME00300  129.227778  35.299444   101  부산울산선   651  E
# 3   154  0651VME00400  129.251944  35.365000   101  부산울산선   651  E
# 4   157  0651VME00500  129.282222  35.451667   101  부산울산선   651  E
# 5   159  0651VME00600  129.269167  35.495000   101  부산울산선   651  E
# 6   147  0651VMS00100  129.205278  35.235833   101  부산울산선   651  S
# 7   151  0651VMS00200  129.229167  35.311389   101  부산울산선   651  S
# 8   153  0651VMS00300  129.251944  35.364167   101  부산울산선   651  S
# 9   156  0651VMS00400  129.274444  35.428333   101  부산울산선   651  S
# 10  160  0651VMS00500  129.263056  35.498611   101  부산울산선   651  S
# 11  145  0651VMX00100  129.165000  35.175556   101  부산울산선   651  X
# 12  146  0651VMX00200  129.205556  35.195833   101  부산울산선   651  X
# ...

# %%
df_name33_num2.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '도로명', '방향'], axis = 1, inplace = True)
df_name33_num2
# Out:
#     노선번호
# 0    651
# 1    651
# 2    651
# 3    651
# 4    651
# 5    651
# 6    651
# 7    651
# 8    651
# 9    651
# 10   651
# 11   651
# 12   651
# 13   651
# 14   651
# 15   651
# 16   651
# 17   651
# 18   651

# %%
df_name33_num2.iloc[:] = '65'
df_name33_num2
# Out:
#    노선번호
# 0    65
# 1    65
# 2    65
# 3    65
# 4    65
# 5    65
# 6    65
# 7    65
# 8    65
# 9    65
# 10   65
# 11   65
# 12   65
# 13   65
# 14   65
# 15   65
# 16   65
# 17   65
# 18   65

# %%
df_name33_num1 = df_name33.reset_index(drop = True)
df_name33_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급    도로명  노선번호 방향
# 0   144  0651VME00100  129.205278  35.212222   101  부산울산선   651  E
# 1   148  0651VME00200  129.208056  35.257500   101  부산울산선   651  E
# 2   150  0651VME00300  129.227778  35.299444   101  부산울산선   651  E
# 3   154  0651VME00400  129.251944  35.365000   101  부산울산선   651  E
# 4   157  0651VME00500  129.282222  35.451667   101  부산울산선   651  E
# 5   159  0651VME00600  129.269167  35.495000   101  부산울산선   651  E
# 6   147  0651VMS00100  129.205278  35.235833   101  부산울산선   651  S
# 7   151  0651VMS00200  129.229167  35.311389   101  부산울산선   651  S
# 8   153  0651VMS00300  129.251944  35.364167   101  부산울산선   651  S
# 9   156  0651VMS00400  129.274444  35.428333   101  부산울산선   651  S
# 10  160  0651VMS00500  129.263056  35.498611   101  부산울산선   651  S
# 11  145  0651VMX00100  129.165000  35.175556   101  부산울산선   651  X
# 12  146  0651VMX00200  129.205556  35.195833   101  부산울산선   651  X
# ...

# %%
df_name33_num1['도로명'] = df_name33_num['도로명']
df_name33_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0   144  0651VME00100  129.205278  35.212222   101  동해고속도로   651  E
# 1   148  0651VME00200  129.208056  35.257500   101  동해고속도로   651  E
# 2   150  0651VME00300  129.227778  35.299444   101  동해고속도로   651  E
# 3   154  0651VME00400  129.251944  35.365000   101  동해고속도로   651  E
# 4   157  0651VME00500  129.282222  35.451667   101  동해고속도로   651  E
# 5   159  0651VME00600  129.269167  35.495000   101  동해고속도로   651  E
# 6   147  0651VMS00100  129.205278  35.235833   101  동해고속도로   651  S
# 7   151  0651VMS00200  129.229167  35.311389   101  동해고속도로   651  S
# 8   153  0651VMS00300  129.251944  35.364167   101  동해고속도로   651  S
# 9   156  0651VMS00400  129.274444  35.428333   101  동해고속도로   651  S
# 10  160  0651VMS00500  129.263056  35.498611   101  동해고속도로   651  S
# 11  145  0651VMX00100  129.165000  35.175556   101  동해고속도로   651  X
# 12  146  0651VMX00200  129.205556  35.195833   101  동해고속도로   651  X
# ...

# %%
df_name33_num1['노선번호'] = df_name33_num2['노선번호']
df_name33_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명 노선번호 방향
# 0   144  0651VME00100  129.205278  35.212222   101  동해고속도로   65  E
# 1   148  0651VME00200  129.208056  35.257500   101  동해고속도로   65  E
# 2   150  0651VME00300  129.227778  35.299444   101  동해고속도로   65  E
# 3   154  0651VME00400  129.251944  35.365000   101  동해고속도로   65  E
# 4   157  0651VME00500  129.282222  35.451667   101  동해고속도로   65  E
# 5   159  0651VME00600  129.269167  35.495000   101  동해고속도로   65  E
# 6   147  0651VMS00100  129.205278  35.235833   101  동해고속도로   65  S
# 7   151  0651VMS00200  129.229167  35.311389   101  동해고속도로   65  S
# 8   153  0651VMS00300  129.251944  35.364167   101  동해고속도로   65  S
# 9   156  0651VMS00400  129.274444  35.428333   101  동해고속도로   65  S
# 10  160  0651VMS00500  129.263056  35.498611   101  동해고속도로   65  S
# 11  145  0651VMX00100  129.165000  35.175556   101  동해고속도로   65  X
# 12  146  0651VMX00200  129.205556  35.195833   101  동해고속도로   65  X
# ...

# %%
df_name34 = df[df['도로명'] == '대전남부순환선']
df_name34
# Out:
#         순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 1144  1285  3000VME00100  127.413889  36.273611   101  대전남부순환선   300  E
# 1145  1283  3000VMS00100  127.363889  36.285556   101  대전남부순환선   300  S
# 1146  1282  3000VMX00700  127.321944  36.297222   101  대전남부순환선   300  X
# 1147  1284  3000VMX00800  127.378333  36.286944   101  대전남부순환선   300  X

# %%
df_name34_num = df_name34.reset_index(drop = True)
df_name34_num
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 0  1285  3000VME00100  127.413889  36.273611   101  대전남부순환선   300  E
# 1  1283  3000VMS00100  127.363889  36.285556   101  대전남부순환선   300  S
# 2  1282  3000VMX00700  127.321944  36.297222   101  대전남부순환선   300  X
# 3  1284  3000VMX00800  127.378333  36.286944   101  대전남부순환선   300  X

# %%
df_name34_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_name34_num
# Out:
#        도로명
# 0  대전남부순환선
# 1  대전남부순환선
# 2  대전남부순환선
# 3  대전남부순환선

# %%
df_name34_num.iloc[:] = '대전남부순환고속도로'
df_name34_num
# Out:
#           도로명
# 0  대전남부순환고속도로
# 1  대전남부순환고속도로
# 2  대전남부순환고속도로
# 3  대전남부순환고속도로

# %%
df_name34_num1 = df_name34.reset_index(drop = True)
df_name34_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급      도로명  노선번호 방향
# 0  1285  3000VME00100  127.413889  36.273611   101  대전남부순환선   300  E
# 1  1283  3000VMS00100  127.363889  36.285556   101  대전남부순환선   300  S
# 2  1282  3000VMX00700  127.321944  36.297222   101  대전남부순환선   300  X
# 3  1284  3000VMX00800  127.378333  36.286944   101  대전남부순환선   300  X

# %%
df_name34_num1['도로명'] = df_name34_num['도로명']
df_name34_num1
# Out:
#      순번        VMS_ID       좌표(X)      좌표(Y)  도로등급         도로명  노선번호 방향
# 0  1285  3000VME00100  127.413889  36.273611   101  대전남부순환고속도로   300  E
# 1  1283  3000VMS00100  127.363889  36.285556   101  대전남부순환고속도로   300  S
# 2  1282  3000VMX00700  127.321944  36.297222   101  대전남부순환고속도로   300  X
# 3  1284  3000VMX00800  127.378333  36.286944   101  대전남부순환고속도로   300  X

# %% [markdown]
# ## 파일 합치기

# %%
df_name_all = pd.concat([df_name1_num1, df_name2_num1, df_name3_num1, df_name4_num1, df_name5_num1, df_name6_num1, df_name7_num1, df_name8_num1, df_name9_num1, df_name10_num1, df_name11_num1, df_name12_num1, df_name13_num1, df_name14_num1, df_name15_num1, df_name16_num1, df_name17_num1, df_name18_num1, df_name19_num1, df_name20_num1, df_name21_num1, df_name22_num1, df_name23_num1, df_name24_num1, df_name25_num1, df_name26_num1, df_name27_num1, df_name28_num1, df_name29_num1, df_name30_num1, df_name31_num1, df_name32_num1, df_name33_num1, df_name34_num1])
df_name_all
# Out:
#       순번        VMS_ID       좌표(X)      좌표(Y)  도로등급         도로명 노선번호 방향
# 0    112  0010VME00100  129.105278  35.279167   101      경부고속도로    1  E
# 1    114  0010VME00200  129.061944  35.317778   101      경부고속도로    1  E
# 2    118  0010VME00400  129.088611  35.466111   101      경부고속도로    1  E
# 3    120  0010VME00500  129.106944  35.519167   101      경부고속도로    1  E
# 4    248  0010VME00600  129.113944  35.830778   101      경부고속도로    1  E
# ..   ...           ...         ...        ...   ...         ...  ... ..
# 18   161  0651VMX00800  129.243611  35.523056   101      동해고속도로   65  X
# 0   1285  3000VME00100  127.413889  36.273611   101  대전남부순환고속도로  300  E
# 1   1283  3000VMS00100  127.363889  36.285556   101  대전남부순환고속도로  300  S
# 2   1282  3000VMX00700  127.321944  36.297222   101  대전남부순환고속도로  300  X
# 3   1284  3000VMX00800  127.378333  36.286944   101  대전남부순환고속도로  300  X
#
# [890 rows x 8 columns]

# %% [markdown]
# ## 확인

# %%
df_all = df_name_all['도로명'].value_counts().index.tolist()
df_all
# Out:
# ['경부고속도로',
#  '남해고속도로',
#  '영동고속도로',
#  '중부고속도로',
#  '서산영덕고속도로',
#  '중부내륙고속도로',
#  '서해안고속도로',
#  '호남고속도로',
#  '동해고속도로',
#  '수도권제1순환선',
#  '중앙고속도로',
#  '평택제천고속도로',
#  '새만금포항고속도로',
#  '무안광주고속도로',
#  '순천완주고속도로',
#  '서천공주고속도로',
#  '호남고속도로지선',
#  '서울양양고속도로',
#  '광주대구고속도로',
#  '고창담양고속도로',
#  '평택화성고속도로',
#  '중부내륙고속도로지선',
#  '제2경인고속도로',
#  '경인고속도로',
#  '남해고속도로제1지선',
#  '남해고속도로제2지선',
#  '수도권제2순환고속도로',
#  '대전남부순환고속도로',
#  '울산고속도로',
#  '중앙고속도로지선',
#  '오산화성고속도로']

# %%
len(df_all)
# Out:
# 31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순번      1490 non-null   int64
#  1   VMS_ID  1490 non-null   object
#  2   좌표(X)   1490 non-null   float64
#  3   좌표(Y)   1490 non-null   float64
#  4   도로등급    1490 non-null   int64
#  5   도로명     890 non-null    object
#  6   노선번호    1490 non-null   int64
#  7   방향      1490 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.2+ KB

# %% [markdown]
# ## 결측치 변경

# %%
df_null = df.loc[df['도로명'].isna()]
df_null
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 829    591  12001VME00101  127.072175  37.016314   103  NaN     1  E
# 830    592  12001VME00201  127.116036  36.978978   103  NaN     1  E
# 831    594  12001VME00401  127.064989  37.042178   103  NaN     1  E
# 832    596  12001VME00601  127.065403  37.121278   103  NaN     1  E
# 833    598  12001VME00801  127.041856  37.196414   103  NaN     1  E
# ...    ...            ...         ...        ...   ...  ...   ... ..
# 1482  1049  52022VME50101  126.972996  35.046152   103  NaN    22  E
# 1483  1048  52022VMS50001  126.925582  35.136574   103  NaN    22  S
# 1484  1075  52026VME21101  127.277909  35.841145   103  NaN    26  E
# 1485  1074  52026VMN21001  126.973701  35.886580   103  NaN    26  N
# 1486  1076  52026VMS21201  127.328327  35.856220   103  NaN    26  S
#
# [600 rows x 8 columns]

# %%
df_null_all = df_null['노선번호'].value_counts().index.tolist()
df_null_all
# Out:
# [1,
#  4,
#  7,
#  6,
#  17,
#  42,
#  21,
#  39,
#  45,
#  38,
#  3,
#  14,
#  23,
#  32,
#  43,
#  5,
#  35,
#  36,
#  46,
#  77,
#  34,
#  47,
#  2,
#  82,
#  44,
#  29,
#  19,
#  25,
#  999,
#  99,
#  96,
#  40,
#  37,
#  28,
#  946,
#  33,
#  13,
#  26,
#  312,
#  306,
#  903,
#  22,
#  189,
#  68,
#  10,
#  399,
#  340,
#  329,
#  88]

# %%
len(df_null_all)
# Out:
# 49

# %%
df_null1 = df_null[df_null['노선번호'] == 1]
df_null1
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 829    591  12001VME00101  127.072175  37.016314   103  NaN     1  E
# 830    592  12001VME00201  127.116036  36.978978   103  NaN     1  E
# 831    594  12001VME00401  127.064989  37.042178   103  NaN     1  E
# 832    596  12001VME00601  127.065403  37.121278   103  NaN     1  E
# 833    598  12001VME00801  127.041856  37.196414   103  NaN     1  E
# 834    600  12001VME01551  126.888083  37.680833   103  NaN     1  E
# 835    602  12001VME01601  126.847783  37.721369   103  NaN     1  E
# 836    604  12001VME01801  126.788403  37.780469   103  NaN     1  E
# 837    606  12001VME02001  126.788689  37.854094   103  NaN     1  E
# 838    593  12001VMS00301  127.099156  37.001044   103  NaN     1  S
# 839    595  12001VMS00501  127.063594  37.095144   103  NaN     1  S
# 840    597  12001VMS00701  127.069164  37.160467   103  NaN     1  S
# 841    599  12001VMS00901  127.038403  37.203114   103  NaN     1  S
# ...

# %%
df_null1_num = df_null1.reset_index(drop = True)
df_null1_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    591  12001VME00101  127.072175  37.016314   103  NaN     1  E
# 1    592  12001VME00201  127.116036  36.978978   103  NaN     1  E
# 2    594  12001VME00401  127.064989  37.042178   103  NaN     1  E
# 3    596  12001VME00601  127.065403  37.121278   103  NaN     1  E
# 4    598  12001VME00801  127.041856  37.196414   103  NaN     1  E
# 5    600  12001VME01551  126.888083  37.680833   103  NaN     1  E
# 6    602  12001VME01601  126.847783  37.721369   103  NaN     1  E
# 7    604  12001VME01801  126.788403  37.780469   103  NaN     1  E
# 8    606  12001VME02001  126.788689  37.854094   103  NaN     1  E
# 9    593  12001VMS00301  127.099156  37.001044   103  NaN     1  S
# 10   595  12001VMS00501  127.063594  37.095144   103  NaN     1  S
# 11   597  12001VMS00701  127.069164  37.160467   103  NaN     1  S
# 12   599  12001VMS00901  127.038403  37.203114   103  NaN     1  S
# ...

# %%
df_null1_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null1_num
# Out:
#     도로명
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  NaN
# 34  NaN
# 35  NaN
# 36  NaN
# 37  NaN
# 38  NaN
# 39  NaN
# 40  NaN
# 41  NaN
# 42  NaN
# 43  NaN
# 44  NaN
# 45  NaN
# 46  NaN
# 47  NaN
# 48  NaN
# 49  NaN
# 50  NaN

# %%
df_null1_num.iloc[:] = '경부고속도로'
df_null1_num
# Out:
#        도로명
# 0   경부고속도로
# 1   경부고속도로
# 2   경부고속도로
# 3   경부고속도로
# 4   경부고속도로
# 5   경부고속도로
# 6   경부고속도로
# 7   경부고속도로
# 8   경부고속도로
# 9   경부고속도로
# 10  경부고속도로
# 11  경부고속도로
# 12  경부고속도로
# 13  경부고속도로
# 14  경부고속도로
# 15  경부고속도로
# 16  경부고속도로
# 17  경부고속도로
# 18  경부고속도로
# 19  경부고속도로
# 20  경부고속도로
# 21  경부고속도로
# 22  경부고속도로
# 23  경부고속도로
# 24  경부고속도로
# 25  경부고속도로
# 26  경부고속도로
# 27  경부고속도로
# 28  경부고속도로
# 29  경부고속도로
# 30  경부고속도로
# 31  경부고속도로
# 32  경부고속도로
# 33  경부고속도로
# 34  경부고속도로
# 35  경부고속도로
# 36  경부고속도로
# 37  경부고속도로
# 38  경부고속도로
# 39  경부고속도로
# 40  경부고속도로
# 41  경부고속도로
# 42  경부고속도로
# 43  경부고속도로
# 44  경부고속도로
# 45  경부고속도로
# 46  경부고속도로
# 47  경부고속도로
# 48  경부고속도로
# 49  경부고속도로
# 50  경부고속도로

# %%
df_null1_num1 = df_null1.reset_index(drop = True)
df_null1_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    591  12001VME00101  127.072175  37.016314   103  NaN     1  E
# 1    592  12001VME00201  127.116036  36.978978   103  NaN     1  E
# 2    594  12001VME00401  127.064989  37.042178   103  NaN     1  E
# 3    596  12001VME00601  127.065403  37.121278   103  NaN     1  E
# 4    598  12001VME00801  127.041856  37.196414   103  NaN     1  E
# 5    600  12001VME01551  126.888083  37.680833   103  NaN     1  E
# 6    602  12001VME01601  126.847783  37.721369   103  NaN     1  E
# 7    604  12001VME01801  126.788403  37.780469   103  NaN     1  E
# 8    606  12001VME02001  126.788689  37.854094   103  NaN     1  E
# 9    593  12001VMS00301  127.099156  37.001044   103  NaN     1  S
# 10   595  12001VMS00501  127.063594  37.095144   103  NaN     1  S
# 11   597  12001VMS00701  127.069164  37.160467   103  NaN     1  S
# 12   599  12001VMS00901  127.038403  37.203114   103  NaN     1  S
# ...

# %%
df_null1_num1['도로명'] = df_null1_num['도로명']
df_null1_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0    591  12001VME00101  127.072175  37.016314   103  경부고속도로     1  E
# 1    592  12001VME00201  127.116036  36.978978   103  경부고속도로     1  E
# 2    594  12001VME00401  127.064989  37.042178   103  경부고속도로     1  E
# 3    596  12001VME00601  127.065403  37.121278   103  경부고속도로     1  E
# 4    598  12001VME00801  127.041856  37.196414   103  경부고속도로     1  E
# 5    600  12001VME01551  126.888083  37.680833   103  경부고속도로     1  E
# 6    602  12001VME01601  126.847783  37.721369   103  경부고속도로     1  E
# 7    604  12001VME01801  126.788403  37.780469   103  경부고속도로     1  E
# 8    606  12001VME02001  126.788689  37.854094   103  경부고속도로     1  E
# 9    593  12001VMS00301  127.099156  37.001044   103  경부고속도로     1  S
# 10   595  12001VMS00501  127.063594  37.095144   103  경부고속도로     1  S
# 11   597  12001VMS00701  127.069164  37.160467   103  경부고속도로     1  S
# ...

# %%
df_null2 = df_null[df_null['노선번호'] == 17]
df_null2
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 885    642  12017VME00201  127.425144  37.071961   103  NaN    17  E
# 886    644  12017VME00401  127.413561  37.126372   103  NaN    17  E
# 887    646  12017VME00551  127.324370  37.203740   103  NaN    17  E
# 888    641  12017VMS00101  127.410322  37.059547   103  NaN    17  S
# 889    643  12017VMS00301  127.433550  37.096731   103  NaN    17  S
# 890    645  12017VMS00501  127.387375  37.146306   103  NaN    17  S
# 891    647  12017VMS00601  127.311420  37.222710   103  NaN    17  S
# 1185   983  32017VME78101  127.424973  36.490878   103  NaN    17  E
# 1186   949  32017VME78301  127.469842  36.591470   103  NaN    17  E
# 1187   936  32017VME78501  127.499479  36.674247   103  NaN    17  E
# 1188   950  32017VME78701  127.471382  36.719450   103  NaN    17  E
# 1189   951  32017VME78902  127.441624  36.770335   103  NaN    17  E
# 1190   952  32017VME79001  127.428851  36.845201   103  NaN    17  E
# ...

# %%
df_null2_num = df_null2.reset_index(drop = True)
df_null2_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    642  12017VME00201  127.425144  37.071961   103  NaN    17  E
# 1    644  12017VME00401  127.413561  37.126372   103  NaN    17  E
# 2    646  12017VME00551  127.324370  37.203740   103  NaN    17  E
# 3    641  12017VMS00101  127.410322  37.059547   103  NaN    17  S
# 4    643  12017VMS00301  127.433550  37.096731   103  NaN    17  S
# 5    645  12017VMS00501  127.387375  37.146306   103  NaN    17  S
# 6    647  12017VMS00601  127.311420  37.222710   103  NaN    17  S
# 7    983  32017VME78101  127.424973  36.490878   103  NaN    17  E
# 8    949  32017VME78301  127.469842  36.591470   103  NaN    17  E
# 9    936  32017VME78501  127.499479  36.674247   103  NaN    17  E
# 10   950  32017VME78701  127.471382  36.719450   103  NaN    17  E
# 11   951  32017VME78902  127.441624  36.770335   103  NaN    17  E
# 12   952  32017VME79001  127.428851  36.845201   103  NaN    17  E
# ...

# %%
df_null2_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null2_num
# Out:
#     도로명
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  NaN
# 34  NaN

# %%
df_null2_num.iloc[:] = '평택파주고속도로'
df_null2_num
# Out:
#          도로명
# 0   평택파주고속도로
# 1   평택파주고속도로
# 2   평택파주고속도로
# 3   평택파주고속도로
# 4   평택파주고속도로
# 5   평택파주고속도로
# 6   평택파주고속도로
# 7   평택파주고속도로
# 8   평택파주고속도로
# 9   평택파주고속도로
# 10  평택파주고속도로
# 11  평택파주고속도로
# 12  평택파주고속도로
# 13  평택파주고속도로
# 14  평택파주고속도로
# 15  평택파주고속도로
# 16  평택파주고속도로
# 17  평택파주고속도로
# 18  평택파주고속도로
# 19  평택파주고속도로
# 20  평택파주고속도로
# 21  평택파주고속도로
# 22  평택파주고속도로
# 23  평택파주고속도로
# 24  평택파주고속도로
# 25  평택파주고속도로
# 26  평택파주고속도로
# 27  평택파주고속도로
# 28  평택파주고속도로
# 29  평택파주고속도로
# 30  평택파주고속도로
# 31  평택파주고속도로
# 32  평택파주고속도로
# 33  평택파주고속도로
# 34  평택파주고속도로

# %%
df_null2_num1 = df_null2.reset_index(drop = True)
df_null2_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    642  12017VME00201  127.425144  37.071961   103  NaN    17  E
# 1    644  12017VME00401  127.413561  37.126372   103  NaN    17  E
# 2    646  12017VME00551  127.324370  37.203740   103  NaN    17  E
# 3    641  12017VMS00101  127.410322  37.059547   103  NaN    17  S
# 4    643  12017VMS00301  127.433550  37.096731   103  NaN    17  S
# 5    645  12017VMS00501  127.387375  37.146306   103  NaN    17  S
# 6    647  12017VMS00601  127.311420  37.222710   103  NaN    17  S
# 7    983  32017VME78101  127.424973  36.490878   103  NaN    17  E
# 8    949  32017VME78301  127.469842  36.591470   103  NaN    17  E
# 9    936  32017VME78501  127.499479  36.674247   103  NaN    17  E
# 10   950  32017VME78701  127.471382  36.719450   103  NaN    17  E
# 11   951  32017VME78902  127.441624  36.770335   103  NaN    17  E
# 12   952  32017VME79001  127.428851  36.845201   103  NaN    17  E
# ...

# %%
df_null2_num1['도로명'] = df_null2_num['도로명']
df_null2_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0    642  12017VME00201  127.425144  37.071961   103  평택파주고속도로    17  E
# 1    644  12017VME00401  127.413561  37.126372   103  평택파주고속도로    17  E
# 2    646  12017VME00551  127.324370  37.203740   103  평택파주고속도로    17  E
# 3    641  12017VMS00101  127.410322  37.059547   103  평택파주고속도로    17  S
# 4    643  12017VMS00301  127.433550  37.096731   103  평택파주고속도로    17  S
# 5    645  12017VMS00501  127.387375  37.146306   103  평택파주고속도로    17  S
# 6    647  12017VMS00601  127.311420  37.222710   103  평택파주고속도로    17  S
# 7    983  32017VME78101  127.424973  36.490878   103  평택파주고속도로    17  E
# 8    949  32017VME78301  127.469842  36.591470   103  평택파주고속도로    17  E
# 9    936  32017VME78501  127.499479  36.674247   103  평택파주고속도로    17  E
# 10   950  32017VME78701  127.471382  36.719450   103  평택파주고속도로    17  E
# 11   951  32017VME78902  127.441624  36.770335   103  평택파주고속도로    17  E
# ...

# %%
df_null3 = df_null[df_null['노선번호'] == 45]
df_null3
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 980    742  12045VME00101  127.022717  37.017256   103  NaN    45  E
# 981    743  12045VME00201  127.050819  37.017614   103  NaN    45  E
# 982    745  12045VME00401  127.144300  37.034822   103  NaN    45  E
# 983    747  12045VME00601  127.200508  37.067558   103  NaN    45  E
# 984    749  12045VME00801  127.216378  37.097883   103  NaN    45  E
# 985    751  12045VME01001  127.204492  37.208889   103  NaN    45  E
# 986    753  12045VME05101  127.210958  37.228503   103  NaN    45  E
# 987    755  12045VME05301  127.365897  37.648244   103  NaN    45  E
# 988    757  12045VME10151  127.245219  37.328083   103  NaN    45  E
# 989    758  12045VME10201  127.282822  37.488247   103  NaN    45  E
# 990    759  12045VME10301  127.257369  37.534706   103  NaN    45  E
# 991    760  12045VME11001  127.374767  37.676119   103  NaN    45  E
# 992    762  12045VME11201  127.394708  37.709697   103  NaN    45  E
# ...

# %%
df_null3_num = df_null3.reset_index(drop = True)
df_null3_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    742  12045VME00101  127.022717  37.017256   103  NaN    45  E
# 1    743  12045VME00201  127.050819  37.017614   103  NaN    45  E
# 2    745  12045VME00401  127.144300  37.034822   103  NaN    45  E
# 3    747  12045VME00601  127.200508  37.067558   103  NaN    45  E
# 4    749  12045VME00801  127.216378  37.097883   103  NaN    45  E
# 5    751  12045VME01001  127.204492  37.208889   103  NaN    45  E
# 6    753  12045VME05101  127.210958  37.228503   103  NaN    45  E
# 7    755  12045VME05301  127.365897  37.648244   103  NaN    45  E
# 8    757  12045VME10151  127.245219  37.328083   103  NaN    45  E
# 9    758  12045VME10201  127.282822  37.488247   103  NaN    45  E
# 10   759  12045VME10301  127.257369  37.534706   103  NaN    45  E
# 11   760  12045VME11001  127.374767  37.676119   103  NaN    45  E
# 12   762  12045VME11201  127.394708  37.709697   103  NaN    45  E
# ...

# %%
df_null3_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null3_num
# Out:
#     도로명
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN

# %%
df_null3_num.iloc[:] = '중부내륙고속도로'
df_null3_num
# Out:
#          도로명
# 0   중부내륙고속도로
# 1   중부내륙고속도로
# 2   중부내륙고속도로
# 3   중부내륙고속도로
# 4   중부내륙고속도로
# 5   중부내륙고속도로
# 6   중부내륙고속도로
# 7   중부내륙고속도로
# 8   중부내륙고속도로
# 9   중부내륙고속도로
# 10  중부내륙고속도로
# 11  중부내륙고속도로
# 12  중부내륙고속도로
# 13  중부내륙고속도로
# 14  중부내륙고속도로
# 15  중부내륙고속도로
# 16  중부내륙고속도로
# 17  중부내륙고속도로
# 18  중부내륙고속도로
# 19  중부내륙고속도로
# 20  중부내륙고속도로
# 21  중부내륙고속도로
# 22  중부내륙고속도로
# 23  중부내륙고속도로
# 24  중부내륙고속도로
# 25  중부내륙고속도로
# 26  중부내륙고속도로
# 27  중부내륙고속도로

# %%
df_null3_num1 = df_null3.reset_index(drop = True)
df_null3_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0    742  12045VME00101  127.022717  37.017256   103  NaN    45  E
# 1    743  12045VME00201  127.050819  37.017614   103  NaN    45  E
# 2    745  12045VME00401  127.144300  37.034822   103  NaN    45  E
# 3    747  12045VME00601  127.200508  37.067558   103  NaN    45  E
# 4    749  12045VME00801  127.216378  37.097883   103  NaN    45  E
# 5    751  12045VME01001  127.204492  37.208889   103  NaN    45  E
# 6    753  12045VME05101  127.210958  37.228503   103  NaN    45  E
# 7    755  12045VME05301  127.365897  37.648244   103  NaN    45  E
# 8    757  12045VME10151  127.245219  37.328083   103  NaN    45  E
# 9    758  12045VME10201  127.282822  37.488247   103  NaN    45  E
# 10   759  12045VME10301  127.257369  37.534706   103  NaN    45  E
# 11   760  12045VME11001  127.374767  37.676119   103  NaN    45  E
# 12   762  12045VME11201  127.394708  37.709697   103  NaN    45  E
# ...

# %%
df_null3_num1['도로명'] = df_null3_num['도로명']
df_null3_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0    742  12045VME00101  127.022717  37.017256   103  중부내륙고속도로    45  E
# 1    743  12045VME00201  127.050819  37.017614   103  중부내륙고속도로    45  E
# 2    745  12045VME00401  127.144300  37.034822   103  중부내륙고속도로    45  E
# 3    747  12045VME00601  127.200508  37.067558   103  중부내륙고속도로    45  E
# 4    749  12045VME00801  127.216378  37.097883   103  중부내륙고속도로    45  E
# 5    751  12045VME01001  127.204492  37.208889   103  중부내륙고속도로    45  E
# 6    753  12045VME05101  127.210958  37.228503   103  중부내륙고속도로    45  E
# 7    755  12045VME05301  127.365897  37.648244   103  중부내륙고속도로    45  E
# 8    757  12045VME10151  127.245219  37.328083   103  중부내륙고속도로    45  E
# 9    758  12045VME10201  127.282822  37.488247   103  중부내륙고속도로    45  E
# 10   759  12045VME10301  127.257369  37.534706   103  중부내륙고속도로    45  E
# 11   760  12045VME11001  127.374767  37.676119   103  중부내륙고속도로    45  E
# ...

# %%
df_null4 = df_null[df_null['노선번호'] == 14]
df_null4
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 1391  1448  42014VME10152  129.206996  35.251789   103  NaN    14  E
# 1392  1449  42014VME10201  129.165418  35.235941   103  NaN    14  E
# 1393  1450  42014VME11001  129.237656  35.297609   103  NaN    14  E
# 1394  1451  42014VME11201  129.265908  35.409310   103  NaN    14  E
# 1395  1452  42014VME11501  129.291115  35.461585   103  NaN    14  E
# 1396  1453  42014VME21002  128.967955  35.212341   103  NaN    14  E
# 1397  1454  42014VME21202  128.867870  35.252352   103  NaN    14  E
# 1398  1455  42014VME21402  128.781379  35.294069   103  NaN    14  E
# 1399  1465  42014VME21502  128.718584  35.312394   103  NaN    14  E
# 1400  1456  42014VMN10101  129.220909  35.243976   103  NaN    14  N
# 1401  1457  42014VMN11301  129.290528  35.435943   103  NaN    14  N
# 1402  1458  42014VMS10001  129.229522  35.269705   103  NaN    14  S
# 1403  1459  42014VMS11101  129.247061  35.337549   103  NaN    14  S
# ...

# %%
df_null4_num = df_null4.reset_index(drop = True)
df_null4_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   1448  42014VME10152  129.206996  35.251789   103  NaN    14  E
# 1   1449  42014VME10201  129.165418  35.235941   103  NaN    14  E
# 2   1450  42014VME11001  129.237656  35.297609   103  NaN    14  E
# 3   1451  42014VME11201  129.265908  35.409310   103  NaN    14  E
# 4   1452  42014VME11501  129.291115  35.461585   103  NaN    14  E
# 5   1453  42014VME21002  128.967955  35.212341   103  NaN    14  E
# 6   1454  42014VME21202  128.867870  35.252352   103  NaN    14  E
# 7   1455  42014VME21402  128.781379  35.294069   103  NaN    14  E
# 8   1465  42014VME21502  128.718584  35.312394   103  NaN    14  E
# 9   1456  42014VMN10101  129.220909  35.243976   103  NaN    14  N
# 10  1457  42014VMN11301  129.290528  35.435943   103  NaN    14  N
# 11  1458  42014VMS10001  129.229522  35.269705   103  NaN    14  S
# 12  1459  42014VMS11101  129.247061  35.337549   103  NaN    14  S
# ...

# %%
df_null4_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null4_num
# Out:
#     도로명
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN

# %%
df_null4_num.iloc[:] = '함양울산고속도로'
df_null4_num
# Out:
#          도로명
# 0   함양울산고속도로
# 1   함양울산고속도로
# 2   함양울산고속도로
# 3   함양울산고속도로
# 4   함양울산고속도로
# 5   함양울산고속도로
# 6   함양울산고속도로
# 7   함양울산고속도로
# 8   함양울산고속도로
# 9   함양울산고속도로
# 10  함양울산고속도로
# 11  함양울산고속도로
# 12  함양울산고속도로
# 13  함양울산고속도로
# 14  함양울산고속도로
# 15  함양울산고속도로
# 16  함양울산고속도로
# 17  함양울산고속도로

# %%
df_null4_num1 = df_null4.reset_index(drop = True)
df_null4_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   1448  42014VME10152  129.206996  35.251789   103  NaN    14  E
# 1   1449  42014VME10201  129.165418  35.235941   103  NaN    14  E
# 2   1450  42014VME11001  129.237656  35.297609   103  NaN    14  E
# 3   1451  42014VME11201  129.265908  35.409310   103  NaN    14  E
# 4   1452  42014VME11501  129.291115  35.461585   103  NaN    14  E
# 5   1453  42014VME21002  128.967955  35.212341   103  NaN    14  E
# 6   1454  42014VME21202  128.867870  35.252352   103  NaN    14  E
# 7   1455  42014VME21402  128.781379  35.294069   103  NaN    14  E
# 8   1465  42014VME21502  128.718584  35.312394   103  NaN    14  E
# 9   1456  42014VMN10101  129.220909  35.243976   103  NaN    14  N
# 10  1457  42014VMN11301  129.290528  35.435943   103  NaN    14  N
# 11  1458  42014VMS10001  129.229522  35.269705   103  NaN    14  S
# 12  1459  42014VMS11101  129.247061  35.337549   103  NaN    14  S
# ...

# %%
df_null4_num1['도로명'] = df_null4_num['도로명']
df_null4_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1448  42014VME10152  129.206996  35.251789   103  함양울산고속도로    14  E
# 1   1449  42014VME10201  129.165418  35.235941   103  함양울산고속도로    14  E
# 2   1450  42014VME11001  129.237656  35.297609   103  함양울산고속도로    14  E
# 3   1451  42014VME11201  129.265908  35.409310   103  함양울산고속도로    14  E
# 4   1452  42014VME11501  129.291115  35.461585   103  함양울산고속도로    14  E
# 5   1453  42014VME21002  128.967955  35.212341   103  함양울산고속도로    14  E
# 6   1454  42014VME21202  128.867870  35.252352   103  함양울산고속도로    14  E
# 7   1455  42014VME21402  128.781379  35.294069   103  함양울산고속도로    14  E
# 8   1465  42014VME21502  128.718584  35.312394   103  함양울산고속도로    14  E
# 9   1456  42014VMN10101  129.220909  35.243976   103  함양울산고속도로    14  N
# 10  1457  42014VMN11301  129.290528  35.435943   103  함양울산고속도로    14  N
# 11  1458  42014VMS10001  129.229522  35.269705   103  함양울산고속도로    14  S
# ...

# %%
df_null5 = df_null[df_null['노선번호'] == 32]
df_null5
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 1246  1016  32032VME01001  126.460617  36.771764   103  NaN    32  E
# 1247   958  32032VME01101  126.486824  36.785441   103  NaN    32  E
# 1248   959  32032VME01201  126.557168  36.808877   103  NaN    32  E
# 1249   960  32032VME01501  126.685652  36.901798   103  NaN    32  E
# 1250  1017  32032VME30001  127.134709  36.466200   103  NaN    32  E
# 1251  1021  32032VME30201  127.171281  36.451076   103  NaN    32  E
# 1252  1023  32032VME30401  127.219831  36.418458   103  NaN    32  E
# 1253  1026  32032VME30601  127.257014  36.384309   103  NaN    32  E
# 1254   904  32032VME70101  126.846564  36.674288   103  NaN    32  E
# 1255   961  32032VMS01301  126.581368  36.833858   103  NaN    32  S
# 1256   962  32032VMS01401  126.641376  36.903904   103  NaN    32  S
# 1257   963  32032VMS01601  126.730458  36.893475   103  NaN    32  S
# 1258   964  32032VMS01701  126.752380  36.866920   103  NaN    32  S
# ...

# %%
df_null5_num = df_null5.reset_index(drop = True)
df_null5_num
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   1016  32032VME01001  126.460617  36.771764   103  NaN    32  E
# 1    958  32032VME01101  126.486824  36.785441   103  NaN    32  E
# 2    959  32032VME01201  126.557168  36.808877   103  NaN    32  E
# 3    960  32032VME01501  126.685652  36.901798   103  NaN    32  E
# 4   1017  32032VME30001  127.134709  36.466200   103  NaN    32  E
# 5   1021  32032VME30201  127.171281  36.451076   103  NaN    32  E
# 6   1023  32032VME30401  127.219831  36.418458   103  NaN    32  E
# 7   1026  32032VME30601  127.257014  36.384309   103  NaN    32  E
# 8    904  32032VME70101  126.846564  36.674288   103  NaN    32  E
# 9    961  32032VMS01301  126.581368  36.833858   103  NaN    32  S
# 10   962  32032VMS01401  126.641376  36.903904   103  NaN    32  S
# 11   963  32032VMS01601  126.730458  36.893475   103  NaN    32  S
# 12   964  32032VMS01701  126.752380  36.866920   103  NaN    32  S
# ...

# %%
df_null5_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null5_num
# Out:
#     도로명
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN

# %%
df_null5_num.iloc[:] = '아산청주고속도로'
df_null5_num
# Out:
#          도로명
# 0   아산청주고속도로
# 1   아산청주고속도로
# 2   아산청주고속도로
# 3   아산청주고속도로
# 4   아산청주고속도로
# 5   아산청주고속도로
# 6   아산청주고속도로
# 7   아산청주고속도로
# 8   아산청주고속도로
# 9   아산청주고속도로
# 10  아산청주고속도로
# 11  아산청주고속도로
# 12  아산청주고속도로
# 13  아산청주고속도로
# 14  아산청주고속도로
# 15  아산청주고속도로
# 16  아산청주고속도로

# %%
df_null5_num1 = df_null5.reset_index(drop = True)
df_null5_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   1016  32032VME01001  126.460617  36.771764   103  NaN    32  E
# 1    958  32032VME01101  126.486824  36.785441   103  NaN    32  E
# 2    959  32032VME01201  126.557168  36.808877   103  NaN    32  E
# 3    960  32032VME01501  126.685652  36.901798   103  NaN    32  E
# 4   1017  32032VME30001  127.134709  36.466200   103  NaN    32  E
# 5   1021  32032VME30201  127.171281  36.451076   103  NaN    32  E
# 6   1023  32032VME30401  127.219831  36.418458   103  NaN    32  E
# 7   1026  32032VME30601  127.257014  36.384309   103  NaN    32  E
# 8    904  32032VME70101  126.846564  36.674288   103  NaN    32  E
# 9    961  32032VMS01301  126.581368  36.833858   103  NaN    32  S
# 10   962  32032VMS01401  126.641376  36.903904   103  NaN    32  S
# 11   963  32032VMS01601  126.730458  36.893475   103  NaN    32  S
# 12   964  32032VMS01701  126.752380  36.866920   103  NaN    32  S
# ...

# %%
df_null5_num1['도로명'] = df_null5_num['도로명']
df_null5_num1
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   1016  32032VME01001  126.460617  36.771764   103  아산청주고속도로    32  E
# 1    958  32032VME01101  126.486824  36.785441   103  아산청주고속도로    32  E
# 2    959  32032VME01201  126.557168  36.808877   103  아산청주고속도로    32  E
# 3    960  32032VME01501  126.685652  36.901798   103  아산청주고속도로    32  E
# 4   1017  32032VME30001  127.134709  36.466200   103  아산청주고속도로    32  E
# 5   1021  32032VME30201  127.171281  36.451076   103  아산청주고속도로    32  E
# 6   1023  32032VME30401  127.219831  36.418458   103  아산청주고속도로    32  E
# 7   1026  32032VME30601  127.257014  36.384309   103  아산청주고속도로    32  E
# 8    904  32032VME70101  126.846564  36.674288   103  아산청주고속도로    32  E
# 9    961  32032VMS01301  126.581368  36.833858   103  아산청주고속도로    32  S
# 10   962  32032VMS01401  126.641376  36.903904   103  아산청주고속도로    32  S
# 11   963  32032VMS01601  126.730458  36.893475   103  아산청주고속도로    32  S
# ...

# %%
df_null6 = df_null[df_null['노선번호'] == 29]
df_null6
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 1239   976  32029VME40001  126.586420  36.593971   103  NaN    29  E
# 1240  1011  32029VME40201  126.535446  36.644149   103  NaN    29  E
# 1241  1012  32029VME40301  126.543889  36.702853   103  NaN    29  E
# 1242  1015  32029VME40501  126.476472  36.767493   103  NaN    29  E
# 1243   923  32029VMS39901  126.613436  36.586267   103  NaN    29  S
# 1244  1010  32029VMS40101  126.544670  36.614425   103  NaN    29  S
# 1245  1014  32029VMS40401  126.525098  36.729798   103  NaN    29  S

# %%
df_null6_num = df_null6.reset_index(drop = True)
df_null6_num
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   976  32029VME40001  126.586420  36.593971   103  NaN    29  E
# 1  1011  32029VME40201  126.535446  36.644149   103  NaN    29  E
# 2  1012  32029VME40301  126.543889  36.702853   103  NaN    29  E
# 3  1015  32029VME40501  126.476472  36.767493   103  NaN    29  E
# 4   923  32029VMS39901  126.613436  36.586267   103  NaN    29  S
# 5  1010  32029VMS40101  126.544670  36.614425   103  NaN    29  S
# 6  1014  32029VMS40401  126.525098  36.729798   103  NaN    29  S

# %%
df_null6_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null6_num
# Out:
#    도로명
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN

# %%
df_null6_num.iloc[:] = '세종포천고속도로'
df_null6_num
# Out:
#         도로명
# 0  세종포천고속도로
# 1  세종포천고속도로
# 2  세종포천고속도로
# 3  세종포천고속도로
# 4  세종포천고속도로
# 5  세종포천고속도로
# 6  세종포천고속도로

# %%
df_null6_num1 = df_null6.reset_index(drop = True)
df_null6_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   976  32029VME40001  126.586420  36.593971   103  NaN    29  E
# 1  1011  32029VME40201  126.535446  36.644149   103  NaN    29  E
# 2  1012  32029VME40301  126.543889  36.702853   103  NaN    29  E
# 3  1015  32029VME40501  126.476472  36.767493   103  NaN    29  E
# 4   923  32029VMS39901  126.613436  36.586267   103  NaN    29  S
# 5  1010  32029VMS40101  126.544670  36.614425   103  NaN    29  S
# 6  1014  32029VMS40401  126.525098  36.729798   103  NaN    29  S

# %%
df_null6_num1['도로명'] = df_null6_num['도로명']
df_null6_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   976  32029VME40001  126.586420  36.593971   103  세종포천고속도로    29  E
# 1  1011  32029VME40201  126.535446  36.644149   103  세종포천고속도로    29  E
# 2  1012  32029VME40301  126.543889  36.702853   103  세종포천고속도로    29  E
# 3  1015  32029VME40501  126.476472  36.767493   103  세종포천고속도로    29  E
# 4   923  32029VMS39901  126.613436  36.586267   103  세종포천고속도로    29  S
# 5  1010  32029VMS40101  126.544670  36.614425   103  세종포천고속도로    29  S
# 6  1014  32029VMS40401  126.525098  36.729798   103  세종포천고속도로    29  S

# %%
df_null7 = df_null[df_null['노선번호'] == 40]
df_null7
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 1293   972  32040VME00101  127.403177  36.529027   103  NaN    40  E
# 1294   930  32040VME01101  126.528930  36.598763   103  NaN    40  E
# 1295  1009  32040VMS01001  126.582535  36.613516   103  NaN    40  S
# 1304   973  34540VME50001  127.452298  36.731463   103  NaN    40  E
# 1305   974  34540VME50101  127.436889  36.707391   103  NaN    40  E

# %%
df_null7_num = df_null7.reset_index(drop = True)
df_null7_num
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   972  32040VME00101  127.403177  36.529027   103  NaN    40  E
# 1   930  32040VME01101  126.528930  36.598763   103  NaN    40  E
# 2  1009  32040VMS01001  126.582535  36.613516   103  NaN    40  S
# 3   973  34540VME50001  127.452298  36.731463   103  NaN    40  E
# 4   974  34540VME50101  127.436889  36.707391   103  NaN    40  E

# %%
df_null7_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null7_num
# Out:
#    도로명
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df_null7_num.iloc[:] = '평택제천고속도로'
df_null7_num
# Out:
#         도로명
# 0  평택제천고속도로
# 1  평택제천고속도로
# 2  평택제천고속도로
# 3  평택제천고속도로
# 4  평택제천고속도로

# %%
df_null7_num1 = df_null7.reset_index(drop = True)
df_null7_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0   972  32040VME00101  127.403177  36.529027   103  NaN    40  E
# 1   930  32040VME01101  126.528930  36.598763   103  NaN    40  E
# 2  1009  32040VMS01001  126.582535  36.613516   103  NaN    40  S
# 3   973  34540VME50001  127.452298  36.731463   103  NaN    40  E
# 4   974  34540VME50101  127.436889  36.707391   103  NaN    40  E

# %%
df_null7_num1['도로명'] = df_null7_num['도로명']
df_null7_num1
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   972  32040VME00101  127.403177  36.529027   103  평택제천고속도로    40  E
# 1   930  32040VME01101  126.528930  36.598763   103  평택제천고속도로    40  E
# 2  1009  32040VMS01001  126.582535  36.613516   103  평택제천고속도로    40  S
# 3   973  34540VME50001  127.452298  36.731463   103  평택제천고속도로    40  E
# 4   974  34540VME50101  127.436889  36.707391   103  평택제천고속도로    40  E

# %%
df_null8 = df_null[df_null['노선번호'] == 37]
df_null8
# Out:
#       순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 892  654  12037VME00101  127.650060  37.247870   103  NaN    37  E
# 893  656  12037VME00301  127.597610  37.352880   103  NaN    37  E
# 894  655  12037VMS00201  127.625500  37.337420   103  NaN    37  S
# 895  657  12037VMS00601  127.523058  37.468467   103  NaN    37  S

# %%
df_null8_num = df_null8.reset_index(drop = True)
df_null8_num
# Out:
#     순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  654  12037VME00101  127.650060  37.247870   103  NaN    37  E
# 1  656  12037VME00301  127.597610  37.352880   103  NaN    37  E
# 2  655  12037VMS00201  127.625500  37.337420   103  NaN    37  S
# 3  657  12037VMS00601  127.523058  37.468467   103  NaN    37  S

# %%
df_null8_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null8_num
# Out:
#    도로명
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN

# %%
df_null8_num.iloc[:] = '제2중부고속도로'
df_null8_num
# Out:
#         도로명
# 0  제2중부고속도로
# 1  제2중부고속도로
# 2  제2중부고속도로
# 3  제2중부고속도로

# %%
df_null8_num1 = df_null8.reset_index(drop = True)
df_null8_num1
# Out:
#     순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  654  12037VME00101  127.650060  37.247870   103  NaN    37  E
# 1  656  12037VME00301  127.597610  37.352880   103  NaN    37  E
# 2  655  12037VMS00201  127.625500  37.337420   103  NaN    37  S
# 3  657  12037VMS00601  127.523058  37.468467   103  NaN    37  S

# %%
df_null8_num1['도로명'] = df_null8_num['도로명']
df_null8_num1
# Out:
#     순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0  654  12037VME00101  127.650060  37.247870   103  제2중부고속도로    37  E
# 1  656  12037VME00301  127.597610  37.352880   103  제2중부고속도로    37  E
# 2  655  12037VMS00201  127.625500  37.337420   103  제2중부고속도로    37  S
# 3  657  12037VMS00601  127.523058  37.468467   103  제2중부고속도로    37  S

# %%
df_null9 = df_null[df_null['노선번호'] == 10]
df_null9
# Out:
#        순번         VMS_ID      좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 1303  873  34510VME60001  127.54156  36.774368   103  NaN    10  E

# %%
df_null9_num = df_null9.reset_index(drop = True)
df_null9_num
# Out:
#     순번         VMS_ID      좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  873  34510VME60001  127.54156  36.774368   103  NaN    10  E

# %%
df_null9_num.drop(['순번', 'VMS_ID', '좌표(X)', '좌표(Y)', '도로등급', '노선번호', '방향'], axis = 1, inplace = True)
df_null9_num
# Out:
#    도로명
# 0  NaN

# %%
df_null9_num.iloc[:] = '남해고속도로'
df_null9_num
# Out:
#       도로명
# 0  남해고속도로

# %%
df_null9_num1 = df_null9.reset_index(drop = True)
df_null9_num1
# Out:
#     순번         VMS_ID      좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 0  873  34510VME60001  127.54156  36.774368   103  NaN    10  E

# %%
df_null9_num1['도로명'] = df_null9_num['도로명']
df_null9_num1
# Out:
#     순번         VMS_ID      좌표(X)      좌표(Y)  도로등급     도로명  노선번호 방향
# 0  873  34510VME60001  127.54156  36.774368   103  남해고속도로    10  E

# %% [markdown]
# ## 결측치 파일 합치기

# %%
df_every = pd.concat([df_null1_num1, df_null2_num1, df_null3_num1, df_null4_num1, df_null5_num1, df_null6_num1, df_null7_num1, df_null8_num1, df_null9_num1])
df_every
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명  노선번호 방향
# 0   591  12001VME00101  127.072175  37.016314   103    경부고속도로     1  E
# 1   592  12001VME00201  127.116036  36.978978   103    경부고속도로     1  E
# 2   594  12001VME00401  127.064989  37.042178   103    경부고속도로     1  E
# 3   596  12001VME00601  127.065403  37.121278   103    경부고속도로     1  E
# 4   598  12001VME00801  127.041856  37.196414   103    경부고속도로     1  E
# ..  ...            ...         ...        ...   ...       ...   ... ..
# 0   654  12037VME00101  127.650060  37.247870   103  제2중부고속도로    37  E
# 1   656  12037VME00301  127.597610  37.352880   103  제2중부고속도로    37  E
# 2   655  12037VMS00201  127.625500  37.337420   103  제2중부고속도로    37  S
# 3   657  12037VMS00601  127.523058  37.468467   103  제2중부고속도로    37  S
# 0   873  34510VME60001  127.541560  36.774368   103    남해고속도로    10  E
#
# [166 rows x 8 columns]

# %% [markdown]
# ## 파일과 변경한 결측치 파일 합치기

# %%
new_df = pd.concat([df_name_all, df_every])
new_df
# Out:
#      순번         VMS_ID       좌표(X)      좌표(Y)  도로등급       도로명 노선번호 방향
# 0   112   0010VME00100  129.105278  35.279167   101    경부고속도로    1  E
# 1   114   0010VME00200  129.061944  35.317778   101    경부고속도로    1  E
# 2   118   0010VME00400  129.088611  35.466111   101    경부고속도로    1  E
# 3   120   0010VME00500  129.106944  35.519167   101    경부고속도로    1  E
# 4   248   0010VME00600  129.113944  35.830778   101    경부고속도로    1  E
# ..  ...            ...         ...        ...   ...       ...  ... ..
# 0   654  12037VME00101  127.650060  37.247870   103  제2중부고속도로   37  E
# 1   656  12037VME00301  127.597610  37.352880   103  제2중부고속도로   37  E
# 2   655  12037VMS00201  127.625500  37.337420   103  제2중부고속도로   37  S
# 3   657  12037VMS00601  127.523058  37.468467   103  제2중부고속도로   37  S
# 0   873  34510VME60001  127.541560  36.774368   103    남해고속도로   10  E
#
# [1056 rows x 8 columns]

# %% [markdown]
# ## 파일 + 변경한 결측치 파일 + 결측치 파일 합치기

# %%
df_null = df.loc[df['도로명'].isna()]
df_null
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 829    591  12001VME00101  127.072175  37.016314   103  NaN     1  E
# 830    592  12001VME00201  127.116036  36.978978   103  NaN     1  E
# 831    594  12001VME00401  127.064989  37.042178   103  NaN     1  E
# 832    596  12001VME00601  127.065403  37.121278   103  NaN     1  E
# 833    598  12001VME00801  127.041856  37.196414   103  NaN     1  E
# ...    ...            ...         ...        ...   ...  ...   ... ..
# 1482  1049  52022VME50101  126.972996  35.046152   103  NaN    22  E
# 1483  1048  52022VMS50001  126.925582  35.136574   103  NaN    22  S
# 1484  1075  52026VME21101  127.277909  35.841145   103  NaN    26  E
# 1485  1074  52026VMN21001  126.973701  35.886580   103  NaN    26  N
# 1486  1076  52026VMS21201  127.328327  35.856220   103  NaN    26  S
#
# [600 rows x 8 columns]

# %%
df_new_null1 = df_null1.index
df_new_null2 = df_null2.index
df_new_null3 = df_null3.index
df_new_null4 = df_null4.index
df_new_null5 = df_null5.index
df_new_null6 = df_null6.index
df_new_null7 = df_null7.index
df_new_null8 = df_null8.index
df_new_null9 = df_null9.index

df_new_null1 = df_null.drop(df_new_null1)
df_new_null2 = df_new_null1.drop(df_new_null2)
df_new_null3 = df_new_null2.drop(df_new_null3)
df_new_null4 = df_new_null3.drop(df_new_null4)
df_new_null5 = df_new_null4.drop(df_new_null5)
df_new_null6 = df_new_null5.drop(df_new_null6)
df_new_null7 = df_new_null6.drop(df_new_null7)
df_new_null8 = df_new_null7.drop(df_new_null8)
df_new_null9 = df_new_null8.drop(df_new_null9)

df_new_null9
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급  도로명  노선번호 방향
# 846    608  12003VME00101  127.616585  37.083543   103  NaN     3  E
# 847    610  12003VME00301  127.576755  37.155640   103  NaN     3  E
# 848    612  12003VME00501  127.496960  37.244130   103  NaN     3  E
# 849    613  12003VME00601  127.459170  37.267750   103  NaN     3  E
# 850    616  12003VME00801  127.359780  37.341491   103  NaN     3  E
# ...    ...            ...         ...        ...   ...  ...   ... ..
# 1482  1049  52022VME50101  126.972996  35.046152   103  NaN    22  E
# 1483  1048  52022VMS50001  126.925582  35.136574   103  NaN    22  S
# 1484  1075  52026VME21101  127.277909  35.841145   103  NaN    26  E
# 1485  1074  52026VMN21001  126.973701  35.886580   103  NaN    26  N
# 1486  1076  52026VMS21201  127.328327  35.856220   103  NaN    26  S
#
# [434 rows x 8 columns]

# %%
new_df_all = pd.concat([new_df, df_new_null9])
new_df_all
# Out:
#         순번         VMS_ID       좌표(X)      좌표(Y)  도로등급     도로명 노선번호 방향
# 0      112   0010VME00100  129.105278  35.279167   101  경부고속도로    1  E
# 1      114   0010VME00200  129.061944  35.317778   101  경부고속도로    1  E
# 2      118   0010VME00400  129.088611  35.466111   101  경부고속도로    1  E
# 3      120   0010VME00500  129.106944  35.519167   101  경부고속도로    1  E
# 4      248   0010VME00600  129.113944  35.830778   101  경부고속도로    1  E
# ...    ...            ...         ...        ...   ...     ...  ... ..
# 1482  1049  52022VME50101  126.972996  35.046152   103     NaN   22  E
# 1483  1048  52022VMS50001  126.925582  35.136574   103     NaN   22  S
# 1484  1075  52026VME21101  127.277909  35.841145   103     NaN   26  E
# 1485  1074  52026VMN21001  126.973701  35.886580   103     NaN   26  N
# 1486  1076  52026VMS21201  127.328327  35.856220   103     NaN   26  S
#
# [1490 rows x 8 columns]

# %% [markdown]
# ## csv 파일 저장

# %%
new_df_all.to_csv('VMS현황자료수정20230117.csv', encoding='utf-8-sig')
